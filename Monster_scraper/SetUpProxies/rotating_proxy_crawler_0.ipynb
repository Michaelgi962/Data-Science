# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from fake_useragent import UserAgent
import random

# %% [markdown]
# # Import the Data

# %%
try:
    Https_txt_file = 'proxyLists/https_proxys_part_0.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
    https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
    #Convert to array
    https_proxys = https_proxys[0].values
    #Convert to list
    https_proxys = list(https_proxys)
except:
    print('There are no https proxies to import')

try:
    Http_txt_file = 'proxyLists/http_proxys_part_0.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
    http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
    #Convert to array
    http_proxys = http_proxys[0].values
    #Convert to list
    http_proxys = list(http_proxys)
except:
    print('There are no http proxies to import')

# %%
# Make a dictionary for the proxies to test
testProxies = {'https':https_proxys,'http':http_proxys}

# %%
# Retrieve a random user-agent
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndex(conn_type):
    num = random.randint(0, len(testProxies[conn_type]) - 1)
    return num

# %%
proxyDict = {}
def randProx(conn_type):
    # Choose a single random proxy to use
    proxy_index = randomIndex(conn_type)
    proxy = testProxies[conn_type][proxy_index]
    proxyDict[conn_type] = conn_type +'://'+ proxy
    return proxy_index

# %%
# Initialize Dictionary for good proxies 
good_http_proxy = []
good_https_proxy = []
conn_time_http = []
conn_time_https = []
goodProxy = {'https':{'proxy':good_https_proxy,'time':conn_time_https},
             'http':{'proxy':good_http_proxy,'time':conn_time_http}}

# %%
def filterProxys(url):
    timer = 0
    count = 0
    if url[0:5] == 'http:':
        conn_type = 'http'
        
    elif url[0:5] == 'https':
        conn_type = 'https'

    total_proxies = len(testProxies[conn_type])
    for n in range(len(testProxies[conn_type])):
        time.sleep(1)
        print(str(total_proxies-n)+' proxies left to filter')
            
        try:
            # Choose a random header
            randHeader()
            
        except:
            # Sometimes the header reassignment function returns an error
            pass
            
        # Choose a random proxy
        proxy_index = randProx(conn_type)

        try:
            # Try to connect to the url
            t1 = time.time()
            soup = requests.get(url,headers=header,proxies=proxyDict,timeout=5)
            t2 = time.time()
            t = t2-t1
                
            if  str(soup) == '<Response [200]>': # the connection is successful when <Response [200]> is returned
                print(str(testProxies[conn_type][proxy_index])+' is good')
                del testProxies[conn_type][proxy_index]
                timer += t
                count += 1
                print('average conn time: '+str(timer/count)+'\n')
                #Add to the good proxy and its connection time
                goodProxy[conn_type]['proxy'].append(proxyDict[conn_type])
                goodProxy[conn_type]['time'].append(t)
                    
            elif str(soup) != '<Response [200]>': #The connection was bad
                print(str(testProxies[conn_type][proxy_index])+' is bad'+'\n')
                del testProxies[conn_type][proxy_index]
                    
                    
        except: # The connection took too long 
            print(str(testProxies[conn_type][proxy_index])+' is slow'+'\n')
            del testProxies[conn_type][proxy_index]
    try:
        print('average proxy time:'+str(timer/count))
    except:
        print('No proxies to text')

# %% [markdown]
# # Filter the Https proxies

# %%
url = 'https://www.proxy-list.download/HTTPS'
filterProxys(url)
# Out:
# 1179 proxies left to filter
# 117.191.11.104:8080 is slow
#
# 1178 proxies left to filter
# 117.191.11.108:8080 is slow
#
# 1177 proxies left to filter
# 139.255.56.66:8080 is good
# average conn time: 3.84980916977
#
# 1176 proxies left to filter
# 1.20.98.168:40771 is bad
#
# 1175 proxies left to filter
# 112.16.28.103:8060 is slow
#
# 1174 proxies left to filter
# 117.191.11.112:80 is slow
#
# 1173 proxies left to filter
# 117.240.138.2:33457 is slow
#
# 1172 proxies left to filter
# 109.194.33.242:53281 is good
# average conn time: 4.75956261158
#
# 1171 proxies left to filter
# 139.194.67.120:8080 is good
# average conn time: 5.70369442304
#
# 1170 proxies left to filter
# 116.114.19.204:443 is slow
#
# 1169 proxies left to filter
# 115.254.38.145:80 is slow
#
# 1168 proxies left to filter
# 119.52.208.205:8080 is slow
#
# 1167 proxies left to filter
# 118.174.131.241:41987 is slow
#
# 1166 proxies left to filter
# 103.106.239.162:8080 is good
# average conn time: 5.7032610774
#
# 1165 proxies left to filter
# 1.20.103.248:52574 is good
# average conn time: 6.03603844643
#
# 1164 proxies left to filter
# 158.69.138.14:1080 is slow
#
# 1163 proxies left to filter
# 117.191.11.106:8080 is slow
#
# 1162 proxies left to filter
# 117.254.217.107:23500 is slow
#
# 1161 proxies left to filter
# 101.51.141.119:40671 is good
# average conn time: 5.49210254351
#
# 1160 proxies left to filter
# 117.206.83.26:41080 is slow
#
# 1159 proxies left to filter
# 118.174.232.243:8080 is good
# average conn time: 5.18918289457
#
# 1158 proxies left to filter
# 103.194.251.37:51436 is slow
#
# 1157 proxies left to filter
# 119.82.253.47:8080 is good
# average conn time: 5.47564855218
#
# 1156 proxies left to filter
# 109.196.127.35:8888 is slow
#
# 1155 proxies left to filter
# 119.235.26.18:8080 is slow
#
# 1154 proxies left to filter
# 1.20.100.227:57396 is slow
#
# 1153 proxies left to filter
# 128.199.235.109:8080 is slow
#
# 1152 proxies left to filter
# 124.248.190.62:8080 is good
# average conn time: 5.43571649657
#
# 1151 proxies left to filter
# 101.51.59.215:8080 is good
# average conn time: 5.5394828558
#
# 1150 proxies left to filter
# 118.174.211.222:8080 is good
# average conn time: 5.23430724577
#
# 1149 proxies left to filter
# 109.122.81.1:44556 is bad
#
# 1148 proxies left to filter
# 134.119.222.247:1080 is slow
#
# 1147 proxies left to filter
# 103.111.83.26:43397 is good
# average conn time: 5.09925963481
#
# 1146 proxies left to filter
# 103.251.225.13:34052 is good
# average conn time: 4.9592995827
#
# 1145 proxies left to filter
# 101.109.83.222:8080 is good
# average conn time: 5.27824933188
#
# 1144 proxies left to filter
# 115.127.92.234:41258 is bad
#
# 1143 proxies left to filter
# 118.175.93.157:49498 is bad
#
# 1142 proxies left to filter
# 115.77.191.180:53281 is bad
#
# 1141 proxies left to filter
# 119.179.136.73:8060 is slow
#
# 1140 proxies left to filter
# 134.209.66.166:8080 is slow
#
# 1139 proxies left to filter
# 103.204.82.15:80 is slow
#
# 1138 proxies left to filter
# 119.2.49.118:31002 is slow
#
# 1137 proxies left to filter
# 151.106.10.51:8080 is slow
#
# 1136 proxies left to filter
# 117.191.11.72:80 is slow
#
# 1135 proxies left to filter
# 111.11.100.13:8060 is slow
#
# 1134 proxies left to filter
# 149.28.72.247:443 is good
# average conn time: 4.9831893762
#
# 1133 proxies left to filter
# 110.74.193.235:53569 is bad
#
# 1132 proxies left to filter
# 103.54.220.148:37046 is bad
#
# 1131 proxies left to filter
# 158.69.104.197:1080 is slow
#
# 1130 proxies left to filter
# 134.119.205.252:8080 is slow
#
# 1129 proxies left to filter
# 113.128.26.9:8888 is slow
#
# 1128 proxies left to filter
# 1.20.97.238:31769 is slow
#
# 1127 proxies left to filter
# 103.194.90.242:53682 is slow
#
# 1126 proxies left to filter
# 1.20.102.99:8080 is slow
#
# 1125 proxies left to filter
# 1.10.189.7:40518 is slow
#
# 1124 proxies left to filter
# 124.41.211.36:8080 is good
# average conn time: 5.17539416254
#
# 1123 proxies left to filter
# 113.7.174.10:8888 is slow
#
# 1122 proxies left to filter
# 145.239.92.81:3128 is good
# average conn time: 4.95810961723
#
# 1121 proxies left to filter
# 1.20.96.95:48881 is good
# average conn time: 4.92282480664
#
# 1120 proxies left to filter
# 101.26.48.58:8060 is slow
#
# 1119 proxies left to filter
# 1.20.100.33:47491 is good
# average conn time: 5.03533481297
#
# 1118 proxies left to filter
# 103.248.219.172:8080 is slow
#
# 1117 proxies left to filter
# 159.65.89.244:8080 is slow
#
# 1116 proxies left to filter
# 104.248.51.244:80 is slow
#
# 1115 proxies left to filter
# 144.217.75.162:1080 is slow
#
# 1114 proxies left to filter
# 103.88.234.248:46868 is bad
#
# 1113 proxies left to filter
# 103.14.45.250:8080 is slow
#
# 1112 proxies left to filter
# 117.191.11.107:8080 is slow
#
# 1111 proxies left to filter
# 103.253.2.168:51229 is bad
#
# 1110 proxies left to filter
# 103.254.86.218:36860 is bad
#
# 1109 proxies left to filter
# 157.230.34.190:1111 is bad
#
# 1108 proxies left to filter
# 138.97.244.22:8080 is good
# average conn time: 4.98510397673
#
# 1107 proxies left to filter
# 157.230.44.168:1111 is bad
#
# 1106 proxies left to filter
# 134.236.17.48:8080 is slow
#
# 1105 proxies left to filter
# 103.104.58.13:8080 is good
# average conn time: 5.04933998698
#
# 1104 proxies left to filter
# 111.198.104.169:808 is bad
#
# 1103 proxies left to filter
# 117.211.166.214:3128 is slow
#
# 1102 proxies left to filter
# 154.73.159.10:8585 is slow
#
# 1101 proxies left to filter
# 103.115.100.246:39249 is slow
#
# 1100 proxies left to filter
# 157.230.243.143:80 is slow
#
# 1099 proxies left to filter
# 133.167.81.162:8080 is good
# average conn time: 4.90268352899
#
# 1098 proxies left to filter
# 103.119.145.38:3128 is slow
#
# 1097 proxies left to filter
# 138.121.25.16:55780 is slow
#
# 1096 proxies left to filter
# 103.23.103.203:32137 is bad
#
# 1095 proxies left to filter
# 101.255.97.74:53281 is slow
#
# 1094 proxies left to filter
# 1.20.100.8:47974 is good
# average conn time: 4.80261345532
#
# 1093 proxies left to filter
# 117.58.247.25:8080 is good
# average conn time: 4.89453668396
#
# 1092 proxies left to filter
# 103.245.77.115:8080 is good
# average conn time: 5.10442557335
#
# 1091 proxies left to filter
# 103.55.193.201:80 is slow
#
# 1090 proxies left to filter
# 115.171.110.84:9000 is slow
#
# 1089 proxies left to filter
# 113.53.61.152:8080 is good
# average conn time: 5.1562388952
#
# 1088 proxies left to filter
# 117.212.95.83:8080 is slow
#
# 1087 proxies left to filter
# 157.230.90.113:8080 is good
# average conn time: 4.98868519289
#
# 1086 proxies left to filter
# 138.204.95.189:8080 is good
# average conn time: 4.9714511122
#
# 1085 proxies left to filter
# 118.175.93.107:38176 is slow
#
# 1084 proxies left to filter
# 128.199.246.226:3128 is bad
#
# 1083 proxies left to filter
# 144.217.69.149:1080 is slow
#
# 1082 proxies left to filter
# 109.194.1.222:8080 is bad
#
# 1081 proxies left to filter
# 103.252.184.21:53281 is slow
#
# 1080 proxies left to filter
# 119.180.173.35:8060 is slow
#
# 1079 proxies left to filter
# 138.197.153.148:3128 is good
# average conn time: 4.82210349214
#
# 1078 proxies left to filter
# 120.50.10.85:8080 is good
# average conn time: 4.84356001218
#
# 1077 proxies left to filter
# 117.196.229.84:8080 is good
# average conn time: 4.92941834081
#
# 1076 proxies left to filter
# 117.191.11.78:8080 is slow
#
# 1075 proxies left to filter
# 1.179.183.109:8080 is good
# average conn time: 4.93674464524
#
# 1074 proxies left to filter
# 110.74.195.86:61412 is good
# average conn time: 5.00495799383
#
# 1073 proxies left to filter
# 103.39.246.210:3128 is slow
#
# 1072 proxies left to filter
# 118.174.220.164:61858 is good
# average conn time: 4.94656278807
#
# 1071 proxies left to filter
# 121.28.43.212:3128 is slow
#
# 1070 proxies left to filter
# 110.138.250.225:8080 is good
# average conn time: 4.99997425079
#
# 1069 proxies left to filter
# 103.224.185.20:40917 is slow
#
# 1068 proxies left to filter
# 158.69.138.13:1080 is slow
#
# 1067 proxies left to filter
# 150.129.171.46:31382 is good
# average conn time: 4.96009946532
#
# 1066 proxies left to filter
# 103.75.25.253:44307 is slow
#
# 1065 proxies left to filter
# 109.86.184.131:39248 is slow
#
# 1064 proxies left to filter
# 103.76.190.178:47492 is slow
#
# 1063 proxies left to filter
# 138.197.180.50:80 is slow
#
# 1062 proxies left to filter
# 118.175.170.72:8080 is good
# average conn time: 4.99488985861
#
# 1061 proxies left to filter
# 118.99.97.49:8080 is good
# average conn time: 4.99540302001
#
# 1060 proxies left to filter
# 138.0.88.197:23500 is slow
#
# 1059 proxies left to filter
# 120.236.128.201:8060 is slow
#
# 1058 proxies left to filter
# 119.15.94.150:8080 is good
# average conn time: 5.00654035348
#
# 1057 proxies left to filter
# 1.179.148.9:60520 is bad
#
# 1056 proxies left to filter
# 110.93.209.142:53153 is bad
#
# 1055 proxies left to filter
# 1.20.101.46:54381 is slow
#
# 1054 proxies left to filter
# 109.73.180.210:8080 is good
# average conn time: 4.97746959329
#
# 1053 proxies left to filter
# 101.51.243.31:8080 is good
# average conn time: 4.91260329107
#
# 1052 proxies left to filter
# 110.93.13.172:8080 is slow
#
# 1051 proxies left to filter
# 101.255.36.233:55839 is slow
#
# 1050 proxies left to filter
# 125.26.7.83:8080 is good
# average conn time: 4.88878066199
#
# 1049 proxies left to filter
# 103.1.94.137:23500 is slow
#
# 1048 proxies left to filter
# 103.15.60.23:8080 is slow
#
# 1047 proxies left to filter
# 1.20.101.203:34657 is slow
#
# 1046 proxies left to filter
# 124.41.211.82:45024 is slow
#
# 1045 proxies left to filter
# 157.230.210.133:8080 is slow
#
# 1044 proxies left to filter
# 120.237.156.43:8088 is bad
#
# 1043 proxies left to filter
# 138.186.23.3:53281 is bad
#
# 1042 proxies left to filter
# 123.200.1.215:8080 is good
# average conn time: 4.90195264373
#
# 1041 proxies left to filter
# 1.10.189.153:8080 is slow
#
# 1040 proxies left to filter
# 103.111.56.41:8080 is slow
#
# 1039 proxies left to filter
# 157.230.250.11:3128 is slow
#
# 1038 proxies left to filter
# 119.28.31.29:8888 is slow
#
# 1037 proxies left to filter
# 103.240.161.107:57893 is good
# average conn time: 4.88329986009
#
# 1036 proxies left to filter
# 118.174.220.131:56183 is good
# average conn time: 4.8286731508
#
# 1035 proxies left to filter
# 144.217.186.69:8080 is good
# average conn time: 4.73509812355
#
# 1034 proxies left to filter
# 1.10.187.128:57434 is good
# average conn time: 4.80266531478
#
# 1033 proxies left to filter
# 103.76.253.156:3128 is good
# average conn time: 4.74719495078
#
# 1032 proxies left to filter
# 103.23.207.106:8080 is good
# average conn time: 4.73332415795
#
# 1031 proxies left to filter
# 117.191.11.110:8080 is slow
#
# 1030 proxies left to filter
# 103.81.104.89:8080 is slow
#
# 1029 proxies left to filter
# 158.69.104.198:1080 is slow
#
# 1028 proxies left to filter
# 103.79.117.130:8080 is slow
#
# 1027 proxies left to filter
# 151.106.27.210:80 is slow
#
# 1026 proxies left to filter
# 110.78.178.116:8083 is slow
#
# 1025 proxies left to filter
# 1.4.221.131:8080 is slow
#
# 1024 proxies left to filter
# 113.53.83.212:44664 is bad
#
# 1023 proxies left to filter
# 103.86.155.78:60879 is bad
#
# 1022 proxies left to filter
# 116.90.233.2:39086 is slow
#
# 1021 proxies left to filter
# 109.70.189.56:32994 is good
# average conn time: 4.74440211296
#
# 1020 proxies left to filter
# 138.59.80.77:63141 is slow
#
# 1019 proxies left to filter
# 117.191.11.71:80 is slow
#
# 1018 proxies left to filter
# 157.230.140.12:8080 is slow
#
# 1017 proxies left to filter
# 103.78.9.203:8080 is slow
#
# 1016 proxies left to filter
# 118.174.220.38:37972 is good
# average conn time: 4.77040724661
#
# 1015 proxies left to filter
# 112.98.126.100:33421 is slow
#
# 1014 proxies left to filter
# 116.204.155.16:8080 is good
# average conn time: 4.79122335636
#
# 1013 proxies left to filter
# 103.130.70.218:8080 is slow
#
# 1012 proxies left to filter
# 138.186.200.21:8080 is good
# average conn time: 4.77313742098
#
# 1011 proxies left to filter
# 101.71.41.169:443 is slow
#
# 1010 proxies left to filter
# 103.78.74.170:3128 is slow
#
# 1009 proxies left to filter
# 128.199.246.226:8080 is bad
#
# 1008 proxies left to filter
# 110.232.85.168:58211 is slow
#
# 1007 proxies left to filter
# 124.41.243.22:52814 is slow
#
# 1006 proxies left to filter
# 117.191.11.111:80 is slow
#
# 1005 proxies left to filter
# 103.122.255.156:8080 is good
# average conn time: 4.80070281912
#
# 1004 proxies left to filter
# 138.255.36.156:8080 is good
# average conn time: 4.8040230751
#
# 1003 proxies left to filter
# 117.186.214.74:9999 is bad
#
# 1002 proxies left to filter
# 1.20.103.171:57198 is good
# average conn time: 4.84110464794
#
# 1001 proxies left to filter
# 134.119.205.242:8080 is slow
#
# 1000 proxies left to filter
# 144.217.229.155:1080 is slow
#
# 999 proxies left to filter
# 103.207.82.72:8080 is slow
#
# 998 proxies left to filter
# 111.67.92.66:8080 is slow
#
# 997 proxies left to filter
# 103.18.134.38:80 is slow
#
# 996 proxies left to filter
# 103.239.254.27:8080 is good
# average conn time: 4.88441851265
#
# 995 proxies left to filter
# 119.180.134.46:8060 is slow
#
# 994 proxies left to filter
# 157.230.220.233:8080 is slow
#
# 993 proxies left to filter
# 103.14.235.26:8080 is good
# average conn time: 4.89337652305
#
# 992 proxies left to filter
# 103.106.148.200:33781 is slow
#
# 991 proxies left to filter
# 159.138.1.185:80 is slow
#
# 990 proxies left to filter
# 115.254.38.148:80 is slow
#
# 989 proxies left to filter
# 1.20.100.100:40734 is good
# average conn time: 4.8855119883
#
# 988 proxies left to filter
# 103.255.30.34:8080 is bad
#
# 987 proxies left to filter
# 128.199.204.6:31330 is good
# average conn time: 4.84049232403
#
# 986 proxies left to filter
# 101.109.128.155:8080 is slow
#
# 985 proxies left to filter
# 117.206.155.158:8080 is good
# average conn time: 4.81705679659
#
# 984 proxies left to filter
# 118.174.233.102:55819 is good
# average conn time: 4.85587843003
#
# 983 proxies left to filter
# 138.118.225.121:35562 is bad
#
# 982 proxies left to filter
# 109.196.179.6:8080 is bad
#
# 981 proxies left to filter
# 101.4.136.34:8080 is slow
#
# 980 proxies left to filter
# 1.20.97.237:60853 is slow
#
# 979 proxies left to filter
# 109.87.165.132:32247 is good
# average conn time: 4.81413101015
#
# 978 proxies left to filter
# 158.140.182.175:8080 is good
# average conn time: 4.77279032022
#
# 977 proxies left to filter
# 142.93.96.177:80 is slow
#
# 976 proxies left to filter
# 134.236.255.6:54878 is slow
#
# 975 proxies left to filter
# 103.111.29.70:42149 is bad
#
# 974 proxies left to filter
# 1.179.155.93:8080 is good
# average conn time: 4.7427662556
#
# 973 proxies left to filter
# 1.20.100.7:44179 is good
# average conn time: 4.70466461326
#
# 972 proxies left to filter
# 104.248.154.84:1111 is bad
#
# 971 proxies left to filter
# 118.173.232.5:34413 is good
# average conn time: 4.70345009619
#
# 970 proxies left to filter
# 114.143.3.66:80 is slow
#
# 969 proxies left to filter
# 103.10.63.30:53281 is bad
#
# 968 proxies left to filter
# 157.230.57.57:3128 is slow
#
# 967 proxies left to filter
# 1.54.133.245:8080 is slow
#
# 966 proxies left to filter
# 118.174.232.54:31793 is good
# average conn time: 4.71045880107
#
# 965 proxies left to filter
# 104.248.127.187:80 is slow
#
# 964 proxies left to filter
# 115.127.78.122:8080 is slow
#
# 963 proxies left to filter
# 151.106.10.56:1080 is slow
#
# 962 proxies left to filter
# 116.212.129.130:8080 is good
# average conn time: 4.73957966031
#
# 961 proxies left to filter
# 134.119.207.2:8080 is slow
#
# 960 proxies left to filter
# 103.12.161.194:8080 is slow
#
# 959 proxies left to filter
# 117.6.255.171:40834 is good
# average conn time: 4.75159862382
#
# 958 proxies left to filter
# 157.230.43.245:8888 is slow
#
# 957 proxies left to filter
# 101.50.1.2:80 is slow
#
# 956 proxies left to filter
# 109.87.193.112:50944 is bad
#
# 955 proxies left to filter
# 103.3.77.94:55517 is bad
#
# 954 proxies left to filter
# 128.199.235.109:3128 is slow
#
# 953 proxies left to filter
# 124.29.240.142:8080 is slow
#
# 952 proxies left to filter
# 1.2.169.54:35782 is bad
#
# 951 proxies left to filter
# 109.195.23.223:57448 is slow
#
# 950 proxies left to filter
# 119.187.120.118:8060 is slow
#
# 949 proxies left to filter
# 114.108.254.59:8080 is slow
#
# 948 proxies left to filter
# 116.212.157.23:56354 is slow
#
# 947 proxies left to filter
# 115.254.38.147:80 is slow
#
# 946 proxies left to filter
# 119.28.73.207:3128 is bad
#
# 945 proxies left to filter
# 117.191.11.79:80 is slow
#
# 944 proxies left to filter
# 1.20.102.167:30163 is slow
#
# 943 proxies left to filter
# 103.28.227.69:3128 is good
# average conn time: 4.72231943171
#
# 942 proxies left to filter
# 1.54.133.244:8080 is slow
#
# 941 proxies left to filter
# 119.55.87.32:8080 is slow
#
# 940 proxies left to filter
# 142.93.96.177:3128 is slow
#
# 939 proxies left to filter
# 134.119.205.247:1080 is slow
#
# 938 proxies left to filter
# 1.54.133.241:8080 is slow
#
# 937 proxies left to filter
# 113.53.91.17:41117 is bad
#
# 936 proxies left to filter
# 103.88.221.114:45504 is bad
#
# 935 proxies left to filter
# 159.192.249.249:8080 is good
# average conn time: 4.68592618903
#
# 934 proxies left to filter
# 1.20.97.223:33599 is good
# average conn time: 4.69928474622
#
# 933 proxies left to filter
# 128.199.244.126:3128 is bad
#
# 932 proxies left to filter
# 117.80.17.81:8118 is slow
#
# 931 proxies left to filter
# 117.196.233.254:8080 is good
# average conn time: 4.84920787167
# 930 proxies left to filter
# 118.174.232.108:37991 is good
# average conn time: 4.8939997673
#
# 929 proxies left to filter
# 119.18.151.43:80 is slow
#
# 928 proxies left to filter
# 103.214.77.34:8080 is bad
#
# 927 proxies left to filter
# 118.174.232.16:40586 is bad
#
# 926 proxies left to filter
# 117.191.11.102:80 is slow
#
# 925 proxies left to filter
# 128.199.255.226:80 is slow
#
# 924 proxies left to filter
# 110.39.128.90:8080 is good
# average conn time: 4.90543344146
#
# 923 proxies left to filter
# 1.20.99.112:53995 is good
# average conn time: 4.89984474554
#
# 922 proxies left to filter
# 1.20.99.143:52971 is good
# average conn time: 4.88576445518
#
# 921 proxies left to filter
# 104.248.84.77:8080 is bad
#
# 920 proxies left to filter
# 117.2.155.16:9090 is good
# average conn time: 4.88579422009
#
# 919 proxies left to filter
# 119.180.179.71:8060 is slow
#
# 918 proxies left to filter
# 110.44.123.203:8080 is good
# average conn time: 4.91866686642
#
# 917 proxies left to filter
# 125.27.31.75:8080 is slow
#
# 916 proxies left to filter
# 1.55.240.156:53281 is slow
#
# 915 proxies left to filter
# 148.251.52.90:80 is slow
#
# 914 proxies left to filter
# 110.74.199.28:8080 is good
# average conn time: 4.91161669625
#
# 913 proxies left to filter
# 157.230.57.151:80 is slow
#
# 912 proxies left to filter
# 151.106.10.101:8080 is slow
#
# 911 proxies left to filter
# 114.244.66.99:8060 is slow
#
# 910 proxies left to filter
# 110.232.83.117:8080 is slow
#
# 909 proxies left to filter
# 103.107.133.1:33236 is slow
#
# 908 proxies left to filter
# 103.17.38.24:8080 is good
# average conn time: 4.9019648331
#
# 907 proxies left to filter
# 103.106.238.230:50941 is good
# average conn time: 4.87744335381
#
# 906 proxies left to filter
# 114.252.38.124:9999 is slow
#
# 905 proxies left to filter
# 117.244.15.243:3128 is slow
#
# 904 proxies left to filter
# 103.69.90.242:8080 is good
# average conn time: 4.86311195862
#
# 903 proxies left to filter
# 102.164.248.51:63238 is slow
#
# 902 proxies left to filter
# 138.219.229.178:8080 is slow
#
# 901 proxies left to filter
# 138.0.89.212:36158 is good
# average conn time: 4.86613701652
#
# 900 proxies left to filter
# 103.106.114.58:8080 is good
# average conn time: 4.8393580165
#
# 899 proxies left to filter
# 151.106.10.62:1080 is slow
#
# 898 proxies left to filter
# 109.95.255.82:8080 is slow
#
# 897 proxies left to filter
# 114.134.184.216:61904 is slow
#
# 896 proxies left to filter
# 144.217.86.131:3128 is good
# average conn time: 4.78874980992
#
# 895 proxies left to filter
# 1.10.185.8:42106 is slow
#
# 894 proxies left to filter
# 134.119.222.244:8080 is slow
#
# 893 proxies left to filter
# 122.141.110.37:8080 is slow
#
# 892 proxies left to filter
# 103.109.57.218:8080 is good
# average conn time: 4.81231067668
#
# 891 proxies left to filter
# 103.240.161.108:6666 is good
# average conn time: 4.81340873643
#
# 890 proxies left to filter
# 1.10.188.77:56137 is bad
#
# 889 proxies left to filter
# 119.179.147.163:8060 is slow
#
# 888 proxies left to filter
# 103.194.249.251:58228 is slow
#
# 887 proxies left to filter
# 114.202.2.185:80 is good
# average conn time: 4.84572667281
#
# 886 proxies left to filter
# 145.239.87.173:3128 is good
# average conn time: 4.804220962
#
# 885 proxies left to filter
# 110.172.135.234:57399 is bad
#
# 884 proxies left to filter
# 142.93.125.169:80 is slow
#
# 883 proxies left to filter
# 123.117.163.254:9000 is slow
#
# 882 proxies left to filter
# 157.230.227.116:8080 is slow
#
# 881 proxies left to filter
# 151.106.8.235:1080 is slow
#
# 880 proxies left to filter
# 103.194.243.65:47633 is slow
#
# 879 proxies left to filter
# 134.209.122.8:8080 is slow
#
# 878 proxies left to filter
# 103.12.246.10:8080 is good
# average conn time: 4.80253989541
#
# 877 proxies left to filter
# 150.129.57.230:39752 is bad
#
# 876 proxies left to filter
# 114.7.3.234:57479 is good
# average conn time: 4.82333573475
#
# 875 proxies left to filter
# 144.217.69.152:1080 is slow
#
# 874 proxies left to filter
# 145.239.169.46:1080 is slow
#
# 873 proxies left to filter
# 103.194.242.254:60025 is slow
#
# 872 proxies left to filter
# 109.72.52.130:58857 is bad
#
# 871 proxies left to filter
# 1.10.187.43:8080 is good
# average conn time: 4.79627381233
#
# 870 proxies left to filter
# 119.47.91.4:8080 is good
# average conn time: 4.78696965669
#
# 869 proxies left to filter
# 103.216.48.83:8080 is good
# average conn time: 4.7888871183
#
# 868 proxies left to filter
# 114.199.123.194:8080 is good
# average conn time: 4.79504293019
#
# 867 proxies left to filter
# 118.174.233.110:47713 is slow
#
# 866 proxies left to filter
# 116.68.160.114:8080 is bad
#
# 865 proxies left to filter
# 115.85.83.197:8080 is slow
#
# 864 proxies left to filter
# 115.124.85.6:8080 is good
# average conn time: 4.81090408442
#
# 863 proxies left to filter
# 103.116.36.241:44760 is bad
#
# 862 proxies left to filter
# 150.107.205.196:8081 is bad
#
# 861 proxies left to filter
# 117.242.36.240:8080 is slow
#
# 860 proxies left to filter
# 1.20.99.122:8080 is good
# average conn time: 4.78307294123
#
# 859 proxies left to filter
# 128.199.255.38:8080 is good
# average conn time: 4.75619091272
#
# 858 proxies left to filter
# 113.161.173.10:3128 is good
# average conn time: 4.73285934004
#
# 857 proxies left to filter
# 103.231.163.58:45893 is bad
#
# 856 proxies left to filter
# 104.198.232.184:80 is slow
#
# 855 proxies left to filter
# 1.10.187.61:34783 is slow
#
# 854 proxies left to filter
# 103.206.132.154:8080 is slow
#
# 853 proxies left to filter
# 117.191.11.78:80 is slow
#
# 852 proxies left to filter
# 103.47.94.74:8080 is good
# average conn time: 4.7157126595
#
# 851 proxies left to filter
# 103.253.211.182:80 is slow
#
# 850 proxies left to filter
# 103.5.232.146:8080 is good
# average conn time: 4.72412484826
#
# 849 proxies left to filter
# 109.73.181.41:8080 is good
# average conn time: 4.70272988769
#
# 848 proxies left to filter
# 124.248.184.222:8080 is bad
#
# 847 proxies left to filter
# 114.143.3.68:80 is slow
#
# 846 proxies left to filter
# 157.230.227.116:80 is slow
#
# 845 proxies left to filter
# 151.106.10.56:8080 is slow
#
# 844 proxies left to filter
# 110.39.60.2:59786 is slow
#
# 843 proxies left to filter
# 159.192.101.10:80 is good
# average conn time: 4.69687388738
#
# 842 proxies left to filter
# 114.252.209.124:8060 is slow
#
# 841 proxies left to filter
# 110.77.212.92:8080 is slow
#
# 840 proxies left to filter
# 109.224.57.14:41207 is bad
#
# 839 proxies left to filter
# 140.227.73.118:3128 is good
# average conn time: 4.66238080331
#
# 838 proxies left to filter
# 115.124.86.61:8080 is bad
#
# 837 proxies left to filter
# 157.230.232.130:80 is slow
#
# 836 proxies left to filter
# 117.196.229.12:8080 is good
# average conn time: 4.66151917092
#
# 835 proxies left to filter
# 1.20.169.105:8080 is slow
#
# 834 proxies left to filter
# 145.239.169.41:1080 is slow
#
# 833 proxies left to filter
# 114.239.255.78:9999 is slow
#
# 832 proxies left to filter
# 103.79.228.246:31065 is good
# average conn time: 4.70162037346
#
# 831 proxies left to filter
# 100.18.1.21:80 is slow
#
# 830 proxies left to filter
# 159.203.65.214:8080 is good
# average conn time: 4.66064147993
#
# 829 proxies left to filter
# 103.74.227.177:63141 is slow
#
# 828 proxies left to filter
# 119.81.154.168:80 is slow
#
# 827 proxies left to filter
# 103.253.168.99:8080 is bad
#
# 826 proxies left to filter
# 134.209.115.104:80 is slow
#
# 825 proxies left to filter
# 1.20.103.252:32143 is bad
#
# 824 proxies left to filter
# 116.37.58.230:3128 is good
# average conn time: 4.63574204662
#
# 823 proxies left to filter
# 159.65.205.44:8080 is good
# average conn time: 4.60044552399
#
# 822 proxies left to filter
# 118.127.99.93:53281 is slow
#
# 821 proxies left to filter
# 125.209.108.26:39462 is slow
#
# 820 proxies left to filter
# 124.41.240.137:23500 is good
# average conn time: 4.58642152803
#
# 819 proxies left to filter
# 117.2.22.41:41973 is bad
#
# 818 proxies left to filter
# 114.55.103.83:8000 is slow
#
# 817 proxies left to filter
# 144.217.229.154:1080 is slow
#
# 816 proxies left to filter
# 114.240.58.244:8060 is slow
#
# 815 proxies left to filter
# 103.204.231.210:55715 is bad
#
# 814 proxies left to filter
# 112.78.43.227:808 is slow
#
# 813 proxies left to filter
# 109.69.209.75:57012 is bad
#
# 812 proxies left to filter
# 103.108.88.158:51387 is bad
#
# 811 proxies left to filter
# 1.0.184.20:8080 is good
# average conn time: 4.58049861942
#
# 810 proxies left to filter
# 103.205.132.70:8080 is good
# average conn time: 4.58614440341
#
# 809 proxies left to filter
# 1.9.216.226:51405 is bad
#
# 808 proxies left to filter
# 151.106.8.232:1080 is slow
#
# 807 proxies left to filter
# 1.10.187.241:58364 is bad
#
# 806 proxies left to filter
# 101.255.89.237:8080 is bad
# 805 proxies left to filter
# 101.255.116.61:8080 is good
# average conn time: 4.56695102609
#
# 804 proxies left to filter
# 114.130.31.157:44273 is slow
#
# 803 proxies left to filter
# 103.103.88.91:8080 is good
# average conn time: 4.58198274004
#
# 802 proxies left to filter
# 118.99.118.69:8080 is good
# average conn time: 4.61574864795
#
# 801 proxies left to filter
# 125.26.99.186:54193 is good
# average conn time: 4.61213795613
#
# 800 proxies left to filter
# 157.230.106.250:80 is slow
#
# 799 proxies left to filter
# 117.184.67.118:8060 is slow
#
# 798 proxies left to filter
# 138.122.222.64:8080 is good
# average conn time: 4.60747157025
#
# 797 proxies left to filter
# 1.20.103.60:52663 is slow
#
# 796 proxies left to filter
# 117.191.11.112:8080 is slow
#
# 795 proxies left to filter
# 1.20.97.4:52237 is good
# average conn time: 4.63416089018
#
# 794 proxies left to filter
# 119.190.136.247:8060 is slow
#
# 793 proxies left to filter
# 119.15.89.106:8080 is good
# average conn time: 4.63554081641
#
# 792 proxies left to filter
# 103.16.104.18:48142 is good
# average conn time: 4.6488295305
#
# 791 proxies left to filter
# 114.99.13.142:9999 is good
# average conn time: 4.63249275355
#
# 790 proxies left to filter
# 103.216.82.50:53281 is slow
#
# 789 proxies left to filter
# 103.111.81.138:8080 is slow
#
# 788 proxies left to filter
# 1.202.245.84:8080 is slow
#
# 787 proxies left to filter
# 119.39.68.118:808 is good
# average conn time: 4.63716807096
#
# 786 proxies left to filter
# 139.60.176.62:53281 is slow
#
# 785 proxies left to filter
# 116.212.150.71:33973 is bad
#
# 784 proxies left to filter
# 102.129.99.248:8080 is slow
#
# 783 proxies left to filter
# 157.230.57.57:8080 is slow
#
# 782 proxies left to filter
# 109.70.189.70:30480 is good
# average conn time: 4.61309366417
#
# 781 proxies left to filter
# 142.93.202.126:3128 is slow
#
# 780 proxies left to filter
# 102.176.160.75:61149 is slow
#
# 779 proxies left to filter
# 117.58.241.68:8080 is bad
#
# 778 proxies left to filter
# 123.231.251.194:3128 is slow
#
# 777 proxies left to filter
# 114.57.238.1:60424 is good
# average conn time: 4.60964714345
#
# 776 proxies left to filter
# 134.19.218.94:3129 is bad
#
# 775 proxies left to filter
# 114.55.103.83:8089 is slow
#
# 774 proxies left to filter
# 103.111.81.142:54660 is good
# average conn time: 4.6572160627
#
# 773 proxies left to filter
# 134.119.205.174:1080 is good
# average conn time: 4.64180755429
#
# 772 proxies left to filter
# 1.4.198.238:8080 is slow
#
# 771 proxies left to filter
# 118.27.31.97:3128 is good
# average conn time: 4.61464151856
#
# 770 proxies left to filter
# 138.122.108.202:8080 is good
# average conn time: 4.65243634627
#
# 769 proxies left to filter
# 112.78.169.98:36963 is good
# average conn time: 4.65233499221
#
# 768 proxies left to filter
# 103.110.88.9:32345 is slow
#
# 767 proxies left to filter
# 117.149.12.242:8060 is slow
#
# 766 proxies left to filter
# 1.54.133.254:8080 is slow
#
# 765 proxies left to filter
# 103.14.232.22:8080 is good
# average conn time: 4.66274572683
#
# 764 proxies left to filter
# 159.65.89.244:3128 is slow
#
# 763 proxies left to filter
# 117.191.11.109:8080 is slow
#
# 762 proxies left to filter
# 157.230.210.133:80 is slow
#
# 761 proxies left to filter
# 138.255.156.20:8080 is bad
#
# 760 proxies left to filter
# 103.15.245.26:8080 is slow
#
# 759 proxies left to filter
# 157.230.55.134:80 is slow
#
# 758 proxies left to filter
# 134.119.207.4:1080 is slow
#
# 757 proxies left to filter
# 116.209.62.35:8082 is slow
#
# 756 proxies left to filter
# 134.209.115.104:8080 is slow
#
# 755 proxies left to filter
# 115.78.13.133:8080 is bad
#
# 754 proxies left to filter
# 117.2.121.41:8080 is good
# average conn time: 4.64800135354
#
# 753 proxies left to filter
# 138.36.1.128:50501 is good
# average conn time: 4.62406657525
#
# 752 proxies left to filter
# 121.54.164.139:8080 is good
# average conn time: 4.61196399265
#
# 751 proxies left to filter
# 102.176.160.70:61279 is slow
#
# 750 proxies left to filter
# 158.69.138.8:1080 is slow
#
# 749 proxies left to filter
# 1.20.99.104:37003 is slow
#
# 748 proxies left to filter
# 138.219.178.44:8080 is good
# average conn time: 4.61170747175
#
# 747 proxies left to filter
# 103.239.254.234:53281 is slow
#
# 746 proxies left to filter
# 103.89.253.249:3128 is bad
#
# 745 proxies left to filter
# 149.3.91.202:3128 is good
# average conn time: 4.60949266392
#
# 744 proxies left to filter
# 158.69.138.9:1080 is slow
#
# 743 proxies left to filter
# 103.111.56.190:56524 is slow
#
# 742 proxies left to filter
# 144.76.189.74:8080 is slow
#
# 741 proxies left to filter
# 118.174.220.138:48071 is good
# average conn time: 4.60912294146
#
# 740 proxies left to filter
# 125.26.56.213:8080 is slow
#
# 739 proxies left to filter
# 1.54.133.242:8080 is bad
#
# 738 proxies left to filter
# 1.179.143.53:32477 is good
# average conn time: 4.61947684837
#
# 737 proxies left to filter
# 143.255.7.67:8080 is good
# average conn time: 4.6103994063
#
# 736 proxies left to filter
# 1.54.133.249:8080 is slow
#
# 735 proxies left to filter
# 138.122.7.33:32192 is bad
#
# 734 proxies left to filter
# 138.97.219.201:8080 is good
# average conn time: 4.59617475753
#
# 733 proxies left to filter
# 157.230.251.25:8080 is good
# average conn time: 4.57896354836
#
# 732 proxies left to filter
# 159.192.217.194:8080 is slow
#
# 731 proxies left to filter
# 112.85.165.105:9999 is slow
#
# 730 proxies left to filter
# 14.102.94.38:8080 is good
# average conn time: 4.57179938997
#
# 729 proxies left to filter
# 113.53.230.167:80 is slow
#
# 728 proxies left to filter
# 152.204.128.46:56895 is good
# average conn time: 4.59230474134
#
# 727 proxies left to filter
# 1.20.99.139:32458 is good
# average conn time: 4.57759237125
#
# 726 proxies left to filter
# 103.230.35.222:3128 is good
# average conn time: 4.56711914278
#
# 725 proxies left to filter
# 109.188.80.79:33392 is bad
#
# 724 proxies left to filter
# 138.121.155.127:61932 is good
# average conn time: 4.55451250887
#
# 723 proxies left to filter
# 114.245.218.112:8060 is slow
#
# 722 proxies left to filter
# 146.82.236.133:55478 is slow
#
# 721 proxies left to filter
# 110.74.196.229:443 is slow
#
# 720 proxies left to filter
# 118.113.14.123:8080 is slow
#
# 719 proxies left to filter
# 109.69.1.172:58002 is good
# average conn time: 4.53257204552
#
# 718 proxies left to filter
# 118.172.201.169:40782 is good
# average conn time: 4.52246721959
#
# 717 proxies left to filter
# 117.206.83.198:52071 is good
# average conn time: 4.51887610594
#
# 716 proxies left to filter
# 103.47.93.102:8080 is slow
#
# 715 proxies left to filter
# 103.255.148.26:61865 is bad
#
# 714 proxies left to filter
# 1.20.97.216:39363 is bad
#
# 713 proxies left to filter
# 110.34.192.12:1080 is slow
#
# 712 proxies left to filter
# 103.19.110.177:8080 is good
# average conn time: 4.53183811864
#
# 711 proxies left to filter
# 114.248.6.240:8060 is slow
#
# 710 proxies left to filter
# 103.110.88.64:48803 is slow
#
# 709 proxies left to filter
# 1.20.103.105:50480 is bad
#
# 708 proxies left to filter
# 103.82.127.4:8080 is good
# average conn time: 4.55884449262
#
# 707 proxies left to filter
# 122.138.16.143:8080 is slow
#
# 706 proxies left to filter
# 124.41.240.226:8080 is good
# average conn time: 4.57034088895
#
# 705 proxies left to filter
# 149.129.118.65:80 is slow
#
# 704 proxies left to filter
# 138.68.174.231:8080 is slow
#
# 703 proxies left to filter
# 1.20.99.32:55064 is bad
#
# 702 proxies left to filter
# 128.201.77.110:8080 is bad
#
# 701 proxies left to filter
# 120.79.246.9:808 is good
# average conn time: 4.61462492757
#
# 700 proxies left to filter
# 157.230.253.14:8080 is good
# average conn time: 4.60718198592
#
# 699 proxies left to filter
# 103.111.53.82:44495 is slow
#
# 698 proxies left to filter
# 103.106.158.252:8080 is slow
#
# 697 proxies left to filter
# 103.77.169.242:80 is slow
#
# 696 proxies left to filter
# 101.109.255.18:56783 is good
# average conn time: 4.60584097948
#
# 695 proxies left to filter
# 118.174.196.39:52226 is slow
#
# 694 proxies left to filter
# 1.20.169.105:80 is slow
#
# 693 proxies left to filter
# 1.186.40.157:54754 is bad
#
# 692 proxies left to filter
# 119.180.178.231:8060 is slow
#
# 691 proxies left to filter
# 124.81.238.244:53281 is slow
#
# 690 proxies left to filter
# 117.102.94.148:51712 is slow
#
# 689 proxies left to filter
# 113.161.197.139:45075 is slow
#
# 688 proxies left to filter
# 134.35.120.219:8080 is slow
#
# 687 proxies left to filter
# 138.197.180.57:3128 is good
# average conn time: 4.58116714514
#
# 686 proxies left to filter
# 134.119.207.11:1080 is slow
#
# 685 proxies left to filter
# 103.16.63.90:38831 is slow
#
# 684 proxies left to filter
# 151.106.8.238:1080 is slow
#
# 683 proxies left to filter
# 103.100.96.174:53281 is slow
#
# 682 proxies left to filter
# 124.124.99.210:3128 is good
# average conn time: 4.56758116921
#
# 681 proxies left to filter
# 116.196.81.58:3128 is slow
#
# 680 proxies left to filter
# 116.58.232.251:80 is slow
#
# 679 proxies left to filter
# 118.173.232.98:39598 is slow
#
# 678 proxies left to filter
# 103.21.160.156:48710 is bad
#
# 677 proxies left to filter
# 119.235.19.42:38546 is bad
#
# 676 proxies left to filter
# 114.55.103.83:9090 is slow
#
# 675 proxies left to filter
# 114.244.212.139:8060 is slow
#
# 674 proxies left to filter
# 115.223.85.198:8060 is slow
#
# 673 proxies left to filter
# 119.179.172.125:8060 is slow
#
# 672 proxies left to filter
# 119.93.152.192:49889 is slow
#
# 671 proxies left to filter
# 118.172.227.89:55425 is bad
#
# 670 proxies left to filter
# 1.10.189.5:34218 is bad
#
# 669 proxies left to filter
# 103.196.233.199:8080 is bad
#
# 668 proxies left to filter
# 159.203.65.214:3128 is good
# average conn time: 4.54033367739
#
# 667 proxies left to filter
# 134.119.222.245:1080 is slow
#
# 666 proxies left to filter
# 119.54.53.174:80 is slow
#
# 665 proxies left to filter
# 138.186.60.238:8080 is slow
#
# 664 proxies left to filter
# 103.218.100.134:8080 is good
# average conn time: 4.52946545482
#
# 663 proxies left to filter
# 151.106.8.228:1080 is slow
#
# 662 proxies left to filter
# 117.196.235.199:63141 is slow
#
# 661 proxies left to filter
# 103.221.254.2:53390 is slow
#
# 660 proxies left to filter
# 142.93.125.169:8080 is slow
#
# 659 proxies left to filter
# 1.228.244.47:443 is good
# average conn time: 4.51686194224
#
# 658 proxies left to filter
# 117.139.126.236:53281 is good
# average conn time: 4.51348739936
#
# 657 proxies left to filter
# 103.106.148.207:51451 is slow
#
# 656 proxies left to filter
# 118.172.201.45:34670 is bad
#
# 655 proxies left to filter
# 117.191.11.111:8080 is slow
#
# 654 proxies left to filter
# 101.109.245.154:50816 is bad
#
# 653 proxies left to filter
# 103.117.232.77:8080 is good
# average conn time: 4.5349803673
#
# 652 proxies left to filter
# 128.199.244.126:8000 is slow
#
# 651 proxies left to filter
# 1.10.186.167:51907 is good
# average conn time: 4.55494770044
#
# 650 proxies left to filter
# 125.209.78.21:8080 is good
# average conn time: 4.55062469136
#
# 649 proxies left to filter
# 115.124.75.77:52928 is slow
#
# 648 proxies left to filter
# 117.191.11.101:80 is slow
#
# 647 proxies left to filter
# 150.107.205.146:8081 is slow
#
# 646 proxies left to filter
# 110.74.221.18:49743 is slow
#
# 645 proxies left to filter
# 124.158.171.18:8080 is good
# average conn time: 4.57658659694
#
# 644 proxies left to filter
# 124.41.214.113:8080 is slow
#
# 643 proxies left to filter
# 103.233.145.133:8080 is good
# average conn time: 4.56491146116
#
# 642 proxies left to filter
# 119.28.203.242:8000 is slow
#
# 641 proxies left to filter
# 103.114.11.9:8080 is slow
#
# 640 proxies left to filter
# 137.59.161.46:8080 is good
# average conn time: 4.56283512002
#
# 639 proxies left to filter
# 101.108.132.107:8080 is slow
#
# 638 proxies left to filter
# 103.226.49.110:8080 is slow
#
# 637 proxies left to filter
# 111.223.75.178:8080 is slow
#
# 636 proxies left to filter
# 103.16.60.146:8080 is good
# average conn time: 4.55653591128
#
# 635 proxies left to filter
# 110.78.168.223:80 is slow
#
# 634 proxies left to filter
# 125.26.202.54:80 is good
# average conn time: 4.54127032897
#
# 633 proxies left to filter
# 134.119.207.6:1080 is slow
#
# 632 proxies left to filter
# 148.103.9.41:37584 is good
# average conn time: 4.53545173567
#
# 631 proxies left to filter
# 134.119.222.252:8080 is slow
#
# 630 proxies left to filter
# 119.190.34.70:80 is slow
#
# 629 proxies left to filter
# 14.102.32.162:8080 is good
# average conn time: 4.56254164424
#
# 628 proxies left to filter
# 109.194.2.126:61822 is slow
#
# 627 proxies left to filter
# 117.252.69.153:8080 is slow
#
# 626 proxies left to filter
# 103.111.83.122:3128 is good
# average conn time: 4.58811167623
#
# 625 proxies left to filter
# 157.230.157.60:80 is slow
#
# 624 proxies left to filter
# 117.191.11.109:80 is slow
#
# 623 proxies left to filter
# 122.22.90.218:8080 is slow
#
# 622 proxies left to filter
# 103.212.128.82:8080 is slow
#
# 621 proxies left to filter
# 113.161.207.99:60626 is slow
#
# 620 proxies left to filter
# 114.4.240.106:8080 is good
# average conn time: 4.62535490798
#
# 619 proxies left to filter
# 124.40.252.138:80 is good
# average conn time: 4.65277359418
#
# 618 proxies left to filter
# 117.191.11.106:80 is slow
#
# 617 proxies left to filter
# 103.239.145.109:32807 is good
# average conn time: 4.66519621015
#
# 616 proxies left to filter
# 128.199.242.231:8080 is good
# average conn time: 4.64683458226
#
# 615 proxies left to filter
# 119.97.237.74:80 is slow
#
# 614 proxies left to filter
# 103.233.145.236:8080 is good
# average conn time: 4.63637794404
#
# 613 proxies left to filter
# 134.209.33.104:8080 is slow
#
# 612 proxies left to filter
# 151.106.10.105:8080 is slow
#
# 611 proxies left to filter
# 110.232.83.115:8080 is slow
#
# 610 proxies left to filter
# 144.48.111.26:53281 is slow
#
# 609 proxies left to filter
# 103.221.254.44:56471 is slow
#
# 608 proxies left to filter
# 159.65.128.131:8080 is good
# average conn time: 4.62177462018
#
# 607 proxies left to filter
# 103.109.111.150:46240 is bad
#
# 606 proxies left to filter
# 110.74.221.169:59124 is good
# average conn time: 4.64436073965
#
# 605 proxies left to filter
# 103.111.55.58:8080 is slow
#
# 604 proxies left to filter
# 102.176.160.57:8080 is good
# average conn time: 4.63752023818
#
# 603 proxies left to filter
# 120.236.130.132:8060 is slow
#
# 602 proxies left to filter
# 157.230.236.97:8080 is slow
#
# 601 proxies left to filter
# 134.119.214.205:8080 is slow
#
# 600 proxies left to filter
# 113.78.255.12:9000 is slow
#
# 599 proxies left to filter
# 150.109.61.203:8080 is good
# average conn time: 4.62234112195
#
# 598 proxies left to filter
# 134.119.222.243:1080 is slow
#
# 597 proxies left to filter
# 120.29.124.131:8080 is bad
#
# 596 proxies left to filter
# 159.138.5.222:80 is slow
#
# 595 proxies left to filter
# 151.106.10.99:8080 is slow
#
# 594 proxies left to filter
# 111.125.85.158:8080 is good
# average conn time: 4.61158487575
#
# 593 proxies left to filter
# 101.51.141.115:44765 is good
# average conn time: 4.61495994096
#
# 592 proxies left to filter
# 128.199.98.7:8080 is good
# average conn time: 4.62457048184
#
# 591 proxies left to filter
# 1.20.102.19:55118 is slow
#
# 590 proxies left to filter
# 104.222.110.66:23500 is slow
#
# 589 proxies left to filter
# 114.143.3.71:80 is slow
#
# 588 proxies left to filter
# 103.199.131.78:8080 is good
# average conn time: 4.63030212925
#
# 587 proxies left to filter
# 125.62.213.18:82 is good
# average conn time: 4.62673203193
#
# 586 proxies left to filter
# 103.254.185.195:53281 is good
# average conn time: 4.6136766279
#
# 585 proxies left to filter
# 124.41.211.177:44265 is slow
#
# 584 proxies left to filter
# 117.191.11.107:80 is slow
#
# 583 proxies left to filter
# 103.122.90.118:8080 is slow
#
# 582 proxies left to filter
# 104.248.51.244:8080 is slow
#
# 581 proxies left to filter
# 101.255.58.225:61598 is bad
#
# 580 proxies left to filter
# 125.26.99.108:31810 is good
# average conn time: 4.60345150806
#
# 579 proxies left to filter
# 118.174.196.216:33100 is slow
#
# 578 proxies left to filter
# 103.232.242.190:56178 is slow
#
# 577 proxies left to filter
# 119.110.75.50:8080 is slow
#
# 576 proxies left to filter
# 151.106.10.61:8080 is slow
#
# 575 proxies left to filter
# 103.122.66.235:8080 is good
# average conn time: 4.59506416823
#
# 574 proxies left to filter
# 134.119.205.171:1080 is slow
#
# 573 proxies left to filter
# 103.239.145.121:8080 is slow
#
# 572 proxies left to filter
# 138.117.115.149:8080 is good
# average conn time: 4.58915534569
#
# 571 proxies left to filter
# 1.186.242.20:39098 is good
# average conn time: 4.59135789548
#
# 570 proxies left to filter
# 1.20.100.18:55348 is bad
#
# 569 proxies left to filter
# 14.139.58.53:9797 is slow
#
# 568 proxies left to filter
# 145.239.169.45:1080 is slow
#
# 567 proxies left to filter
# 119.180.132.249:8060 is slow
#
# 566 proxies left to filter
# 125.27.179.88:36127 is slow
#
# 565 proxies left to filter
# 123.161.23.45:9797 is good
# average conn time: 4.59088596902
#
# 564 proxies left to filter
# 134.209.115.104:3128 is slow
#
# 563 proxies left to filter
# 110.39.10.115:8080 is good
# average conn time: 4.60154943859
#
# 562 proxies left to filter
# 103.216.48.81:8080 is good
# average conn time: 4.6124542004
#
# 561 proxies left to filter
# 103.105.40.161:16538 is slow
#
# 560 proxies left to filter
# 125.26.7.115:30012 is good
# average conn time: 4.62176031726
#
# 559 proxies left to filter
# 112.17.177.33:8060 is slow
#
# 558 proxies left to filter
# 101.51.141.106:59932 is bad
#
# 557 proxies left to filter
# 151.106.10.50:8080 is bad
#
# 556 proxies left to filter
# 113.227.182.15:8118 is slow
#
# 555 proxies left to filter
# 151.106.8.229:1080 is slow
#
# 554 proxies left to filter
# 157.230.43.245:8000 is bad
#
# 553 proxies left to filter
# 109.188.64.248:47893 is slow
#
# 552 proxies left to filter
# 117.191.11.74:8080 is slow
#
# 551 proxies left to filter
# 158.69.104.194:1080 is slow
#
# 550 proxies left to filter
# 151.106.8.233:1080 is slow
#
# 549 proxies left to filter
# 117.158.189.238:9999 is slow
#
# 548 proxies left to filter
# 1.20.99.23:54067 is slow
#
# 547 proxies left to filter
# 1.54.133.251:8080 is slow
#
# 546 proxies left to filter
# 157.230.55.134:8080 is slow
#
# 545 proxies left to filter
# 103.240.109.109:3128 is good
# average conn time: 4.61342660546
#
# 544 proxies left to filter
# 103.116.87.21:8080 is slow
#
# 543 proxies left to filter
# 116.214.27.96:8080 is good
# average conn time: 4.61418971871
#
# 542 proxies left to filter
# 138.186.22.117:8080 is bad
#
# 541 proxies left to filter
# 134.209.41.247:8080 is slow
#
# 540 proxies left to filter
# 115.78.160.247:8080 is good
# average conn time: 4.6116438511
#
# 539 proxies left to filter
# 115.254.38.144:80 is slow
#
# 538 proxies left to filter
# 103.103.33.166:8080 is slow
#
# 537 proxies left to filter
# 1.20.102.87:8080 is slow
#
# 536 proxies left to filter
# 151.106.10.58:1080 is slow
#
# 535 proxies left to filter
# 134.209.125.125:3128 is slow
#
# 534 proxies left to filter
# 139.59.45.210:8080 is good
# average conn time: 4.60039258599
#
# 533 proxies left to filter
# 114.67.229.212:8080 is slow
#
# 532 proxies left to filter
# 109.245.234.1:8080 is good
# average conn time: 4.60308257857
#
# 531 proxies left to filter
# 103.108.146.43:23500 is slow
#
# 530 proxies left to filter
# 158.46.86.19:8081 is slow
#
# 529 proxies left to filter
# 110.77.232.222:3128 is slow
#
# 528 proxies left to filter
# 117.102.92.221:8080 is slow
#
# 527 proxies left to filter
# 125.26.99.149:56359 is slow
#
# 526 proxies left to filter
# 1.54.133.250:8080 is slow
#
# 525 proxies left to filter
# 125.162.44.139:3128 is good
# average conn time: 4.59318030353
#
# 524 proxies left to filter
# 117.191.11.103:8080 is slow
#
# 523 proxies left to filter
# 1.54.133.240:8080 is slow
#
# 522 proxies left to filter
# 103.10.81.138:80 is slow
#
# 521 proxies left to filter
# 103.235.199.46:31611 is slow
#
# 520 proxies left to filter
# 1.2.169.12:47678 is good
# average conn time: 4.60158364174
#
# 519 proxies left to filter
# 124.41.240.205:36752 is slow
#
# 518 proxies left to filter
# 101.109.116.104:8080 is slow
#
# 517 proxies left to filter
# 124.225.223.101:80 is slow
#
# 516 proxies left to filter
# 1.10.189.166:49880 is good
# average conn time: 4.60540888941
#
# 515 proxies left to filter
# 157.230.232.130:8080 is slow
#
# 514 proxies left to filter
# 138.204.48.233:8080 is good
# average conn time: 4.61664639217
#
# 513 proxies left to filter
# 134.119.214.194:8080 is slow
#
# 512 proxies left to filter
# 101.255.120.170:6969 is good
# average conn time: 4.61626168131
#
# 511 proxies left to filter
# 103.194.251.43:42892 is slow
#
# 510 proxies left to filter
# 120.29.125.97:32431 is good
# average conn time: 4.63755438293
#
# 509 proxies left to filter
# 114.69.229.161:8080 is bad
#
# 508 proxies left to filter
# 1.54.133.247:8080 is bad
#
# 507 proxies left to filter
# 102.177.194.26:59042 is bad
#
# 506 proxies left to filter
# 117.7.230.113:443 is slow
#
# 505 proxies left to filter
# 1.10.187.13:51064 is good
# average conn time: 4.63662391901
#
# 504 proxies left to filter
# 101.51.191.147:8080 is slow
#
# 503 proxies left to filter
# 148.72.23.193:80 is slow
#
# 502 proxies left to filter
# 103.216.50.157:8080 is bad
#
# 501 proxies left to filter
# 117.255.222.34:8080 is good
# average conn time: 4.63143861693
#
# 500 proxies left to filter
# 101.255.115.41:8080 is good
# average conn time: 4.6434378851
#
# 499 proxies left to filter
# 157.230.159.32:80 is slow
#
# 498 proxies left to filter
# 125.167.177.164:8080 is good
# average conn time: 4.64198112714
#
# 497 proxies left to filter
# 119.2.41.29:8080 is slow
#
# 496 proxies left to filter
# 151.106.10.102:8080 is slow
#
# 495 proxies left to filter
# 103.88.234.251:44320 is bad
#
# 494 proxies left to filter
# 125.26.109.129:37625 is slow
#
# 493 proxies left to filter
# 125.208.136.146:8181 is slow
#
# 492 proxies left to filter
# 134.119.214.204:1080 is slow
#
# 491 proxies left to filter
# 134.209.15.143:3128 is slow
#
# 490 proxies left to filter
# 113.252.222.73:8380 is slow
#
# 489 proxies left to filter
# 103.112.128.6:53281 is good
# average conn time: 4.65616738121
#
# 488 proxies left to filter
# 1.32.57.81:58556 is good
# average conn time: 4.64838254844
#
# 487 proxies left to filter
# 101.255.121.168:8888 is slow
#
# 486 proxies left to filter
# 134.119.222.246:1080 is slow
#
# 485 proxies left to filter
# 14.207.7.41:8080 is slow
#
# 484 proxies left to filter
# 138.94.132.145:8080 is slow
#
# 483 proxies left to filter
# 138.185.22.130:8080 is good
# average conn time: 4.65441555509
#
# 482 proxies left to filter
# 154.72.79.37:23500 is slow
#
# 481 proxies left to filter
# 134.119.205.248:8080 is slow
#
# 480 proxies left to filter
# 103.250.166.4:44472 is good
# average conn time: 4.64676179886
#
# 479 proxies left to filter
# 125.62.213.33:84 is slow
#
# 478 proxies left to filter
# 116.209.54.22:9999 is slow
#
# 477 proxies left to filter
# 119.42.76.191:8080 is good
# average conn time: 4.65088224411
#
# 476 proxies left to filter
# 103.105.68.124:45146 is slow
#
# 475 proxies left to filter
# 103.255.30.34:3128 is bad
#
# 474 proxies left to filter
# 103.22.248.59:57296 is slow
#
# 473 proxies left to filter
# 103.224.37.129:8080 is good
# average conn time: 4.65737309104
#
# 472 proxies left to filter
# 1.20.101.121:31946 is good
# average conn time: 4.66478713171
#
# 471 proxies left to filter
# 138.117.4.45:80 is slow
#
# 470 proxies left to filter
# 103.87.16.2:80 is slow
#
# 469 proxies left to filter
# 143.0.109.18:3128 is good
# average conn time: 4.66441035488
#
# 468 proxies left to filter
# 123.200.14.238:8080 is good
# average conn time: 4.67163790356
#
# 467 proxies left to filter
# 103.206.130.118:8080 is good
# average conn time: 4.66179071832
#
# 466 proxies left to filter
# 121.46.95.27:8080 is slow
#
# 465 proxies left to filter
# 103.105.238.1:32883 is slow
#
# 464 proxies left to filter
# 117.7.230.113:8080 is bad
#
# 463 proxies left to filter
# 124.41.211.231:58637 is bad
#
# 462 proxies left to filter
# 1.10.187.232:36819 is slow
#
# 461 proxies left to filter
# 138.0.89.144:32715 is slow
#
# 460 proxies left to filter
# 138.186.23.5:46098 is slow
#
# 459 proxies left to filter
# 119.188.171.32:8081 is slow
#
# 458 proxies left to filter
# 103.254.59.50:8080 is good
# average conn time: 4.66094014237
#
# 457 proxies left to filter
# 114.119.116.92:61066 is bad
#
# 456 proxies left to filter
# 103.209.81.138:8080 is good
# average conn time: 4.65257005627
#
# 455 proxies left to filter
# 1.20.102.116:8080 is good
# average conn time: 4.65414680966
#
# 454 proxies left to filter
# 117.245.130.82:8080 is good
# average conn time: 4.66022226016
#
# 453 proxies left to filter
# 159.138.22.112:80 is slow
#
# 452 proxies left to filter
# 122.144.4.94:8080 is good
# average conn time: 4.65254303312
#
# 451 proxies left to filter
# ...
#
# 242 proxies left to filter
# 150.107.205.22:32080 is good
# average conn time: 4.66928937411
#
# 241 proxies left to filter
# 1.54.133.246:8080 is slow
#
# 240 proxies left to filter
# 151.106.8.234:1080 is slow
#
# 239 proxies left to filter
# 103.240.161.109:6666 is good
# average conn time: 4.66332218517
#
# 238 proxies left to filter
# 138.219.228.113:8080 is slow
#
# 237 proxies left to filter
# 151.106.8.231:1080 is slow
#
# 236 proxies left to filter
# 138.0.89.189:51285 is slow
#
# 235 proxies left to filter
# 120.210.219.102:80 is slow
#
# 234 proxies left to filter
# 117.191.11.76:8080 is slow
#
# 233 proxies left to filter
# 103.212.128.1:52390 is good
# average conn time: 4.66738512718
#
# 232 proxies left to filter
# 118.175.207.84:8080 is good
# average conn time: 4.65867780592
#
# 231 proxies left to filter
# 103.119.54.48:8080 is slow
#
# 230 proxies left to filter
# 110.39.166.146:8080 is good
# average conn time: 4.66648503265
#
# 229 proxies left to filter
# 125.209.115.186:8080 is slow
#
# 228 proxies left to filter
# 118.174.220.36:33234 is bad
#
# 227 proxies left to filter
# 1.10.188.78:45208 is slow
#
# 226 proxies left to filter
# 103.99.177.247:80 is slow
#
# 225 proxies left to filter
# 157.230.57.151:8080 is slow
#
# 224 proxies left to filter
# 102.141.67.16:8080 is slow
#
# 223 proxies left to filter
# 101.109.255.48:42015 is good
# average conn time: 4.67991935167
#
# 222 proxies left to filter
# 138.121.32.133:23492 is bad
#
# 221 proxies left to filter
# 132.148.150.41:80 is slow
#
# 220 proxies left to filter
# 103.250.158.227:23500 is slow
#
# 219 proxies left to filter
# 101.51.106.70:51946 is slow
#
# 218 proxies left to filter
# 101.51.141.46:37858 is bad
#
# 217 proxies left to filter
# 103.119.144.215:8080 is slow
#
# 216 proxies left to filter
# 1.54.133.248:8080 is slow
#
# 215 proxies left to filter
# 158.58.132.12:56962 is bad
#
# 214 proxies left to filter
# 1.10.189.64:56253 is slow
#
# 213 proxies left to filter
# 109.238.222.5:52157 is bad
#
# 212 proxies left to filter
# 157.230.243.143:8080 is slow
#
# 211 proxies left to filter
# 101.109.44.39:8080 is good
# average conn time: 4.67695445361
#
# 210 proxies left to filter
# 103.194.251.42:47477 is slow
#
# 209 proxies left to filter
# 134.236.247.137:8080 is good
# average conn time: 4.6690729626
#
# 208 proxies left to filter
# 138.122.51.101:30247 is bad
#
# 207 proxies left to filter
# 101.108.156.223:8080 is good
# average conn time: 4.68177428515
#
# 206 proxies left to filter
# 119.161.99.25:83 is good
# average conn time: 4.68945372184
#
# 205 proxies left to filter
# 1.20.103.196:42792 is slow
#
# 204 proxies left to filter
# 1.10.187.221:33042 is slow
#
# 203 proxies left to filter
# 120.234.63.196:3128 is slow
#
# 202 proxies left to filter
# 114.199.115.46:40431 is good
# average conn time: 4.69368042568
#
# 201 proxies left to filter
# 138.201.72.117:80 is slow
#
# 200 proxies left to filter
# 114.7.163.78:8080 is good
# average conn time: 4.71447988168
#
# 199 proxies left to filter
# 103.28.87.69:8080 is good
# average conn time: 4.71207196126
#
# 198 proxies left to filter
# 144.217.68.210:1080 is slow
#
# 197 proxies left to filter
# 158.69.138.12:1080 is slow
#
# 196 proxies left to filter
# 144.217.229.158:1080 is slow
#
# 195 proxies left to filter
# 103.224.48.17:8080 is good
# average conn time: 4.71623262471
#
# 194 proxies left to filter
# 113.166.127.60:8080 is good
# average conn time: 4.70888239475
#
# 193 proxies left to filter
# 144.172.116.158:3128 is slow
#
# 192 proxies left to filter
# 110.74.199.16:63141 is slow
#
# 191 proxies left to filter
# 103.224.186.20:58133 is slow
#
# 190 proxies left to filter
# 149.202.121.231:8082 is slow
#
# 189 proxies left to filter
# 103.106.119.154:8080 is good
# average conn time: 4.71750083217
#
# 188 proxies left to filter
# 157.230.94.149:8080 is good
# average conn time: 4.70301452887
#
# 187 proxies left to filter
# 101.255.85.114:80 is good
# average conn time: 4.69404014003
#
# 186 proxies left to filter
# 116.212.128.146:8080 is good
# average conn time: 4.69033850351
#
# 185 proxies left to filter
# 118.99.96.59:8080 is good
# average conn time: 4.69554127485
#
# 184 proxies left to filter
# 159.138.21.170:80 is slow
# 183 proxies left to filter
# 117.191.11.103:80 is slow
#
# 182 proxies left to filter
# 103.101.233.13:8080 is good
# average conn time: 4.71045530947
#
# 181 proxies left to filter
# 139.99.209.69:80 is slow
#
# 180 proxies left to filter
# 110.164.58.103:30543 is bad
#
# 179 proxies left to filter
# 103.225.222.73:8080 is good
# average conn time: 4.71588749643
#
# 178 proxies left to filter
# 138.59.148.61:8080 is slow
#
# 177 proxies left to filter
# 103.194.90.178:44487 is bad
#
# 176 proxies left to filter
# 1.20.101.110:59949 is bad
#
# 175 proxies left to filter
# 144.76.82.111:3128 is good
# average conn time: 4.70335503154
#
# 174 proxies left to filter
# 103.29.144.117:8080 is slow
#
# 173 proxies left to filter
# 119.180.168.170:8060 is slow
#
# 172 proxies left to filter
# 103.255.145.146:82 is slow
#
# 171 proxies left to filter
# 121.140.126.250:3128 is slow
#
# 170 proxies left to filter
# 111.67.97.35:36251 is slow
#
# 169 proxies left to filter
# 144.217.229.157:1080 is slow
#
# 168 proxies left to filter
# 115.124.72.166:60346 is slow
#
# 167 proxies left to filter
# 134.119.207.8:8080 is slow
#
# 166 proxies left to filter
# 103.102.73.72:8080 is slow
#
# 165 proxies left to filter
# 14.207.102.103:8080 is good
# average conn time: 4.71148719893
#
# 164 proxies left to filter
# 1.0.135.251:8080 is slow
#
# 163 proxies left to filter
# 101.109.83.194:8080 is bad
#
# 162 proxies left to filter
# 114.143.3.64:80 is slow
#
# 161 proxies left to filter
# 143.106.73.29:80 is slow
#
# 160 proxies left to filter
# 103.110.43.3:44255 is good
# average conn time: 4.71412533089
#
# 159 proxies left to filter
# 119.252.163.66:443 is slow
#
# 158 proxies left to filter
# 103.73.224.196:8080 is good
# average conn time: 4.71831931408
#
# 157 proxies left to filter
# 1.20.100.93:34926 is bad
#
# 156 proxies left to filter
# 101.255.120.249:48667 is slow
#
# 155 proxies left to filter
# 103.216.169.253:8080 is slow
#
# 154 proxies left to filter
# 103.76.50.182:8080 is good
# average conn time: 4.71642665131
#
# 153 proxies left to filter
# 103.1.94.213:53281 is good
# average conn time: 4.72992054597
#
# 152 proxies left to filter
# 119.179.151.220:8060 is slow
#
# 151 proxies left to filter
# 116.214.24.120:8080 is good
# average conn time: 4.72973831346
#
# 150 proxies left to filter
# 138.68.174.231:80 is slow
#
# 149 proxies left to filter
# 103.115.180.242:40625 is slow
#
# 148 proxies left to filter
# 143.255.40.30:63141 is bad
#
# 147 proxies left to filter
# 157.230.157.60:8080 is slow
#
# 146 proxies left to filter
# 120.210.219.101:8080 is slow
#
# 145 proxies left to filter
# 103.215.27.162:44896 is good
# average conn time: 4.73038801421
#
# 144 proxies left to filter
# 103.5.125.153:8080 is good
# average conn time: 4.72729181874
#
# 143 proxies left to filter
# 103.235.66.166:8080 is slow
#
# 142 proxies left to filter
# 114.33.189.29:41697 is bad
#
# 141 proxies left to filter
# 157.230.45.121:1111 is bad
#
# 140 proxies left to filter
# 144.76.45.24:8080 is good
# average conn time: 4.71499013754
#
# 139 proxies left to filter
# 101.255.125.10:8080 is bad
#
# 138 proxies left to filter
# 138.197.102.119:80 is slow
#
# 137 proxies left to filter
# 111.59.90.238:80 is bad
#
# 136 proxies left to filter
# 103.25.167.200:33575 is good
# average conn time: 4.72643496147
#
# 135 proxies left to filter
# 110.49.11.50:8080 is good
# average conn time: 4.72097945506
#
# 134 proxies left to filter
# 146.0.120.200:53281 is bad
#
# 133 proxies left to filter
# 117.191.11.72:8080 is slow
#
# 132 proxies left to filter
# 159.203.11.15:8080 is slow
#
# 131 proxies left to filter
# 117.2.121.203:8080 is good
# average conn time: 4.71936510462
#
# 130 proxies left to filter
# 1.0.133.78:8080 is slow
#
# 129 proxies left to filter
# 103.105.67.244:8080 is slow
#
# 128 proxies left to filter
# 110.138.58.6:8080 is good
# average conn time: 4.71493057434
#
# 127 proxies left to filter
# 103.98.79.42:46525 is slow
#
# 126 proxies left to filter
# 123.1.170.138:3128 is slow
#
# 125 proxies left to filter
# 117.191.11.108:80 is slow
#
# 124 proxies left to filter
# 117.191.11.105:80 is slow
#
# 123 proxies left to filter
# 113.65.160.41:808 is slow
#
# 122 proxies left to filter
# 103.250.152.62:36664 is good
# average conn time: 4.71918418342
#
# 121 proxies left to filter
# 1.54.133.243:8080 is slow
#
# 120 proxies left to filter
# 144.217.229.159:1080 is slow
#
# 119 proxies left to filter
# 119.252.168.53:53281 is slow
#
# 118 proxies left to filter
# 134.249.231.78:8080 is good
# average conn time: 4.71518063473
#
# 117 proxies left to filter
# 103.246.2.246:8080 is good
# average conn time: 4.71468908261
#
# 116 proxies left to filter
# 117.191.11.74:80 is slow
#
# 115 proxies left to filter
# 128.199.255.226:3128 is slow
#
# 114 proxies left to filter
# 101.109.252.80:8081 is good
# average conn time: 4.72297770862
#
# 113 proxies left to filter
# 134.209.209.76:8080 is slow
#
# 112 proxies left to filter
# 119.76.141.107:8080 is slow
#
# 111 proxies left to filter
# 1.0.133.212:8080 is good
# average conn time: 4.71572936476
#
# 110 proxies left to filter
# 103.111.55.142:30559 is bad
#
# 109 proxies left to filter
# 118.175.244.21:8080 is good
# average conn time: 4.70812552204
#
# 108 proxies left to filter
# 119.15.91.226:8080 is good
# average conn time: 4.71183387272
#
# 107 proxies left to filter
# 134.119.205.173:1080 is slow
#
# 106 proxies left to filter
# 115.124.75.6:8080 is good
# average conn time: 4.71136734315
#
# 105 proxies left to filter
# 104.155.103.87:80 is slow
#
# 104 proxies left to filter
# 114.143.3.67:80 is slow
#
# 103 proxies left to filter
# 118.172.201.94:40418 is good
# average conn time: 4.70740802139
#
# 102 proxies left to filter
# 124.41.211.211:40031 is slow
#
# 101 proxies left to filter
# 1.10.189.100:50169 is good
# average conn time: 4.70980238209
#
# 100 proxies left to filter
# 117.206.151.195:8080 is slow
#
# 99 proxies left to filter
# 149.56.99.222:80 is slow
#
# 98 proxies left to filter
# 118.173.80.186:8080 is slow
#
# 97 proxies left to filter
# 103.119.145.38:80 is good
# average conn time: 4.72062172018
#
# 96 proxies left to filter
# 102.177.105.34:3128 is good
# average conn time: 4.71935042984
#
# 95 proxies left to filter
# 142.93.216.200:80 is slow
#
# 94 proxies left to filter
# 128.199.80.51:8080 is slow
#
# 93 proxies left to filter
# 150.129.124.42:8080 is good
# average conn time: 4.72843075148
#
# 92 proxies left to filter
# 1.54.133.252:8080 is slow
#
# 91 proxies left to filter
# 151.106.8.235:8080 is slow
#
# 90 proxies left to filter
# 117.191.11.76:80 is slow
#
# 89 proxies left to filter
# 103.89.152.85:8080 is bad
#
# 88 proxies left to filter
# 134.209.119.225:8080 is good
# average conn time: 4.71545050367
#
# 87 proxies left to filter
# 138.117.84.22:8080 is slow
#
# 86 proxies left to filter
# 103.87.48.57:8080 is slow
#
# 85 proxies left to filter
# 103.252.184.25:53281 is good
# average conn time: 4.72536940269
#
# 84 proxies left to filter
# 138.197.10.18:80 is slow
#
# 83 proxies left to filter
# 117.254.60.118:8080 is good
# average conn time: 4.73210089013
#
# 82 proxies left to filter
# 109.92.140.250:53281 is bad
#
# 81 proxies left to filter
# 1.10.187.60:55266 is bad
#
# 80 proxies left to filter
# 110.232.89.202:3128 is slow
#
# 79 proxies left to filter
# 109.24.192.25:3128 is good
# average conn time: 4.72115428206
#
# 78 proxies left to filter
# 118.174.220.133:50616 is bad
#
# 77 proxies left to filter
# 103.217.109.118:60793 is bad
#
# 76 proxies left to filter
# 138.0.204.122:41496 is bad
#
# 75 proxies left to filter
# 1.20.100.231:57337 is good
# average conn time: 4.71343571189
#
# 74 proxies left to filter
# 103.24.107.2:8181 is good
# average conn time: 4.7232731591
#
# 73 proxies left to filter
# 103.74.244.177:43033 is good
# average conn time: 4.73366453524
#
# 72 proxies left to filter
# 103.102.12.52:8080 is slow
#
# 71 proxies left to filter
# 155.0.180.254:44649 is bad
#
# 70 proxies left to filter
# 117.191.11.113:8080 is slow
#
# 69 proxies left to filter
# 103.49.30.40:8080 is good
# average conn time: 4.74163865087
#
# 68 proxies left to filter
# 138.0.229.209:33611 is good
# average conn time: 4.73300155163
#
# 67 proxies left to filter
# 134.209.123.111:8080 is slow
#
# 66 proxies left to filter
# 1.20.100.165:61085 is slow
#
# 65 proxies left to filter
# 103.28.56.182:49519 is slow
#
# 64 proxies left to filter
# 157.119.118.122:45178 is bad
#
# 63 proxies left to filter
# 159.65.92.98:8080 is good
# average conn time: 4.72158443894
#
# 62 proxies left to filter
# 119.82.252.90:33367 is bad
#
# 61 proxies left to filter
# 119.2.41.10:8080 is slow
#
# 60 proxies left to filter
# 115.79.31.73:8080 is good
# average conn time: 4.72677043216
#
# 59 proxies left to filter
# 139.255.25.106:80 is slow
#
# 58 proxies left to filter
# 103.210.141.31:8080 is bad
#
# 57 proxies left to filter
# 101.231.104.82:80 is slow
#
# 56 proxies left to filter
# 157.230.44.168:8080 is good
# average conn time: 4.71935377378
#
# 55 proxies left to filter
# 150.109.55.190:83 is slow
#
# 54 proxies left to filter
# 103.247.122.38:8080 is slow
#
# 53 proxies left to filter
# 110.137.115.144:8080 is good
# average conn time: 4.71380601226
#
# 52 proxies left to filter
# 1.10.189.141:33933 is good
# average conn time: 4.71268942658
#
# 51 proxies left to filter
# 158.69.104.199:1080 is slow
#
# 50 proxies left to filter
# 103.226.203.42:34668 is slow
#
# 49 proxies left to filter
# 116.209.54.115:9999 is slow
#
# 48 proxies left to filter
# 157.230.163.11:80 is slow
#
# 47 proxies left to filter
# 113.130.126.228:35869 is bad
#
# 46 proxies left to filter
# 115.178.27.125:8080 is bad
#
# 45 proxies left to filter
# 116.212.148.42:8080 is good
# average conn time: 4.71166223756
#
# 44 proxies left to filter
# 113.200.214.164:9999 is good
# average conn time: 4.71228302961
#
# 43 proxies left to filter
# 138.59.33.43:63141 is bad
#
# 42 proxies left to filter
# 118.174.220.58:60547 is good
# average conn time: 4.70953659372
#
# 41 proxies left to filter
# 158.69.59.171:3128 is good
# average conn time: 4.69754919103
#
# 40 proxies left to filter
# 1.20.101.201:45863 is slow
#
# 39 proxies left to filter
# 159.65.229.150:8080 is good
# average conn time: 4.68909219305
#
# 38 proxies left to filter
# 144.217.229.156:1080 is slow
#
# 37 proxies left to filter
# 114.108.181.130:33378 is slow
#
# 36 proxies left to filter
# 125.26.99.185:34600 is good
# average conn time: 4.69772746953
#
# 35 proxies left to filter
# 134.119.222.246:8080 is slow
#
# 34 proxies left to filter
# 138.197.10.18:8080 is slow
#
# 33 proxies left to filter
# 148.72.209.119:80 is good
# average conn time: 4.69616646793
#
# 32 proxies left to filter
# 109.248.249.25:8081 is slow
#
# 31 proxies left to filter
# 101.255.40.18:47966 is good
# average conn time: 4.69902915009
#
# 30 proxies left to filter
# 103.9.188.219:32861 is bad
#
# 29 proxies left to filter
# 139.255.31.146:8080 is slow
#
# 28 proxies left to filter
# 118.175.93.93:40976 is good
# average conn time: 4.69645800695
#
# 27 proxies left to filter
# 1.20.102.113:8080 is good
# average conn time: 4.70246365364
#
# 26 proxies left to filter
# 138.219.229.247:8080 is slow
#
# 25 proxies left to filter
# 101.255.121.105:8080 is slow
#
# 24 proxies left to filter
# 124.108.51.89:8080 is slow
#
# 23 proxies left to filter
# 114.129.17.52:9191 is good
# average conn time: 4.71127821188
#
# 22 proxies left to filter
# 103.111.56.60:53281 is slow
#
# 21 proxies left to filter
# 118.175.207.218:8080 is bad
#
# 20 proxies left to filter
# 120.210.219.104:80 is slow
#
# 19 proxies left to filter
# 1.20.100.195:61802 is good
# average conn time: 4.7151610455
#
# 18 proxies left to filter
# 111.125.143.174:47233 is good
# average conn time: 4.71514082538
#
# 17 proxies left to filter
# 137.74.254.242:3128 is slow
#
# 16 proxies left to filter
# 1.20.101.175:58741 is bad
#
# 15 proxies left to filter
# 1.20.217.221:8080 is slow
#
# 14 proxies left to filter
# 118.143.215.239:80 is good
# average conn time: 4.70999093107
#
# 13 proxies left to filter
# 134.119.207.10:1080 is bad
#
# 12 proxies left to filter
# 119.192.179.46:54192 is bad
#
# 11 proxies left to filter
# 103.74.220.47:43678 is good
# average conn time: 4.71380073895
#
# 10 proxies left to filter
# 119.179.182.110:8060 is slow
#
# 9 proxies left to filter
# 134.119.222.251:8080 is bad
#
# 8 proxies left to filter
# 139.194.82.145:8080 is good
# average conn time: 4.72040451826
#
# 7 proxies left to filter
# 103.120.152.182:59068 is slow
#
# 6 proxies left to filter
# 159.203.11.15:80 is slow
#
# 5 proxies left to filter
# 138.197.208.221:8080 is bad
#
# 4 proxies left to filter
# 158.69.138.15:1080 is slow
#
# 3 proxies left to filter
# 118.175.207.38:8080 is good
# average conn time: 4.71893136668
#
# 2 proxies left to filter
# 151.106.10.52:8080 is slow
#
# 1 proxies left to filter
# 134.119.214.204:8080 is slow
#
# average proxy time:4.71893136668

# %% [markdown]
# # Filter the Http proxies

# %%
url = 'https://www.proxy-list.download/HTTP'
filterProxys(url)

# %% [markdown]
# # Overwrite the source text file with partially filtered or empty ip list

# %%
# overwrite the existing source of https proxy data with the filtered data
with open('proxyLists/https_proxys_part_0.txt', "w") as output:
    for line in testProxies['https']:
        output.write("%s\n" % line)

# %%
# overwrite the existing source of http proxy data with the filtered data
with open('proxyLists/http_proxys_part_0.txt', "w") as output:
    for line in testProxies['http']:
        output.write("%s\n" % line)

# %% [markdown]
# # Get all proxys that had connections times less than one second

# %%
df = pd.DataFrame(goodProxy['https'])
fast_proxies_https = list(df['proxy'][df['time']<1])

# %%
df = pd.DataFrame(goodProxy['http'])
fast_proxies_http = list(df['proxy'][df['time']<1])

# %% [markdown]
# # Import the single filtered files of proxys that had connections times less than one second and combine with the new filtered proxys

# %%
# Import
try:
    existing_https_proxies = list(pd.read_csv('../filtered_https_proxys.txt', header = None)[0])
except: #If the file is empty
    existing_https_proxies = []
try:
    existing_http_proxies = list(pd.read_csv('../filtered_http_proxys.txt', header = None)[0])
except: #If the file is empty
    existing_http_proxies = []

# %%
# add the new proxys to the existing ones if they are not already there
[existing_https_proxies.append(x) 
 for x in fast_proxies_https 
 if x not in existing_https_proxies]

[existing_http_proxies.append(x) 
 for x in fast_proxies_http 
 if x not in existing_http_proxies]
# Out:
# []

# %% [markdown]
# # Rewrite the final proxys text file with the new and old filtered proxies

# %%
#append filtered http proxys to existing .txt file
with open('../filtered_http_proxys.txt', "w") as output:
    for line in existing_http_proxies:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('../filtered_https_proxys.txt', "w") as output:
    for line in existing_https_proxies:
        output.write("%s\n" % line)
