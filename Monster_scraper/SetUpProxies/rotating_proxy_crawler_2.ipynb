# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from fake_useragent import UserAgent
import random

# %% [markdown]
# # Import the Data

# %%
try:
    Https_txt_file = 'proxyLists/https_proxys_part_2.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
    https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
    #Convert to array
    https_proxys = https_proxys[0].values
    #Convert to list
    https_proxys = list(https_proxys)
except:
    print('There are no https proxies to import')

try:
    Http_txt_file = 'proxyLists/http_proxys_part_2.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
    http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
    #Convert to array
    http_proxys = http_proxys[0].values
    #Convert to list
    http_proxys = list(http_proxys)
except:
    print('There are no http proxies to import')

# %%
# Make a dictionary for the proxies to test
testProxies = {'https':https_proxys,'http':http_proxys}

# %%
# Retrieve a random user-agent
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndex(conn_type):
    num = random.randint(0, len(testProxies[conn_type]) - 1)
    return num

# %%
proxyDict = {}
def randProx(conn_type):
    # Choose a single random proxy to use
    proxy_index = randomIndex(conn_type)
    proxy = testProxies[conn_type][proxy_index]
    proxyDict[conn_type] = conn_type +'://'+ proxy
    return proxy_index

# %%
# Initialize Dictionary for good proxies 
good_http_proxy = []
good_https_proxy = []
conn_time_http = []
conn_time_https = []
goodProxy = {'https':{'proxy':good_https_proxy,'time':conn_time_https},
             'http':{'proxy':good_http_proxy,'time':conn_time_http}}

# %%
def filterProxys(url):
    timer = 0
    count = 0
    if url[0:5] == 'http:':
        conn_type = 'http'
        
    elif url[0:5] == 'https':
        conn_type = 'https'

    total_proxies = len(testProxies[conn_type])
    for n in range(len(testProxies[conn_type])):
        time.sleep(1)
        print(str(total_proxies-n)+' proxies left to filter')
            
        try:
            # Choose a random header
            randHeader()
            
        except:
            # Sometimes the header reassignment function returns an error
            pass
            
        # Choose a random proxy
        proxy_index = randProx(conn_type)

        try:
            # Try to connect to the url
            t1 = time.time()
            soup = requests.get(url,headers=header,proxies=proxyDict,timeout=5)
            t2 = time.time()
            t = t2-t1
                
            if  str(soup) == '<Response [200]>': # the connection is successful when <Response [200]> is returned
                print(str(testProxies[conn_type][proxy_index])+' is good')
                del testProxies[conn_type][proxy_index]
                timer += t
                count += 1
                print('average conn time: '+str(timer/count)+'\n')
                #Add to the good proxy and its connection time
                goodProxy[conn_type]['proxy'].append(proxyDict[conn_type])
                goodProxy[conn_type]['time'].append(t)
                    
            elif str(soup) != '<Response [200]>': #The connection was bad
                print(str(testProxies[conn_type][proxy_index])+' is bad'+'\n')
                del testProxies[conn_type][proxy_index]
                    
                    
        except: # The connection took too long 
            print(str(testProxies[conn_type][proxy_index])+' is slow'+'\n')
            del testProxies[conn_type][proxy_index]
    try:
        print('average proxy time:'+str(timer/count))
    except:
        print('No proxies to text')

# %% [markdown]
# # Filter the Https proxies

# %%
url = 'https://www.proxy-list.download/HTTPS'
filterProxys(url)
# Out:
# 1180 proxies left to filter
# 5.17.161.134:8080 is slow
#
# 1179 proxies left to filter
# 49.204.80.158:8080 is slow
#
# 1178 proxies left to filter
# 203.177.169.90:30395 is bad
#
# 1177 proxies left to filter
# 203.107.135.123:80 is slow
#
# 1176 proxies left to filter
# 5.58.56.109:34242 is slow
#
# 1175 proxies left to filter
# 31.24.90.213:53281 is good
# average conn time: 6.06722187996
#
# 1174 proxies left to filter
# 45.119.82.88:80 is slow
#
# 1173 proxies left to filter
# 35.211.128.210:80 is good
# average conn time: 3.39979588985
#
# 1172 proxies left to filter
# 95.131.91.130:33523 is good
# average conn time: 4.25519220034
#
# 1171 proxies left to filter
# 80.99.19.213:8080 is good
# average conn time: 3.87100714445
#
# 1170 proxies left to filter
# 54.39.147.31:8080 is slow
#
# 1169 proxies left to filter
# 94.179.130.34:43902 is bad
#
# 1168 proxies left to filter
# 35.229.113.175:443 is good
# average conn time: 3.26363329887
#
# 1167 proxies left to filter
# 36.91.28.98:8080 is slow
#
# 1166 proxies left to filter
# 35.246.195.132:80 is slow
#
# 1165 proxies left to filter
# 36.255.87.250:82 is good
# average conn time: 3.69577924411
#
# 1164 proxies left to filter
# 59.91.127.29:53844 is slow
#
# 1163 proxies left to filter
# 31.31.107.248:53281 is good
# average conn time: 3.89638590813
#
# 1162 proxies left to filter
# 95.0.219.198:23500 is good
# average conn time: 3.65823316574
#
# 1161 proxies left to filter
# 80.211.234.18:3128 is slow
#
# 1160 proxies left to filter
# 27.147.255.12:32589 is good
# average conn time: 4.00025693576
#
# 1159 proxies left to filter
# 36.67.8.27:53281 is slow
#
# 1158 proxies left to filter
# 43.252.158.21:56595 is slow
#
# 1157 proxies left to filter
# 36.89.183.77:37586 is slow
#
# 1156 proxies left to filter
# 40.76.78.215:80 is slow
#
# 1155 proxies left to filter
# 213.14.32.75:54575 is good
# average conn time: 3.96752934456
#
# 1154 proxies left to filter
# 89.186.1.215:53281 is slow
#
# 1153 proxies left to filter
# 5.56.103.45:49132 is slow
#
# 1152 proxies left to filter
# 77.120.163.23:55060 is good
# average conn time: 4.36208612269
#
# 1151 proxies left to filter
# 219.166.174.194:80 is slow
#
# 1150 proxies left to filter
# 27.147.143.186:43380 is good
# average conn time: 4.45486768087
#
# 1149 proxies left to filter
# 89.29.100.240:3128 is bad
#
# 1148 proxies left to filter
# 80.232.240.198:8080 is good
# average conn time: 4.24629616737
#
# 1147 proxies left to filter
# 212.3.210.61:37344 is slow
#
# 1146 proxies left to filter
# 45.166.65.169:8080 is good
# average conn time: 4.44158966201
#
# 1145 proxies left to filter
# 220.175.133.119:8060 is slow
#
# 1144 proxies left to filter
# 5.58.167.211:42341 is bad
#
# 1143 proxies left to filter
# 203.150.243.246:8080 is good
# average conn time: 4.66362908681
#
# 1142 proxies left to filter
# 27.158.162.193:53281 is slow
#
# 1141 proxies left to filter
# 90.157.19.31:8081 is slow
#
# 1140 proxies left to filter
# 77.95.96.168:80 is slow
#
# 1139 proxies left to filter
# 202.51.181.82:8080 is good
# average conn time: 4.63479483128
#
# 1138 proxies left to filter
# 54.36.44.248:1080 is slow
#
# 1137 proxies left to filter
# 5.140.233.249:59800 is bad
#
# 1136 proxies left to filter
# 61.118.35.94:55725 is bad
#
# 1135 proxies left to filter
# 54.36.44.255:1080 is slow
#
# 1134 proxies left to filter
# 5.58.85.32:43214 is bad
#
# 1133 proxies left to filter
# 94.130.126.87:80 is good
# average conn time: 4.43903031069
#
# 1132 proxies left to filter
# 41.139.184.250:8080 is good
# average conn time: 4.56722184022
#
# 1131 proxies left to filter
# 212.129.5.216:54321 is slow
#
# 1130 proxies left to filter
# 197.234.55.145:8083 is slow
#
# 1129 proxies left to filter
# 212.2.204.181:32713 is good
# average conn time: 4.54891174718
#
# 1128 proxies left to filter
# 223.25.111.4:8181 is good
# average conn time: 4.56940921545
#
# 1127 proxies left to filter
# 91.202.72.105:8080 is slow
#
# 1126 proxies left to filter
# 203.80.170.130:8080 is slow
#
# 1125 proxies left to filter
# 79.104.28.46:35405 is good
# average conn time: 4.44808953149
#
# 1124 proxies left to filter
# 93.41.192.228:32409 is slow
#
# 1123 proxies left to filter
# 95.87.14.3:34731 is slow
#
# 1122 proxies left to filter
# 49.0.36.134:8080 is slow
#
# 1121 proxies left to filter
# 37.145.73.119:50110 is slow
#
# 1120 proxies left to filter
# 95.65.1.200:58768 is good
# average conn time: 4.37751900066
#
# 1119 proxies left to filter
# 36.66.206.74:8080 is slow
#
# 1118 proxies left to filter
# 83.168.86.169:8090 is bad
#
# 1117 proxies left to filter
# 94.249.222.200:8080 is good
# average conn time: 4.31107178978
#
# 1116 proxies left to filter
# 51.77.211.175:3128 is slow
#
# 1115 proxies left to filter
# 91.185.21.124:8123 is good
# average conn time: 4.33003575603
#
# 1114 proxies left to filter
# 89.107.136.146:47138 is good
# average conn time: 4.24818180084
#
# 1113 proxies left to filter
# 80.38.223.240:80 is slow
#
# 1112 proxies left to filter
# 79.106.162.194:45962 is good
# average conn time: 4.35088534539
#
# 1111 proxies left to filter
# 202.62.47.200:23500 is good
# average conn time: 4.39189633617
#
# 1110 proxies left to filter
# 36.37.114.40:41454 is slow
#
# 1109 proxies left to filter
# 49.173.19.134:443 is good
# average conn time: 4.31419321469
#
# 1108 proxies left to filter
# 202.84.79.11:35020 is bad
#
# 1107 proxies left to filter
# 36.72.128.15:8083 is good
# average conn time: 4.48771859037
#
# 1106 proxies left to filter
# 77.95.96.173:80 is slow
#
# 1105 proxies left to filter
# 213.63.134.210:39873 is bad
#
# 1104 proxies left to filter
# 46.72.131.251:8081 is slow
#
# 1103 proxies left to filter
# 206.189.117.237:8080 is good
# average conn time: 4.37317376932
#
# 1102 proxies left to filter
# 45.123.109.149:8080 is slow
#
# 1101 proxies left to filter
# 200.77.176.138:63141 is slow
#
# 1100 proxies left to filter
# 36.67.196.105:8080 is good
# average conn time: 4.47912296941
#
# 1099 proxies left to filter
# 78.186.140.120:38072 is slow
#
# 1098 proxies left to filter
# 47.74.46.193:3128 is good
# average conn time: 4.39637438208
#
# 1097 proxies left to filter
# 92.241.234.141:33647 is good
# average conn time: 4.33848906286
#
# 1096 proxies left to filter
# 37.235.65.76:8080 is slow
#
# 1095 proxies left to filter
# 221.126.249.101:8080 is bad
#
# 1094 proxies left to filter
# 213.168.37.86:8080 is good
# average conn time: 4.36130597311
#
# 1093 proxies left to filter
# 80.211.36.44:8080 is slow
#
# 1092 proxies left to filter
# 222.222.250.143:8060 is slow
#
# 1091 proxies left to filter
# 213.178.38.246:34511 is slow
#
# 1090 proxies left to filter
# 217.173.18.238:8080 is good
# average conn time: 4.40678294046
#
# 1089 proxies left to filter
# 35.212.158.132:80 is good
# average conn time: 4.3105050789
#
# 1088 proxies left to filter
# 27.116.51.119:8080 is good
# average conn time: 4.35316983429
#
# 1087 proxies left to filter
# 217.78.5.57:3128 is good
# average conn time: 4.26774285969
#
# 1086 proxies left to filter
# 27.37.108.28:80 is slow
#
# 1085 proxies left to filter
# 5.10.86.242:3128 is slow
#
# 1084 proxies left to filter
# 5.141.86.233:48149 is bad
#
# 1083 proxies left to filter
# 216.169.73.65:34981 is bad
#
# 1082 proxies left to filter
# 92.247.151.174:59284 is slow
#
# 1081 proxies left to filter
# 200.105.170.52:42886 is bad
#
# 1080 proxies left to filter
# 213.21.23.98:53281 is slow
#
# 1079 proxies left to filter
# 202.79.34.167:48646 is good
# average conn time: 4.33878147908
#
# 1078 proxies left to filter
# 36.71.249.212:8080 is good
# average conn time: 4.3093626678
#
# 1077 proxies left to filter
# 36.91.212.199:8080 is good
# average conn time: 4.34802499632
#
# 1076 proxies left to filter
# 79.120.16.38:41240 is slow
#
# 1075 proxies left to filter
# 5.63.154.215:80 is slow
#
# 1074 proxies left to filter
# 50.195.207.133:47593 is bad
#
# 1073 proxies left to filter
# 87.140.92.161:34693 is slow
#
# 1072 proxies left to filter
# 35.209.254.16:80 is good
# average conn time: 4.25901985168
#
# 1071 proxies left to filter
# 91.121.166.208:80 is slow
#
# 1070 proxies left to filter
# 36.255.87.232:82 is bad
#
# 1069 proxies left to filter
# 84.22.59.74:8080 is slow
#
# 1068 proxies left to filter
# 51.255.115.231:1080 is slow
#
# 1067 proxies left to filter
# 24.248.207.7:53281 is good
# average conn time: 4.42604434213
#
# 1066 proxies left to filter
# 51.38.101.215:3128 is slow
#
# 1065 proxies left to filter
# 46.40.3.115:8082 is slow
#
# 1064 proxies left to filter
# 45.160.145.201:8080 is good
# average conn time: 4.48886647008
#
# 1063 proxies left to filter
# 43.224.8.114:50333 is slow
#
# 1062 proxies left to filter
# 212.205.149.211:50276 is slow
#
# 1061 proxies left to filter
# 51.158.123.154:80 is good
# average conn time: 4.47688303524
#
# 1060 proxies left to filter
# 5.135.71.160:80 is slow
#
# 1059 proxies left to filter
# 222.124.173.147:53281 is slow
#
# 1058 proxies left to filter
# 35.155.132.170:80 is slow
#
# 1057 proxies left to filter
# 41.216.230.148:40609 is slow
#
# 1056 proxies left to filter
# 95.154.73.122:31664 is bad
#
# 1055 proxies left to filter
# 213.6.144.70:8080 is slow
#
# 1054 proxies left to filter
# 5.231.205.174:8080 is slow
#
# 1053 proxies left to filter
# 222.93.65.168:8118 is slow
#
# 1052 proxies left to filter
# 203.84.141.105:3333 is good
# average conn time: 4.58959016593
#
# 1051 proxies left to filter
# 34.80.102.113:3128 is good
# average conn time: 4.535789647
#
# 1050 proxies left to filter
# 46.241.120.230:33516 is slow
#
# 1049 proxies left to filter
# 45.64.99.151:3128 is slow
#
# 1048 proxies left to filter
# 94.55.161.67:8080 is slow
#
# 1047 proxies left to filter
# 221.141.130.183:33741 is good
# average conn time: 4.63355475664
#
# 1046 proxies left to filter
# 45.250.226.21:8080 is slow
#
# 1045 proxies left to filter
# 36.89.17.27:3128 is good
# average conn time: 4.67676553434
#
# 1044 proxies left to filter
# 45.120.116.247:52678 is slow
#
# 1043 proxies left to filter
# 35.188.131.123:80 is slow
#
# 1042 proxies left to filter
# 95.67.100.105:42675 is good
# average conn time: 4.60725068092
#
# 1041 proxies left to filter
# 221.120.163.253:42764 is slow
#
# 1040 proxies left to filter
# 51.15.110.96:8080 is slow
#
# 1039 proxies left to filter
# 27.208.89.71:8060 is slow
#
# 1038 proxies left to filter
# 206.189.152.96:31330 is good
# average conn time: 4.56800511772
#
# 1037 proxies left to filter
# 41.75.211.202:45500 is bad
#
# 1036 proxies left to filter
# 5.148.128.44:80 is good
# average conn time: 4.59229394106
#
# 1035 proxies left to filter
# 203.189.133.5:30225 is slow
#
# 1034 proxies left to filter
# 36.255.87.238:82 is good
# average conn time: 4.71426235955
#
# 1033 proxies left to filter
# 36.255.87.237:83 is good
# average conn time: 4.77156883257
#
# 1032 proxies left to filter
# 51.68.199.130:3128 is good
# average conn time: 4.69872593013
#
# 1031 proxies left to filter
# 49.128.170.110:49146 is bad
#
# 1030 proxies left to filter
# 94.242.59.135:10010 is good
# average conn time: 4.63293984532
#
# 1029 proxies left to filter
# 213.184.225.102:8080 is good
# average conn time: 4.57374577773
#
# 1028 proxies left to filter
# 36.67.93.220:3128 is good
# average conn time: 4.54699817608
#
# 1027 proxies left to filter
# 35.196.186.229:80 is slow
#
# 1026 proxies left to filter
# 36.71.69.1:3128 is good
# average conn time: 4.5692830894
#
# 1025 proxies left to filter
# 213.163.181.33:80 is slow
#
# 1024 proxies left to filter
# 203.107.135.120:80 is slow
#
# 1023 proxies left to filter
# 36.72.130.49:80 is slow
#
# 1022 proxies left to filter
# 94.189.138.101:42401 is good
# average conn time: 4.5694675525
#
# 1021 proxies left to filter
# 45.231.213.110:47421 is good
# average conn time: 4.59627174159
#
# 1020 proxies left to filter
# 36.73.197.160:8080 is good
# average conn time: 4.57928700216
#
# 1019 proxies left to filter
# 213.222.244.150:34425 is bad
#
# 1018 proxies left to filter
# 80.78.70.29:8080 is good
# average conn time: 4.61507190598
#
# 1017 proxies left to filter
# 213.198.241.6:8080 is slow
#
# 1016 proxies left to filter
# 61.14.229.122:32940 is bad
#
# 1015 proxies left to filter
# 94.143.172.37:8080 is slow
#
# 1014 proxies left to filter
# 51.77.202.89:80 is slow
#
# 1013 proxies left to filter
# 77.95.96.175:80 is slow
#
# 1012 proxies left to filter
# 202.72.233.18:8080 is good
# average conn time: 4.6317060478
#
# 1011 proxies left to filter
# 204.48.18.225:8080 is good
# average conn time: 4.56452475328
#
# 1010 proxies left to filter
# 203.189.136.224:8080 is slow
#
# 1009 proxies left to filter
# 91.211.122.94:46406 is slow
#
# 1008 proxies left to filter
# 36.67.197.54:3128 is good
# average conn time: 4.54359983314
#
# 1007 proxies left to filter
# 45.112.56.2:46224 is good
# average conn time: 4.56239573279
#
# 1006 proxies left to filter
# 46.16.225.236:8080 is good
# average conn time: 4.54387107667
#
# 1005 proxies left to filter
# 79.98.212.14:3128 is good
# average conn time: 4.55168720605
#
# 1004 proxies left to filter
# 78.140.201.226:8090 is good
# average conn time: 4.50725467546
#
# 1003 proxies left to filter
# 77.72.38.22:8080 is slow
#
# 1002 proxies left to filter
# 222.222.153.171:808 is bad
#
# 1001 proxies left to filter
# 37.252.77.92:8080 is slow
#
# 1000 proxies left to filter
# 35.222.53.115:3128 is good
# average conn time: 4.47142036868
#
# 999 proxies left to filter
# 83.13.205.178:8080 is slow
#
# 998 proxies left to filter
# 39.137.107.98:80 is slow
#
# 997 proxies left to filter
# 212.119.229.18:33852 is bad
#
# 996 proxies left to filter
# 91.144.20.192:8080 is slow
#
# 995 proxies left to filter
# 213.32.70.223:8000 is slow
#
# 994 proxies left to filter
# 49.156.32.108:8080 is slow
#
# 993 proxies left to filter
# 222.165.195.75:55949 is bad
#
# 992 proxies left to filter
# 35.210.203.226:80 is good
# average conn time: 4.42057973809
#
# 991 proxies left to filter
# 51.254.50.238:8080 is good
# average conn time: 4.37204211052
#
# 990 proxies left to filter
# 221.6.32.214:41816 is bad
#
# 989 proxies left to filter
# 46.231.12.250:30249 is good
# average conn time: 4.38265441882
#
# 988 proxies left to filter
# 41.134.42.10:53281 is good
# average conn time: 4.44766813278
#
# 987 proxies left to filter
# 36.67.24.109:63141 is good
# average conn time: 4.49214316983
#
# 986 proxies left to filter
# 36.67.32.249:8080 is bad
#
# 985 proxies left to filter
# 37.232.13.78:8080 is good
# average conn time: 4.4582613753
#
# 984 proxies left to filter
# 202.51.68.16:8080 is slow
#
# 983 proxies left to filter
# 80.78.75.59:45483 is slow
#
# 982 proxies left to filter
# 94.177.240.64:8080 is slow
#
# 981 proxies left to filter
# 212.237.124.15:31318 is bad
#
# 980 proxies left to filter
# 31.128.101.55:36642 is slow
#
# 979 proxies left to filter
# 45.248.138.150:8080 is slow
#
# 978 proxies left to filter
# 31.132.145.19:8081 is slow
#
# 977 proxies left to filter
# 201.71.45.217:8080 is good
# average conn time: 4.46878781991
#
# 976 proxies left to filter
# 37.194.50.174:8080 is good
# average conn time: 4.470666822
#
# 975 proxies left to filter
# 89.191.14.102:51318 is bad
#
# 974 proxies left to filter
# 213.163.49.223:47779 is bad
#
# 973 proxies left to filter
# 203.150.128.114:8080 is good
# average conn time: 4.50804719925
#
# 972 proxies left to filter
# 41.164.41.138:8080 is good
# average conn time: 4.56186109708
#
# 971 proxies left to filter
# 31.15.88.122:59300 is slow
#
# 970 proxies left to filter
# 80.211.66.190:80 is good
# average conn time: 4.51796626463
#
# 969 proxies left to filter
# 41.139.147.34:8080 is slow
#
# 968 proxies left to filter
# 93.190.139.155:8080 is slow
#
# 967 proxies left to filter
# 221.206.100.133:54781 is slow
#
# 966 proxies left to filter
# 58.137.62.133:80 is bad
#
# 965 proxies left to filter
# 80.106.241.214:8080 is good
# average conn time: 4.56599634527
#
# 964 proxies left to filter
# 35.183.224.95:8080 is slow
#
# 963 proxies left to filter
# 39.50.130.246:8080 is slow
#
# 962 proxies left to filter
# 212.129.6.253:54321 is slow
#
# 961 proxies left to filter
# 217.79.3.94:8080 is good
# average conn time: 4.55952976999
#
# 960 proxies left to filter
# 43.230.157.153:49072 is bad
#
# 959 proxies left to filter
# 27.145.100.22:8080 is bad
#
# 958 proxies left to filter
# 5.206.76.111:8081 is slow
#
# 957 proxies left to filter
# 94.101.226.2:8080 is slow
#
# 956 proxies left to filter
# 46.55.21.80:8080 is slow
#
# 955 proxies left to filter
# 60.190.153.150:8080 is slow
#
# 954 proxies left to filter
# 51.255.115.230:1080 is slow
#
# 953 proxies left to filter
# 81.173.195.38:48522 is slow
#
# 952 proxies left to filter
# 212.98.143.141:8082 is good
# average conn time: 4.53367783042
#
# 951 proxies left to filter
# 213.234.0.242:56503 is slow
#
# 950 proxies left to filter
# 5.59.179.216:8081 is slow
#
# 949 proxies left to filter
# 45.64.87.129:8080 is good
# average conn time: 4.56239782101
#
# 948 proxies left to filter
# 50.239.245.105:80 is slow
#
# 947 proxies left to filter
# 213.6.156.113:8080 is slow
#
# 946 proxies left to filter
# 43.229.73.155:8080 is good
# average conn time: 4.59286965173
#
# 945 proxies left to filter
# 45.248.42.200:8080 is good
# average conn time: 4.598377962
#
# 944 proxies left to filter
# 95.107.3.76:60722 is slow
#
# 943 proxies left to filter
# 23.23.61.86:80 is good
# average conn time: 4.61608471495
#
# 942 proxies left to filter
# 50.233.228.147:8080 is slow
#
# 941 proxies left to filter
# 45.235.120.65:8080 is good
# average conn time: 4.60183639791
#
# 940 proxies left to filter
# 88.99.29.47:80 is slow
#
# 939 proxies left to filter
# 202.91.68.186:60259 is good
# average conn time: 4.64697560373
# 938 proxies left to filter
# 203.115.97.106:31070 is good
# average conn time: 4.64302331468
#
# 937 proxies left to filter
# 36.91.91.26:8080 is good
# average conn time: 4.65543699008
#
# 936 proxies left to filter
# 212.5.107.81:56481 is bad
#
# 935 proxies left to filter
# 94.244.28.246:31280 is slow
#
# 934 proxies left to filter
# 45.220.58.79:8080 is good
# average conn time: 4.66758079985
#
# 933 proxies left to filter
# 213.145.145.78:48449 is slow
#
# 932 proxies left to filter
# 36.77.253.127:8080 is slow
#
# 931 proxies left to filter
# 221.120.211.97:8080 is slow
#
# 930 proxies left to filter
# 203.76.124.35:8080 is good
# average conn time: 4.66997366704
#
# 929 proxies left to filter
# 27.72.61.48:48455 is slow
#
# 928 proxies left to filter
# 212.14.243.42:8080 is bad
#
# 927 proxies left to filter
# 36.71.150.113:80 is good
# average conn time: 4.69363807638
#
# 926 proxies left to filter
# 89.24.124.83:46507 is slow
#
# 925 proxies left to filter
# 41.217.219.53:43081 is slow
#
# 924 proxies left to filter
# 23.237.22.87:3128 is good
# average conn time: 4.64943271568
#
# 923 proxies left to filter
# 203.154.83.72:8080 is good
# average conn time: 4.62232951485
#
# 922 proxies left to filter
# 212.86.21.181:80 is slow
#
# 921 proxies left to filter
# 89.31.46.208:8080 is good
# average conn time: 4.64023391406
#
# 920 proxies left to filter
# 200.195.15.150:8080 is slow
#
# 919 proxies left to filter
# 60.149.95.179:3128 is good
# average conn time: 4.60466942549
#
# 918 proxies left to filter
# 27.147.250.114:33328 is good
# average conn time: 4.58924500541
#
# 917 proxies left to filter
# 96.9.88.47:49013 is good
# average conn time: 4.58196197538
#
# 916 proxies left to filter
# 36.72.108.42:80 is good
# average conn time: 4.56536710147
#
# 915 proxies left to filter
# 36.89.76.133:44800 is slow
#
# 914 proxies left to filter
# 217.182.120.162:1080 is slow
#
# 913 proxies left to filter
# 45.123.42.149:60253 is bad
#
# 912 proxies left to filter
# 51.255.115.224:1080 is slow
#
# 911 proxies left to filter
# 213.174.23.209:53281 is good
# average conn time: 4.56516580169
#
# 910 proxies left to filter
# 213.192.253.58:80 is slow
#
# 909 proxies left to filter
# 36.67.155.59:80 is good
# average conn time: 4.57459903217
#
# 908 proxies left to filter
# 49.156.42.188:8080 is good
# average conn time: 4.57540392876
#
# 907 proxies left to filter
# 95.71.126.215:50537 is slow
#
# 906 proxies left to filter
# 212.50.85.39:31237 is slow
#
# 905 proxies left to filter
# 203.84.143.190:3333 is good
# average conn time: 4.59845740773
#
# 904 proxies left to filter
# 52.83.253.74:3128 is slow
#
# 903 proxies left to filter
# 5.44.55.176:8080 is slow
#
# 902 proxies left to filter
# 77.94.112.234:55519 is good
# average conn time: 4.57018407186
#
# 901 proxies left to filter
# 36.255.87.241:83 is bad
#
# 900 proxies left to filter
# 5.206.233.106:44075 is bad
#
# 899 proxies left to filter
# 94.130.126.94:8008 is bad
#
# 898 proxies left to filter
# 60.212.194.161:8060 is slow
#
# 897 proxies left to filter
# 3.17.175.232:3128 is good
# average conn time: 4.53197778693
#
# 896 proxies left to filter
# 84.232.111.251:21776 is good
# average conn time: 4.55290036201
#
# 895 proxies left to filter
# 89.31.126.50:80 is slow
#
# 894 proxies left to filter
# 95.0.6.252:8080 is slow
#
# 893 proxies left to filter
# 36.91.51.233:3128 is good
# average conn time: 4.57072049218
#
# 892 proxies left to filter
# 202.169.252.131:23500 is slow
#
# 891 proxies left to filter
# 27.123.221.129:8080 is good
# average conn time: 4.59080767419
#
# 890 proxies left to filter
# 91.210.178.161:8080 is good
# average conn time: 4.57035113647
#
# 889 proxies left to filter
# 27.111.44.202:80 is good
# average conn time: 4.58469324154
#
# 888 proxies left to filter
# 43.245.218.255:59952 is slow
#
# 887 proxies left to filter
# 217.73.177.132:37641 is bad
#
# 886 proxies left to filter
# 52.22.122.114:3128 is good
# average conn time: 4.54695009149
#
# 885 proxies left to filter
# 35.235.75.244:3128 is good
# average conn time: 4.51119850422
#
# 884 proxies left to filter
# 41.215.81.170:59959 is bad
#
# 883 proxies left to filter
# 43.245.218.166:53281 is good
# average conn time: 4.50262132058
#
# 882 proxies left to filter
# 5.53.119.186:59437 is slow
#
# 881 proxies left to filter
# 203.150.113.79:8080 is slow
#
# 880 proxies left to filter
# 82.151.98.218:3128 is bad
#
# 879 proxies left to filter
# 80.211.159.187:80 is slow
#
# 878 proxies left to filter
# 212.88.122.246:35820 is good
# average conn time: 4.4866625212
#
# 877 proxies left to filter
# 203.84.136.69:3333 is good
# average conn time: 4.48305267647
#
# 876 proxies left to filter
# 51.255.161.222:80 is slow
#
# 875 proxies left to filter
# 36.74.156.163:8080 is good
# average conn time: 4.52513211171
#
# 874 proxies left to filter
# 213.74.123.103:31922 is good
# average conn time: 4.52724200438
#
# 873 proxies left to filter
# 213.58.202.70:54214 is bad
#
# 872 proxies left to filter
# 31.209.104.163:51417 is good
# average conn time: 4.50906381451
#
# 871 proxies left to filter
# 213.135.131.109:8081 is slow
#
# 870 proxies left to filter
# 95.107.161.210:59237 is bad
#
# 869 proxies left to filter
# 37.57.15.43:33761 is bad
#
# 868 proxies left to filter
# 36.67.198.35:3128 is slow
#
# 867 proxies left to filter
# 41.77.188.81:53432 is slow
#
# 866 proxies left to filter
# 218.241.219.226:9999 is good
# average conn time: 4.50090120672
#
# 865 proxies left to filter
# 212.156.146.22:40080 is good
# average conn time: 4.48687133481
#
# 864 proxies left to filter
# 60.10.2.53:3128 is bad
#
# 863 proxies left to filter
# 201.6.109.189:8080 is good
# average conn time: 4.49894702721
#
# 862 proxies left to filter
# 36.91.86.180:8080 is good
# average conn time: 4.51280440792
#
# 861 proxies left to filter
# 217.107.71.14:8080 is good
# average conn time: 4.53250749843
#
# 860 proxies left to filter
# 203.150.128.82:8080 is good
# average conn time: 4.52925767377
#
# 859 proxies left to filter
# 62.122.99.235:8080 is good
# average conn time: 4.540248102
#
# 858 proxies left to filter
# 35.200.160.182:3128 is slow
#
# 857 proxies left to filter
# 41.217.219.49:52669 is slow
#
# 856 proxies left to filter
# 37.10.172.39:8080 is good
# average conn time: 4.53864482366
#
# 855 proxies left to filter
# 43.229.72.237:36218 is slow
#
# 854 proxies left to filter
# 35.181.36.31:3128 is good
# average conn time: 4.50920234382
#
# 853 proxies left to filter
# 27.72.56.206:56698 is good
# average conn time: 4.52801093911
#
# 852 proxies left to filter
# 35.244.1.59:80 is slow
#
# 851 proxies left to filter
# 47.51.51.190:8080 is good
# average conn time: 4.52458498352
#
# 850 proxies left to filter
# 80.120.171.99:80 is slow
#
# 849 proxies left to filter
# 40.68.149.233:8080 is good
# average conn time: 4.49755594624
#
# 848 proxies left to filter
# 89.47.38.196:52917 is bad
#
# 847 proxies left to filter
# 206.125.41.130:80 is slow
#
# 846 proxies left to filter
# 89.29.100.212:3128 is bad
#
# 845 proxies left to filter
# 54.36.44.252:1080 is slow
#
# 844 proxies left to filter
# 43.229.72.233:59299 is bad
#
# 843 proxies left to filter
# 23.102.224.85:80 is slow
#
# 842 proxies left to filter
# 81.199.32.218:50154 is bad
#
# 841 proxies left to filter
# 210.16.85.98:83 is good
# average conn time: 4.49023381339
#
# 840 proxies left to filter
# 35.189.90.214:3128 is good
# average conn time: 4.46243494048
#
# 839 proxies left to filter
# 212.69.18.108:8080 is slow
#
# 838 proxies left to filter
# 36.65.222.50:8080 is good
# average conn time: 4.45019645238
#
# 837 proxies left to filter
# 54.38.214.35:80 is slow
#
# 836 proxies left to filter
# 60.10.2.78:3128 is slow
#
# 835 proxies left to filter
# 54.64.52.81:3128 is good
# average conn time: 4.42685655062
#
# 834 proxies left to filter
# 98.172.142.6:8080 is bad
#
# 833 proxies left to filter
# 82.138.23.141:3128 is bad
#
# 832 proxies left to filter
# 206.189.163.84:8080 is slow
#
# 831 proxies left to filter
# 35.245.172.192:3128 is good
# average conn time: 4.4315709193
#
# 830 proxies left to filter
# 31.14.49.1:8080 is slow
#
# 829 proxies left to filter
# 201.158.0.58:999 is slow
#
# 828 proxies left to filter
# 203.30.254.107:53281 is slow
#
# 827 proxies left to filter
# 89.29.100.210:3128 is bad
#
# 826 proxies left to filter
# 202.77.107.243:61917 is slow
#
# 825 proxies left to filter
# 51.255.115.227:1080 is slow
#
# 824 proxies left to filter
# 41.79.198.36:8080 is slow
#
# 823 proxies left to filter
# 200.69.81.198:58593 is slow
#
# 822 proxies left to filter
# 94.242.58.142:1448 is good
# average conn time: 4.40970055546
#
# 821 proxies left to filter
# 35.231.181.180:80 is slow
#
# 820 proxies left to filter
# 36.66.217.179:8080 is good
# average conn time: 4.41615774276
#
# 819 proxies left to filter
# 93.190.137.58:8080 is slow
# 818 proxies left to filter
# 45.70.106.34:8080 is good
# average conn time: 4.43153444982
#
# 817 proxies left to filter
# 43.228.221.171:61267 is bad
#
# 816 proxies left to filter
# 36.255.87.238:83 is slow
#
# 815 proxies left to filter
# 51.15.103.214:3128 is good
# average conn time: 4.40615295697
#
# 814 proxies left to filter
# 46.253.12.46:53281 is good
# average conn time: 4.40642690162
#
# 813 proxies left to filter
# 78.186.169.88:8080 is slow
#
# 812 proxies left to filter
# 83.151.14.6:3128 is slow
#
# 811 proxies left to filter
# 46.148.196.130:8080 is good
# average conn time: 4.41228585408
#
# 810 proxies left to filter
# 81.17.131.61:8080 is good
# average conn time: 4.40427369777
#
# 809 proxies left to filter
# 89.29.100.225:3128 is bad
#
# 808 proxies left to filter
# 47.96.122.110:8080 is slow
#
# 807 proxies left to filter
# 95.139.200.28:8081 is slow
#
# 806 proxies left to filter
# 94.242.58.108:10010 is good
# average conn time: 4.38113709372
#
# 805 proxies left to filter
# 83.168.86.189:8090 is good
# average conn time: 4.40565176751
#
# 804 proxies left to filter
# 49.156.34.103:51394 is bad
#
# 803 proxies left to filter
# 36.68.44.210:8080 is slow
#
# 802 proxies left to filter
# 80.151.181.110:80 is slow
#
# 801 proxies left to filter
# 36.89.228.201:30612 is slow
#
# 800 proxies left to filter
# 80.52.206.34:30211 is slow
#
# 799 proxies left to filter
# 213.145.3.104:8080 is slow
#
# 798 proxies left to filter
# 54.36.44.251:1080 is slow
#
# 797 proxies left to filter
# 54.37.74.251:80 is slow
#
# 796 proxies left to filter
# 36.81.175.24:8080 is good
# average conn time: 4.41439793094
#
# 795 proxies left to filter
# 54.39.98.135:3128 is slow
#
# 794 proxies left to filter
# 93.190.139.150:8080 is slow
#
# 793 proxies left to filter
# 45.7.178.121:8080 is good
# average conn time: 4.41807457765
#
# 792 proxies left to filter
# 3.104.89.98:80 is slow
#
# 791 proxies left to filter
# 39.137.69.7:80 is slow
#
# 790 proxies left to filter
# 221.5.80.66:3128 is good
# average conn time: 4.4059234676
#
# 789 proxies left to filter
# 213.6.49.114:54565 is bad
#
# 788 proxies left to filter
# 51.255.115.224:8080 is bad
#
# 787 proxies left to filter
# 203.202.243.71:47337 is slow
#
# 786 proxies left to filter
# 60.205.202.3:3128 is slow
#
# 785 proxies left to filter
# 222.165.214.98:51204 is bad
#
# 784 proxies left to filter
# 217.182.120.162:8080 is slow
#
# 783 proxies left to filter
# 89.29.100.217:3128 is bad
#
# 782 proxies left to filter
# 80.211.66.190:8080 is good
# average conn time: 4.38313259106
#
# 781 proxies left to filter
# 223.85.196.75:9999 is slow
#
# 780 proxies left to filter
# 212.43.123.18:41258 is slow
#
# 779 proxies left to filter
# 61.142.176.17:8082 is slow
#
# 778 proxies left to filter
# 5.189.133.231:80 is slow
#
# 777 proxies left to filter
# 59.153.100.84:80 is slow
#
# 776 proxies left to filter
# 213.6.162.6:8080 is good
# average conn time: 4.38603800574
#
# 775 proxies left to filter
# 46.201.225.210:36909 is good
# average conn time: 4.37486744701
#
# 774 proxies left to filter
# 213.108.18.34:41812 is slow
#
# 773 proxies left to filter
# 37.57.216.4:4444 is slow
#
# 772 proxies left to filter
# 222.24.94.218:80 is slow
#
# 771 proxies left to filter
# 61.220.204.25:3128 is bad
#
# 770 proxies left to filter
# 37.57.129.4:4444 is bad
#
# 769 proxies left to filter
# 202.79.48.38:56079 is good
# average conn time: 4.40014121148
#
# 768 proxies left to filter
# 54.38.37.42:80 is slow
#
# 767 proxies left to filter
# 202.79.30.38:8080 is good
# average conn time: 4.39092532488
#
# 766 proxies left to filter
# 35.241.65.18:80 is slow
#
# 765 proxies left to filter
# 217.117.4.155:3128 is good
# average conn time: 4.38182157772
#
# 764 proxies left to filter
# 54.39.98.135:8080 is slow
#
# 763 proxies left to filter
# 36.66.170.19:8080 is slow
#
# 762 proxies left to filter
# 27.208.93.208:8060 is slow
#
# 761 proxies left to filter
# 212.210.138.140:53281 is good
# average conn time: 4.36908075779
#
# 760 proxies left to filter
# 51.68.141.240:3128 is good
# average conn time: 4.34785957156
#
# 759 proxies left to filter
# 216.250.114.254:3128 is slow
#
# 758 proxies left to filter
# 51.158.64.170:3128 is good
# average conn time: 4.3250495106
#
# 757 proxies left to filter
# 27.208.138.230:8060 is slow
#
# 756 proxies left to filter
# 96.9.66.112:8080 is slow
#
# 755 proxies left to filter
# 89.250.220.40:40423 is slow
#
# 754 proxies left to filter
# 79.34.207.240:8080 is slow
#
# 753 proxies left to filter
# 35.236.207.97:8080 is slow
#
# 752 proxies left to filter
# 88.190.203.36:80 is slow
#
# 751 proxies left to filter
# 24.35.1.5:52867 is bad
#
# 750 proxies left to filter
# 47.89.249.166:80 is slow
#
# 749 proxies left to filter
# 36.37.160.253:53480 is bad
#
# 748 proxies left to filter
# 43.250.126.1:9001 is bad
#
# 747 proxies left to filter
# 203.153.117.65:54144 is good
# average conn time: 4.33660941983
#
# 746 proxies left to filter
# 99.79.89.69:8080 is slow
#
# 745 proxies left to filter
# 36.255.87.231:83 is good
# average conn time: 4.32791378763
#
# 744 proxies left to filter
# 51.15.50.11:80 is good
# average conn time: 4.30646554385
#
# 743 proxies left to filter
# 78.111.250.174:8080 is good
# average conn time: 4.32620025989
#
# 742 proxies left to filter
# 91.214.128.243:23500 is good
# average conn time: 4.32064795494
#
# 741 proxies left to filter
# 36.67.90.34:3128 is slow
#
# 740 proxies left to filter
# 36.37.219.198:53281 is slow
#
# 739 proxies left to filter
# 54.39.53.104:3128 is slow
#
# 738 proxies left to filter
# 202.137.134.39:8080 is slow
#
# 737 proxies left to filter
# 62.152.85.158:31156 is bad
#
# 736 proxies left to filter
# 50.73.137.241:3128 is good
# average conn time: 4.31997375029
#
# 735 proxies left to filter
# 43.254.54.81:49788 is slow
#
# 734 proxies left to filter
# 3.86.191.197:3128 is slow
#
# 733 proxies left to filter
# 216.215.123.174:8080 is bad
#
# 732 proxies left to filter
# 221.4.150.7:8181 is slow
#
# 731 proxies left to filter
# 212.184.186.146:8080 is bad
#
# 730 proxies left to filter
# 37.57.253.91:37186 is slow
#
# 729 proxies left to filter
# 212.74.213.86:46020 is bad
#
# 728 proxies left to filter
# 223.85.196.75:9797 is slow
#
# 727 proxies left to filter
# 202.62.47.244:8080 is good
# average conn time: 4.33567785931
#
# 726 proxies left to filter
# 41.76.155.194:8080 is good
# average conn time: 4.32765286026
#
# 725 proxies left to filter
# 46.254.184.149:8080 is good
# average conn time: 4.31571613966
#
# 724 proxies left to filter
# 5.8.207.160:57192 is good
# average conn time: 4.3108949507
#
# 723 proxies left to filter
# 96.9.73.79:36360 is slow
#
# 722 proxies left to filter
# 50.252.127.53:53304 is bad
#
# 721 proxies left to filter
# 61.136.163.246:8103 is slow
#
# 720 proxies left to filter
# 36.90.30.227:8080 is good
# average conn time: 4.31770277581
#
# 719 proxies left to filter
# 200.69.66.42:9991 is good
# average conn time: 4.33222598115
#
# 718 proxies left to filter
# 50.253.229.189:45725 is slow
#
# 717 proxies left to filter
# 27.123.254.182:38097 is slow
#
# 716 proxies left to filter
# 45.70.107.189:8080 is slow
#
# 715 proxies left to filter
# 80.52.238.30:36321 is good
# average conn time: 4.34710849641
#
# 714 proxies left to filter
# 51.255.115.228:1080 is slow
#
# 713 proxies left to filter
# 88.255.101.244:8080 is slow
#
# 712 proxies left to filter
# 79.173.124.113:8080 is slow
#
# 711 proxies left to filter
# 36.65.107.9:8080 is good
# average conn time: 4.34345961987
#
# 710 proxies left to filter
# 49.236.212.30:45648 is slow
#
# 709 proxies left to filter
# 36.71.226.77:8080 is slow
#
# 708 proxies left to filter
# 43.246.139.82:8080 is good
# average conn time: 4.37929187366
#
# 707 proxies left to filter
# 36.66.209.3:8080 is good
# average conn time: 4.38136573813
#
# 706 proxies left to filter
# 45.164.166.77:8080 is good
# average conn time: 4.36452063194
#
# 705 proxies left to filter
# 54.37.84.141:3128 is good
# average conn time: 4.34445962209
#
# 704 proxies left to filter
# 89.251.146.11:58893 is slow
#
# 703 proxies left to filter
# 213.192.75.198:3128 is good
# average conn time: 4.32555076263
#
# 702 proxies left to filter
# 47.98.168.204:8080 is slow
#
# 701 proxies left to filter
# 85.238.105.190:8181 is slow
#
# 700 proxies left to filter
# 45.163.163.170:8080 is slow
#
# 699 proxies left to filter
# 95.141.36.112:8686 is good
# average conn time: 4.30723454158
#
# 698 proxies left to filter
# 54.238.250.4:80 is slow
#
# 697 proxies left to filter
# 213.6.7.51:80 is slow
#
# 696 proxies left to filter
# 46.165.19.207:41901 is bad
#
# 695 proxies left to filter
# 41.215.26.182:8080 is good
# average conn time: 4.31417210721
#
# 694 proxies left to filter
# 41.73.4.42:8080 is slow
#
# 693 proxies left to filter
# 93.190.139.153:8080 is slow
#
# 692 proxies left to filter
# 51.38.147.171:3128 is good
# average conn time: 4.29573354092
#
# 691 proxies left to filter
# 81.196.41.75:43614 is good
# average conn time: 4.29220597601
#
# 690 proxies left to filter
# 54.162.202.98:80 is slow
#
# 689 proxies left to filter
# 43.242.242.196:8080 is good
# average conn time: 4.30799062356
#
# 688 proxies left to filter
# 60.10.2.69:3128 is bad
#
# 687 proxies left to filter
# 77.95.96.169:80 is slow
#
# 686 proxies left to filter
# 59.38.61.3:9797 is slow
#
# 685 proxies left to filter
# 212.72.159.22:30323 is good
# average conn time: 4.31027766949
#
# 684 proxies left to filter
# 36.66.176.85:8080 is slow
#
# 683 proxies left to filter
# 49.156.35.230:8080 is bad
#
# 682 proxies left to filter
# 95.137.240.30:35165 is bad
#
# 681 proxies left to filter
# 45.238.140.62:46938 is good
# average conn time: 4.30377288659
#
# 680 proxies left to filter
# 41.60.228.187:41125 is slow
#
# 679 proxies left to filter
# 3.87.85.38:3128 is good
# average conn time: 4.28205915951
#
# 678 proxies left to filter
# 49.128.181.13:8081 is slow
#
# 677 proxies left to filter
# 54.39.147.31:80 is slow
#
# 676 proxies left to filter
# 37.235.198.163:3128 is slow
#
# 675 proxies left to filter
# 202.79.43.139:8080 is good
# average conn time: 4.27480184398
#
# 674 proxies left to filter
# 202.79.25.246:44810 is bad
#
# 673 proxies left to filter
# 46.17.120.217:36127 is bad
#
# 672 proxies left to filter
# 73.165.155.245:80 is slow
#
# 671 proxies left to filter
# 36.65.97.49:8080 is good
# average conn time: 4.275446613
#
# 670 proxies left to filter
# 222.165.204.163:23500 is slow
#
# 669 proxies left to filter
# 84.39.243.12:34198 is bad
#
# 668 proxies left to filter
# 95.47.180.171:53484 is slow
#
# 667 proxies left to filter
# 95.67.67.54:53281 is bad
#
# 666 proxies left to filter
# 47.52.153.167:443 is slow
#
# 665 proxies left to filter
# 43.252.18.140:35377 is slow
#
# 664 proxies left to filter
# 51.255.115.226:1080 is slow
#
# 663 proxies left to filter
# 203.113.119.226:40618 is bad
#
# 662 proxies left to filter
# 49.49.26.113:8080 is slow
#
# 661 proxies left to filter
# 36.75.172.239:8080 is good
# average conn time: 4.27341588924
#
# 660 proxies left to filter
# 221.203.78.138:8082 is slow
#
# 659 proxies left to filter
# 223.25.108.19:8080 is good
# average conn time: 4.29421886349
#
# 658 proxies left to filter
# 35.245.88.169:3128 is good
# average conn time: 4.29341531793
#
# 657 proxies left to filter
# 41.223.234.37:8080 is slow
#
# 656 proxies left to filter
# 202.182.59.114:8080 is slow
#
# 655 proxies left to filter
# 202.169.252.230:8080 is slow
#
# 654 proxies left to filter
# 36.65.184.186:8080 is good
# average conn time: 4.28845463268
#
# 653 proxies left to filter
# 88.255.168.3:23500 is bad
#
# 652 proxies left to filter
# 51.158.102.56:80 is good
# average conn time: 4.27013644361
#
# 651 proxies left to filter
# 23.237.23.73:3128 is good
# average conn time: 4.25001304578
#
# 650 proxies left to filter
# 41.73.3.206:8080 is slow
#
# 649 proxies left to filter
# 36.255.87.226:83 is slow
#
# 648 proxies left to filter
# 221.126.249.99:8080 is bad
#
# 647 proxies left to filter
# 217.145.150.71:80 is slow
#
# 646 proxies left to filter
# 213.230.68.183:3128 is slow
#
# 645 proxies left to filter
# 202.75.97.82:47009 is bad
#
# 644 proxies left to filter
# 217.126.203.104:55114 is good
# average conn time: 4.2424528465
#
# 643 proxies left to filter
# 209.97.187.179:3128 is good
# average conn time: 4.22433465992
#
# 642 proxies left to filter
# 91.194.247.247:31337 is slow
#
# 641 proxies left to filter
# 95.141.132.138:30743 is bad
#
# 640 proxies left to filter
# 35.208.145.249:80 is good
# average conn time: 4.2043836165
#
# 639 proxies left to filter
# 36.67.16.39:51347 is bad
#
# 638 proxies left to filter
# 91.185.237.65:3128 is good
# average conn time: 4.20366276928
#
# 637 proxies left to filter
# 51.15.110.96:3128 is slow
#
# 636 proxies left to filter
# 60.10.2.74:3128 is slow
#
# 635 proxies left to filter
# 36.66.43.27:8080 is bad
#
# 634 proxies left to filter
# 54.36.44.253:1080 is slow
#
# 633 proxies left to filter
# 95.87.220.19:15600 is slow
#
# 632 proxies left to filter
# 212.72.133.212:47960 is good
# average conn time: 4.20893775582
#
# 631 proxies left to filter
# 45.234.95.120:3128 is slow
#
# 630 proxies left to filter
# 45.125.66.131:54321 is slow
#
# 629 proxies left to filter
# 212.72.141.242:8080 is slow
#
# 628 proxies left to filter
# 213.254.21.53:8080 is good
# average conn time: 4.19299935939
#
# 627 proxies left to filter
# 217.64.109.234:45282 is slow
#
# 626 proxies left to filter
# 27.208.226.91:8060 is slow
#
# 625 proxies left to filter
# 51.83.31.150:3128 is good
# average conn time: 4.17688825815
#
# 624 proxies left to filter
# 37.123.96.237:8080 is good
# average conn time: 4.17116437052
#
# 623 proxies left to filter
# 92.127.155.231:59512 is slow
#
# 622 proxies left to filter
# 27.208.95.51:8060 is slow
#
# 621 proxies left to filter
# 95.47.116.184:60722 is good
# average conn time: 4.18934106944
#
# 620 proxies left to filter
# 203.107.135.126:80 is slow
#
# 619 proxies left to filter
# 223.206.22.253:8080 is good
# average conn time: 4.17917551762
#
# 618 proxies left to filter
# 5.140.233.194:45375 is slow
#
# 617 proxies left to filter
# 97.75.124.126:8080 is slow
#
# 616 proxies left to filter
# 36.255.86.227:83 is good
# average conn time: 4.18180404936
#
# 615 proxies left to filter
# 212.66.34.240:39800 is slow
#
# 614 proxies left to filter
# 94.230.243.6:8080 is slow
#
# 613 proxies left to filter
# 80.94.229.172:3128 is slow
#
# 612 proxies left to filter
# 5.23.103.98:54754 is slow
#
# 611 proxies left to filter
# 77.93.126.140:3128 is slow
#
# 610 proxies left to filter
# 27.147.215.188:8080 is slow
#
# 609 proxies left to filter
# 217.24.183.72:58739 is slow
#
# 608 proxies left to filter
# 90.151.59.222:35336 is bad
#
# 607 proxies left to filter
# 46.163.184.59:80 is slow
#
# 606 proxies left to filter
# 77.95.96.170:80 is slow
#
# 605 proxies left to filter
# 31.61.112.130:51885 is good
# average conn time: 4.18789969205
#
# 604 proxies left to filter
# 88.199.21.74:80 is good
# average conn time: 4.18344031847
#
# 603 proxies left to filter
# 213.100.168.84:34173 is good
# average conn time: 4.18226709206
#
# 602 proxies left to filter
# 202.51.115.122:42080 is slow
#
# 601 proxies left to filter
# 54.38.110.35:47640 is good
# average conn time: 4.16632703032
#
# 600 proxies left to filter
# 159.203.184.52:3128 is good
# average conn time: 4.14776548503
#
# 599 proxies left to filter
# 41.73.15.130:8080 is slow
#
# 598 proxies left to filter
# 51.255.115.225:1080 is slow
#
# 597 proxies left to filter
# 36.255.189.38:8080 is slow
#
# 596 proxies left to filter
# 27.110.221.178:8080 is good
# average conn time: 4.16891343076
#
# 595 proxies left to filter
# 203.223.41.34:54773 is bad
#
# 594 proxies left to filter
# 210.16.85.98:82 is good
# average conn time: 4.16722361247
#
# 593 proxies left to filter
# 95.133.163.98:61821 is slow
#
# 592 proxies left to filter
# 36.255.86.230:82 is slow
#
# 591 proxies left to filter
# 41.206.33.234:60203 is slow
#
# 590 proxies left to filter
# 5.14.202.55:53281 is good
# average conn time: 4.16111804058
#
# 589 proxies left to filter
# 46.44.56.42:8081 is slow
#
# 588 proxies left to filter
# 89.27.165.167:8080 is good
# average conn time: 4.15828395666
#
# 587 proxies left to filter
# 77.95.96.167:80 is slow
#
# 586 proxies left to filter
# 213.100.166.196:51265 is good
# average conn time: 4.14554363268
#
# 585 proxies left to filter
# 217.182.120.161:1080 is slow
#
# 584 proxies left to filter
# 51.83.74.198:80 is slow
#
# 583 proxies left to filter
# 52.83.255.89:80 is slow
#
# 582 proxies left to filter
# 36.89.228.57:35400 is slow
#
# 581 proxies left to filter
# 222.121.116.26:45570 is bad
#
# 580 proxies left to filter
# 89.249.251.21:3128 is slow
#
# 579 proxies left to filter
# 203.84.141.81:3333 is good
# average conn time: 4.14706690191
#
# 578 proxies left to filter
# 94.73.202.65:8081 is slow
#
# 577 proxies left to filter
# 41.76.245.254:8080 is slow
#
# 576 proxies left to filter
# 3.95.193.173:80 is slow
#
# 575 proxies left to filter
# 203.189.137.112:8080 is slow
#
# 574 proxies left to filter
# 203.189.153.24:80 is good
# average conn time: 4.14862785646
#
# 573 proxies left to filter
# 62.210.201.111:8080 is slow
#
# 572 proxies left to filter
# 202.91.75.52:8080 is good
# average conn time: 4.14500710409
#
# 571 proxies left to filter
# 31.46.29.45:8080 is slow
#
# 570 proxies left to filter
# 31.193.90.243:8080 is bad
#
# 569 proxies left to filter
# 222.186.129.51:9001 is slow
#
# 568 proxies left to filter
# 36.255.86.232:82 is slow
#
# 567 proxies left to filter
# 202.169.226.232:8080 is good
# average conn time: 4.17329072194
#
# 566 proxies left to filter
# 213.230.68.182:3128 is slow
# 565 proxies left to filter
# 213.245.37.71:3128 is slow
#
# 564 proxies left to filter
# 52.194.230.130:8080 is slow
#
# 563 proxies left to filter
# 78.158.54.213:51787 is good
# average conn time: 4.18050443317
#
# 562 proxies left to filter
# 35.212.23.251:80 is good
# average conn time: 4.16359230527
#
# 561 proxies left to filter
# 83.167.203.174:35260 is bad
#
# 560 proxies left to filter
# 41.189.164.74:8080 is slow
#
# 559 proxies left to filter
# 212.86.21.180:80 is slow
#
# 558 proxies left to filter
# 80.211.36.44:80 is slow
#
# 557 proxies left to filter
# 92.39.55.186:48537 is bad
#
# 556 proxies left to filter
# 60.212.196.29:8060 is slow
#
# 555 proxies left to filter
# 60.249.176.76:8080 is slow
#
# 554 proxies left to filter
# 96.9.82.78:50541 is bad
#
# 553 proxies left to filter
# 36.90.150.53:3128 is good
# average conn time: 4.16636155967
#
# 552 proxies left to filter
# 35.211.237.137:80 is good
# average conn time: 4.14949078858
#
# 551 proxies left to filter
# 206.12.89.89:3128 is good
# average conn time: 4.13412244797
#
# 550 proxies left to filter
# 202.182.164.165:55047 is good
# average conn time: 4.16736011484
#
# 549 proxies left to filter
# 47.107.163.15:3128 is slow
#
# 548 proxies left to filter
# 51.145.159.35:3128 is good
# average conn time: 4.15289659962
#
# 547 proxies left to filter
# 77.95.96.162:80 is slow
#
# 546 proxies left to filter
# 91.235.247.252:8081 is slow
#
# 545 proxies left to filter
# 202.84.77.78:60322 is slow
#
# 544 proxies left to filter
# 89.218.133.170:43810 is slow
#
# 543 proxies left to filter
# 39.106.35.21:3128 is slow
#
# 542 proxies left to filter
# 36.66.124.157:8080 is slow
#
# 541 proxies left to filter
# 202.182.52.130:80 is slow
#
# 540 proxies left to filter
# 83.175.238.170:53281 is bad
#
# 539 proxies left to filter
# 82.147.120.38:41741 is bad
#
# 538 proxies left to filter
# 54.210.229.54:3128 is slow
#
# 537 proxies left to filter
# 82.145.149.156:54678 is bad
#
# 536 proxies left to filter
# 35.198.1.58:80 is good
# average conn time: 4.13905839125
#
# 535 proxies left to filter
# 36.255.87.234:83 is slow
#
# 534 proxies left to filter
# 60.10.2.77:3128 is bad
#
# 533 proxies left to filter
# 79.134.211.30:46852 is good
# average conn time: 4.13543352914
#
# 532 proxies left to filter
# 202.56.186.146:8080 is slow
#
# 531 proxies left to filter
# 213.184.251.36:43439 is slow
#
# 530 proxies left to filter
# 78.109.129.46:45943 is slow
#
# 529 proxies left to filter
# 3.208.218.238:8080 is slow
#
# 528 proxies left to filter
# 213.6.148.150:8080 is slow
#
# 527 proxies left to filter
# 223.19.141.26:8197 is slow
#
# 526 proxies left to filter
# 45.125.66.146:54321 is slow
#
# 525 proxies left to filter
# 83.12.84.2:8080 is slow
#
# 524 proxies left to filter
# 217.13.220.6:60936 is bad
#
# 523 proxies left to filter
# 213.184.226.166:33940 is slow
#
# 522 proxies left to filter
# 36.67.27.29:56125 is good
# average conn time: 4.143120718
#
# 521 proxies left to filter
# 203.114.106.253:8080 is slow
#
# 520 proxies left to filter
# 202.91.89.204:54404 is slow
#
# 519 proxies left to filter
# 202.131.229.10:8080 is slow
#
# 518 proxies left to filter
# 37.187.149.234:8080 is slow
#
# 517 proxies left to filter
# 36.66.138.25:40496 is slow
#
# 516 proxies left to filter
# 81.198.119.241:42183 is bad
#
# 515 proxies left to filter
# 46.151.60.99:35732 is slow
#
# 514 proxies left to filter
# 212.28.84.105:53281 is slow
#
# 513 proxies left to filter
# 36.89.237.202:8080 is slow
#
# 512 proxies left to filter
# 47.74.158.207:80 is slow
#
# 511 proxies left to filter
# 94.244.27.90:8080 is good
# average conn time: 4.15187294452
#
# 510 proxies left to filter
# 221.239.86.26:32228 is slow
#
# 509 proxies left to filter
# 93.42.192.110:56769 is good
# average conn time: 4.14646809985
#
# 508 proxies left to filter
# 212.73.69.6:61119 is slow
#
# 507 proxies left to filter
# 203.150.191.157:8080 is good
# average conn time: 4.14941372585
#
# 506 proxies left to filter
# 35.222.211.82:3128 is good
# average conn time: 4.14184193224
#
# 505 proxies left to filter
# 36.66.127.99:8080 is good
# average conn time: 4.16695899659
#
# 504 proxies left to filter
# 72.255.33.255:3128 is good
# average conn time: 4.16671775458
#
# 503 proxies left to filter
# 222.74.237.246:808 is good
# average conn time: 4.16300438426
#
# 502 proxies left to filter
# 51.38.217.121:808 is slow
#
# 501 proxies left to filter
# 60.10.2.70:3128 is bad
#
# 500 proxies left to filter
# 90.127.130.118:8080 is slow
#
# 499 proxies left to filter
# 47.52.153.167:80 is slow
#
# 498 proxies left to filter
# 46.151.156.198:56013 is bad
#
# 497 proxies left to filter
# 78.92.232.39:8080 is good
# average conn time: 4.17646816398
#
# 496 proxies left to filter
# 82.151.114.197:56208 is bad
#
# 495 proxies left to filter
# 95.47.116.73:63141 is slow
#
# 494 proxies left to filter
# 96.9.66.241:40921 is good
# average conn time: 4.18584612922
#
# 493 proxies left to filter
# 85.196.183.162:8080 is bad
#
# 492 proxies left to filter
# 77.95.96.161:80 is slow
#
# 491 proxies left to filter
# 91.90.188.241:58375 is bad
#
# 490 proxies left to filter
# 95.156.102.34:46583 is slow
#
# 489 proxies left to filter
# 59.91.123.94:8080 is good
# average conn time: 4.1809401075
#
# 488 proxies left to filter
# 41.190.92.99:34582 is slow
#
# 487 proxies left to filter
# 45.166.86.6:8080 is slow
#
# 486 proxies left to filter
# 88.202.44.210:48352 is slow
#
# 485 proxies left to filter
# 41.59.200.33:8080 is good
# average conn time: 4.17633455522
#
# 484 proxies left to filter
# 212.90.169.173:8081 is good
# average conn time: 4.17756828099
#
# 483 proxies left to filter
# 36.89.226.254:8081 is bad
#
# 482 proxies left to filter
# 85.238.98.160:34414 is bad
#
# 481 proxies left to filter
# 36.75.209.120:8080 is good
# average conn time: 4.17201830821
#
# 480 proxies left to filter
# 5.58.156.61:53654 is good
# average conn time: 4.17047283591
#
# 479 proxies left to filter
# 31.11.177.235:80 is slow
#
# 478 proxies left to filter
# 206.81.11.75:80 is slow
#
# 477 proxies left to filter
# 27.72.72.48:50544 is bad
#
# 476 proxies left to filter
# 221.4.172.162:3128 is bad
#
# 475 proxies left to filter
# 81.93.73.28:8081 is slow
#
# 474 proxies left to filter
# 45.116.106.109:8080 is slow
#
# 473 proxies left to filter
# 79.115.40.3:41258 is slow
#
# 472 proxies left to filter
# 223.111.254.83:80 is slow
#
# 471 proxies left to filter
# 47.52.25.211:3128 is slow
#
# 470 proxies left to filter
# 95.134.195.78:36133 is bad
#
# 469 proxies left to filter
# 58.244.27.49:8080 is slow
#
# 468 proxies left to filter
# 35.211.241.158:80 is good
# average conn time: 4.15511255459
#
# 467 proxies left to filter
# 213.80.112.197:80 is slow
#
# 466 proxies left to filter
# 36.37.114.41:41454 is slow
#
# 465 proxies left to filter
# 27.147.197.126:8080 is slow
#
# 464 proxies left to filter
# 213.142.206.146:53281 is slow
#
# 463 proxies left to filter
# 79.135.194.127:8080 is good
# average conn time: 4.16210518232
#
# 462 proxies left to filter
# 95.87.127.133:48383 is bad
#
# 461 proxies left to filter
# 78.187.61.40:8080 is slow
#
# 460 proxies left to filter
# 203.205.32.74:44537 is good
# average conn time: 4.16714957465
#
# 459 proxies left to filter
# 36.67.250.197:8080 is slow
#
# 458 proxies left to filter
# 202.179.7.182:40798 is slow
#
# 457 proxies left to filter
# 41.139.141.254:39607 is slow
#
# 456 proxies left to filter
# 62.107.204.156:80 is slow
#
# ...
#
# 238 proxies left to filter
# 79.175.57.77:55477 is good
# average conn time: 4.19951419322
#
# 237 proxies left to filter
# 36.90.163.212:8080 is good
# average conn time: 4.19516387656
#
# 236 proxies left to filter
# 94.41.190.15:8080 is slow
#
# 235 proxies left to filter
# 23.96.22.86:80 is slow
#
# 234 proxies left to filter
# 80.91.116.233:8080 is good
# average conn time: 4.20237579301
#
# 233 proxies left to filter
# 41.144.132.206:8080 is slow
#
# 232 proxies left to filter
# 94.242.58.142:655 is slow
#
# 231 proxies left to filter
# 5.16.15.2:8080 is good
# average conn time: 4.20363797682
#
# 230 proxies left to filter
# 41.77.23.202:8080 is slow
#
# 229 proxies left to filter
# 51.255.115.230:8080 is good
# average conn time: 4.1976441252
#
# 228 proxies left to filter
# 36.67.24.61:55683 is bad
#
# 227 proxies left to filter
# 37.143.160.5:59027 is bad
#
# 226 proxies left to filter
# 54.39.97.250:3128 is good
# average conn time: 4.18593113069
#
# 225 proxies left to filter
# 206.189.114.168:8080 is good
# average conn time: 4.17512608161
#
# 224 proxies left to filter
# 196.0.110.146:38482 is slow
#
# 223 proxies left to filter
# 58.187.77.36:61252 is bad
#
# 222 proxies left to filter
# 39.137.69.6:80 is slow
#
# 221 proxies left to filter
# 37.187.149.129:8080 is bad
#
# 220 proxies left to filter
# 87.27.225.147:8080 is good
# average conn time: 4.16800380558
#
# 219 proxies left to filter
# 221.223.82.142:8060 is slow
#
# 218 proxies left to filter
# 223.205.77.88:8080 is good
# average conn time: 4.16422313069
#
# 217 proxies left to filter
# 5.230.140.38:8082 is slow
#
# 216 proxies left to filter
# 203.156.209.121:8080 is bad
#
# 215 proxies left to filter
# 92.249.70.83:46792 is good
# average conn time: 4.16578041344
#
# 214 proxies left to filter
# 94.23.196.68:3128 is good
# average conn time: 4.16325520527
#
# 213 proxies left to filter
# 81.90.12.32:45482 is good
# average conn time: 4.16724973158
#
# 212 proxies left to filter
# 82.81.169.142:80 is good
# average conn time: 4.15821648148
#
# 211 proxies left to filter
# 79.143.225.152:45229 is bad
#
# 210 proxies left to filter
# 27.147.184.110:8080 is bad
#
# 209 proxies left to filter
# 37.59.35.174:1080 is slow
#
# 208 proxies left to filter
# 36.89.55.205:48347 is bad
#
# 207 proxies left to filter
# 213.6.7.52:80 is slow
#
# 206 proxies left to filter
# 220.247.164.53:8080 is good
# average conn time: 4.17049908566
#
# 205 proxies left to filter
# 94.242.59.135:1448 is good
# average conn time: 4.1625417854
#
# 204 proxies left to filter
# 223.207.15.105:8080 is slow
#
# 203 proxies left to filter
# 94.127.144.179:55649 is bad
#
# 202 proxies left to filter
# 37.228.89.215:80 is slow
#
# 201 proxies left to filter
# 46.101.246.130:3128 is bad
#
# 200 proxies left to filter
# 88.255.101.245:8080 is good
# average conn time: 4.1664988759
#
# 199 proxies left to filter
# 36.66.206.74:80 is slow
#
# 198 proxies left to filter
# 37.77.135.126:44497 is slow
#
# 197 proxies left to filter
# 45.248.138.210:59714 is good
# average conn time: 4.17329032741
#
# 196 proxies left to filter
# 35.212.155.228:3128 is good
# average conn time: 4.16232762663
#
# 195 proxies left to filter
# 35.205.239.243:3128 is good
# average conn time: 4.15211943491
#
# 194 proxies left to filter
# 206.167.181.179:3128 is bad
#
# 193 proxies left to filter
# 37.221.204.206:47424 is bad
#
# 192 proxies left to filter
# 93.91.210.140:60395 is bad
#
# 191 proxies left to filter
# 212.26.144.234:8080 is good
# average conn time: 4.14332033544
#
# 190 proxies left to filter
# 47.74.46.193:8000 is slow
#
# 189 proxies left to filter
# 203.128.92.66:8080 is good
# average conn time: 4.14160931919
#
# 188 proxies left to filter
# 219.92.37.175:80 is slow
#
# 187 proxies left to filter
# 5.228.211.189:59570 is slow
#
# 186 proxies left to filter
# 213.171.45.178:37608 is bad
#
# 185 proxies left to filter
# 60.5.254.169:8081 is slow
#
# 184 proxies left to filter
# 89.22.210.191:41258 is slow
#
# 183 proxies left to filter
# 94.136.157.85:60399 is slow
#
# 182 proxies left to filter
# 221.124.99.125:8080 is slow
#
# 181 proxies left to filter
# 203.128.68.242:53281 is bad
#
# 180 proxies left to filter
# 203.112.76.193:8080 is good
# average conn time: 4.13822477074
#
# 179 proxies left to filter
# 91.93.64.244:49905 is slow
#
# 178 proxies left to filter
# 77.94.107.148:38816 is bad
#
# 177 proxies left to filter
# 95.0.219.98:8080 is good
# average conn time: 4.14169149595
#
# 176 proxies left to filter
# 45.169.214.1:8080 is good
# average conn time: 4.14984938624
#
# 175 proxies left to filter
# 46.32.68.188:39707 is good
# average conn time: 4.14437873788
#
# 174 proxies left to filter
# 203.83.182.86:8080 is good
# average conn time: 4.14694413959
#
# 173 proxies left to filter
# 36.37.113.4:36485 is bad
#
# 172 proxies left to filter
# 80.38.223.227:80 is slow
#
# 171 proxies left to filter
# 45.121.43.14:8080 is good
# average conn time: 4.14174036496
#
# 170 proxies left to filter
# 203.128.94.102:48476 is good
# average conn time: 4.14767389835
#
# 169 proxies left to filter
# 80.211.36.44:3128 is slow
#
# 168 proxies left to filter
# 5.128.73.158:8081 is slow
#
# 167 proxies left to filter
# 77.120.5.243:80 is slow
#
# 166 proxies left to filter
# 213.226.181.86:42599 is good
# average conn time: 4.15069180675
#
# 165 proxies left to filter
# 96.9.67.45:8080 is good
# average conn time: 4.14875606901
#
# 164 proxies left to filter
# 41.139.251.102:53281 is good
# average conn time: 4.15421666525
#
# 163 proxies left to filter
# 31.184.252.69:443 is good
# average conn time: 4.14619906902
#
# 162 proxies left to filter
# 216.163.15.34:42065 is slow
#
# 161 proxies left to filter
# 41.221.148.202:8080 is slow
#
# 160 proxies left to filter
# 35.211.176.159:80 is good
# average conn time: 4.13553163537
#
# 159 proxies left to filter
# 202.75.110.114:63141 is good
# average conn time: 4.14952450855
#
# 158 proxies left to filter
# 202.166.169.19:8080 is good
# average conn time: 4.15535977339
#
# 157 proxies left to filter
# 37.247.209.179:8080 is good
# average conn time: 4.15858537599
#
# 156 proxies left to filter
# 36.67.23.117:8888 is slow
#
# 155 proxies left to filter
# 27.147.236.140:63141 is good
# average conn time: 4.15918356936
#
# 154 proxies left to filter
# 91.192.24.104:32231 is slow
#
# 153 proxies left to filter
# 59.91.122.1:54086 is slow
#
# 152 proxies left to filter
# 36.66.206.74:3128 is good
# average conn time: 4.15541670564
#
# 151 proxies left to filter
# 27.208.70.212:8060 is slow
#
# 150 proxies left to filter
# 51.77.162.148:3128 is slow
#
# 149 proxies left to filter
# 39.137.77.66:80 is slow
#
# 148 proxies left to filter
# 220.247.170.30:8080 is slow
#
# 147 proxies left to filter
# 43.245.184.202:41102 is good
# average conn time: 4.1650511938
#
# 146 proxies left to filter
# 212.34.53.150:53281 is good
# average conn time: 4.16252641438
#
# 145 proxies left to filter
# 213.159.248.165:33553 is bad
#
# 144 proxies left to filter
# 36.89.234.175:8080 is slow
#
# 143 proxies left to filter
# 217.91.89.84:3128 is bad
#
# 142 proxies left to filter
# 37.187.149.234:1080 is slow
#
# 141 proxies left to filter
# 222.165.234.147:31510 is bad
#
# 140 proxies left to filter
# 36.67.245.213:8080 is slow
#
# 139 proxies left to filter
# 41.60.209.160:8080 is slow
#
# 138 proxies left to filter
# 49.156.40.198:8080 is good
# average conn time: 4.16480122702
#
# 137 proxies left to filter
# 47.254.38.195:443 is slow
#
# 136 proxies left to filter
# 27.147.217.154:43252 is bad
#
# 135 proxies left to filter
# 61.128.208.94:3128 is slow
#
# 134 proxies left to filter
# 217.147.1.82:8080 is good
# average conn time: 4.17103594012
#
# 133 proxies left to filter
# 78.189.86.14:23500 is slow
#
# 132 proxies left to filter
# 83.12.5.154:8080 is good
# average conn time: 4.16918045794
#
# 131 proxies left to filter
# 89.185.204.188:57914 is bad
#
# 130 proxies left to filter
# 51.255.115.228:8080 is slow
#
# 129 proxies left to filter
# 61.7.186.215:8080 is slow
#
# 128 proxies left to filter
# 203.176.138.25:8080 is slow
#
# 127 proxies left to filter
# 78.60.203.75:58692 is slow
#
# 126 proxies left to filter
# 36.74.92.182:8080 is good
# average conn time: 4.17660723338
#
# 125 proxies left to filter
# 31.200.229.104:56471 is bad
#
# 124 proxies left to filter
# 42.115.98.89:8080 is good
# average conn time: 4.19076169227
#
# 123 proxies left to filter
# 90.150.185.83:57771 is slow
#
# 122 proxies left to filter
# 36.67.39.47:8080 is good
# average conn time: 4.1912163031
#
# 121 proxies left to filter
# 60.10.2.72:3128 is bad
#
# 120 proxies left to filter
# 95.154.104.153:8080 is slow
#
# 119 proxies left to filter
# 91.187.113.205:53281 is good
# average conn time: 4.19486366102
#
# 118 proxies left to filter
# 36.89.21.171:8080 is slow
#
# 117 proxies left to filter
# 45.70.106.31:8080 is slow
#
# 116 proxies left to filter
# 217.73.192.11:50890 is bad
#
# 115 proxies left to filter
# 36.91.60.66:80 is slow
#
# 114 proxies left to filter
# 43.228.221.175:53464 is slow
#
# 113 proxies left to filter
# 94.23.218.85:80 is slow
#
# 112 proxies left to filter
# 222.88.158.34:8060 is slow
#
# 111 proxies left to filter
# 46.229.187.169:53281 is bad
#
# 110 proxies left to filter
# 3.89.153.156:3128 is good
# average conn time: 4.1841185145
#
# 109 proxies left to filter
# 203.202.249.58:80 is good
# average conn time: 4.18513402237
#
# 108 proxies left to filter
# 92.38.46.217:36880 is slow
#
# 107 proxies left to filter
# 27.68.131.218:8080 is good
# average conn time: 4.18934936174
#
# 106 proxies left to filter
# 203.189.155.117:80 is good
# average conn time: 4.19336163448
#
# 105 proxies left to filter
# 5.32.131.98:53792 is bad
#
# 104 proxies left to filter
# 213.32.58.10:80 is slow
#
# 103 proxies left to filter
# 203.189.155.117:8080 is good
# average conn time: 4.1996448839
#
# 102 proxies left to filter
# 222.24.94.217:80 is slow
#
# 101 proxies left to filter
# 212.129.5.85:54321 is slow
#
# 100 proxies left to filter
# 202.79.29.250:8080 is slow
#
# 99 proxies left to filter
# 41.190.95.66:57258 is good
# average conn time: 4.21523113456
#
# 98 proxies left to filter
# 78.159.79.245:8888 is slow
#
# 97 proxies left to filter
# 43.226.12.234:8080 is good
# average conn time: 4.21313242182
#
# 96 proxies left to filter
# 96.9.83.85:60058 is bad
#
# 95 proxies left to filter
# 45.112.127.146:8080 is good
# average conn time: 4.21355930538
#
# 94 proxies left to filter
# 202.51.189.195:8080 is slow
#
# 93 proxies left to filter
# 35.198.147.143:80 is slow
#
# 92 proxies left to filter
# 35.211.4.249:80 is good
# average conn time: 4.20342309335
#
# 91 proxies left to filter
# 67.198.189.239:8888 is slow
#
# 90 proxies left to filter
# 65.210.76.8:3128 is bad
#
# 89 proxies left to filter
# 35.193.0.225:80 is good
# average conn time: 4.19438968277
#
# 88 proxies left to filter
# 95.0.35.208:8080 is good
# average conn time: 4.19224462737
#
# 87 proxies left to filter
# 96.85.35.233:3128 is slow
#
# 86 proxies left to filter
# 27.147.167.98:60510 is good
# average conn time: 4.20358489869
#
# 85 proxies left to filter
# 202.79.26.62:8080 is bad
#
# 84 proxies left to filter
# 54.37.136.149:3128 is bad
#
# 83 proxies left to filter
# 36.67.59.169:8080 is good
# average conn time: 4.21092856309
#
# 82 proxies left to filter
# 60.217.139.244:8060 is slow
#
# 81 proxies left to filter
# 5.9.233.14:8080 is good
# average conn time: 4.20262395486
#
# 80 proxies left to filter
# 202.79.31.50:8080 is good
# average conn time: 4.19864934181
#
# 79 proxies left to filter
# 27.147.255.74:8080 is good
# average conn time: 4.19791311542
#
# 78 proxies left to filter
# 92.217.150.53:3128 is good
# average conn time: 4.21707777702
#
# 77 proxies left to filter
# 85.29.136.212:8080 is slow
#
# 76 proxies left to filter
# 217.150.56.125:8080 is good
# average conn time: 4.22033582219
#
# 75 proxies left to filter
# 51.255.115.225:8080 is slow
#
# 74 proxies left to filter
# 200.116.198.148:54799 is bad
#
# 73 proxies left to filter
# 35.247.139.250:80 is good
# average conn time: 4.21452348928
#
# 72 proxies left to filter
# 203.77.239.2:8080 is good
# average conn time: 4.21703667765
#
# 71 proxies left to filter
# 222.160.35.82:8080 is slow
#
# 70 proxies left to filter
# 91.237.161.150:38169 is bad
#
# 69 proxies left to filter
# 41.190.95.92:47720 is slow
#
# 68 proxies left to filter
# 87.228.103.111:8080 is slow
#
# 67 proxies left to filter
# 203.150.187.232:8080 is good
# average conn time: 4.22021784128
#
# 66 proxies left to filter
# 46.150.174.90:53281 is bad
#
# 65 proxies left to filter
# 36.37.124.226:36179 is good
# average conn time: 4.22045037358
#
# 64 proxies left to filter
# 31.202.35.218:31680 is slow
#
# 63 proxies left to filter
# 45.71.38.77:999 is good
# average conn time: 4.22177218469
#
# 62 proxies left to filter
# 92.245.161.204:53281 is good
# average conn time: 4.23145423818
#
# 61 proxies left to filter
# 219.92.17.225:8080 is good
# average conn time: 4.22613203281
#
# 60 proxies left to filter
# 78.183.140.2:80 is good
# average conn time: 4.22226527036
#
# 59 proxies left to filter
# 5.53.116.162:8080 is good
# average conn time: 4.21874334618
#
# 58 proxies left to filter
# 91.82.42.2:43881 is slow
#
# 57 proxies left to filter
# 46.151.156.138:43480 is slow
#
# 56 proxies left to filter
# 213.59.251.247:8080 is good
# average conn time: 4.22942731763
#
# 55 proxies left to filter
# 78.131.58.83:37800 is slow
#
# 54 proxies left to filter
# 36.255.220.222:8080 is good
# average conn time: 4.2491153527
#
# 53 proxies left to filter
# 36.255.86.231:83 is slow
#
# 52 proxies left to filter
# 36.66.220.173:53850 is good
# average conn time: 4.25089573679
#
# 51 proxies left to filter
# 93.190.137.26:8080 is slow
#
# 50 proxies left to filter
# 203.77.229.124:8080 is good
# average conn time: 4.26541060089
#
# 49 proxies left to filter
# 213.6.87.158:55295 is bad
#
# 48 proxies left to filter
# 222.231.59.130:443 is slow
#
# 47 proxies left to filter
# 78.11.28.20:8080 is slow
#
# 46 proxies left to filter
# 82.85.144.92:32291 is good
# average conn time: 4.26391123404
#
# 45 proxies left to filter
# 94.242.58.108:1448 is good
# average conn time: 4.25559670602
#
# 44 proxies left to filter
# 206.189.231.239:8080 is slow
#
# 43 proxies left to filter
# 45.33.31.25:80 is slow
#
# 42 proxies left to filter
# 43.252.159.87:8080 is slow
#
# 41 proxies left to filter
# 210.11.181.221:52539 is bad
#
# 40 proxies left to filter
# 94.158.151.19:57537 is slow
#
# 39 proxies left to filter
# 222.124.173.146:53281 is slow
#
# 38 proxies left to filter
# 206.189.112.106:3128 is bad
#
# 37 proxies left to filter
# 41.77.188.38:8080 is slow
#
# 36 proxies left to filter
# 84.22.199.14:8080 is bad
#
# 35 proxies left to filter
# 37.52.15.70:8080 is bad
#
# 34 proxies left to filter
# 213.6.7.53:80 is slow
#
# 33 proxies left to filter
# 212.67.0.150:33171 is bad
#
# 32 proxies left to filter
# 200.254.125.5:80 is slow
#
# 31 proxies left to filter
# 220.227.0.209:3128 is bad
#
# 30 proxies left to filter
# 85.29.136.212:8085 is slow
#
# 29 proxies left to filter
# 94.242.59.245:10010 is good
# average conn time: 4.24752971702
#
# 28 proxies left to filter
# 83.171.113.12:44422 is bad
#
# 27 proxies left to filter
# 35.240.224.241:3128 is good
# average conn time: 4.24182336271
#
# 26 proxies left to filter
# 36.71.22.128:8080 is good
# average conn time: 4.24585460368
#
# 25 proxies left to filter
# 27.255.13.134:48613 is good
# average conn time: 4.24812816209
#
# 24 proxies left to filter
# 78.61.157.167:54572 is good
# average conn time: 4.24476422625
#
# 23 proxies left to filter
# 41.221.107.110:37557 is slow
#
# 22 proxies left to filter
# 212.47.254.202:3128 is good
# average conn time: 4.23602924075
#
# 21 proxies left to filter
# 93.175.203.124:42144 is good
# average conn time: 4.23215962045
#
# 20 proxies left to filter
# 27.208.29.93:8060 is slow
#
# 19 proxies left to filter
# 94.242.57.136:10010 is good
# average conn time: 4.22435094629
#
# 18 proxies left to filter
# 31.43.135.58:41962 is slow
#
# 17 proxies left to filter
# 217.182.120.161:8080 is good
# average conn time: 4.21612968082
#
# 16 proxies left to filter
# 50.236.148.254:39970 is bad
#
# 15 proxies left to filter
# 63.134.172.12:80 is slow
#
# 14 proxies left to filter
# 89.28.53.42:8080 is good
# average conn time: 4.21233390476
#
# 13 proxies left to filter
# 91.144.147.46:8080 is slow
#
# 12 proxies left to filter
# 60.51.17.106:80 is slow
#
# 11 proxies left to filter
# 203.246.112.133:3128 is good
# average conn time: 4.20808335971
#
# 10 proxies left to filter
# 78.62.214.242:60678 is slow
#
# 9 proxies left to filter
# 212.83.142.185:54321 is slow
#
# 8 proxies left to filter
# 95.88.12.230:3128 is bad
#
# 7 proxies left to filter
# 94.245.171.77:8080 is slow
#
# 6 proxies left to filter
# 27.208.91.77:8060 is slow
#
# 5 proxies left to filter
# 50.7.87.220:38082 is bad
#
# 4 proxies left to filter
# 37.247.108.75:3128 is slow
#
# 3 proxies left to filter
# 91.187.69.2:80 is slow
#
# 2 proxies left to filter
# 96.9.87.54:35643 is bad
#
# 1 proxies left to filter
# 91.185.255.123:8080 is good
# average conn time: 4.21688040989
#
# average proxy time:4.21688040989

# %% [markdown]
# # Filter the Http proxies

# %%
url = 'https://www.proxy-list.download/HTTP'
filterProxys(url)

# %% [markdown]
# # Overwrite the source text file with partially filtered or empty ip list

# %%
# overwrite the existing source of https proxy data with the filtered data
with open('proxyLists/https_proxys_part_2.txt', "w") as output:
    for line in testProxies['https']:
        output.write("%s\n" % line)

# %%
# overwrite the existing source of http proxy data with the filtered data
with open('proxyLists/http_proxys_part_2.txt', "w") as output:
    for line in testProxies['http']:
        output.write("%s\n" % line)

# %% [markdown]
# # Get all proxys that had connections times less than one second

# %%
df = pd.DataFrame(goodProxy['https'])
fast_proxies_https = list(df['proxy'][df['time']<1])

# %%
df = pd.DataFrame(goodProxy['http'])
fast_proxies_http = list(df['proxy'][df['time']<1])

# %% [markdown]
# # Import the single filtered files of proxys that had connections times less than one second and combine with the new filtered proxys

# %%
# Import
try:
    existing_https_proxies = list(pd.read_csv('../filtered_https_proxys.txt', header = None)[0])
except: #If the file is empty
    existing_https_proxies = []
try:
    existing_http_proxies = list(pd.read_csv('../filtered_http_proxys.txt', header = None)[0])
except: #If the file is empty
    existing_http_proxies = []

# %%
# add the new proxys to the existing ones if they are not already there
[existing_https_proxies.append(x) 
 for x in fast_proxies_https 
 if x not in existing_https_proxies]

[existing_http_proxies.append(x) 
 for x in fast_proxies_http 
 if x not in existing_http_proxies]
# Out:
# []

# %% [markdown]
# # Rewrite the final proxys text file with the new and old filtered proxies

# %%
#append filtered http proxys to existing .txt file
with open('../filtered_http_proxys.txt', "w") as output:
    for line in existing_http_proxies:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('../filtered_https_proxys.txt', "w") as output:
    for line in existing_https_proxies:
        output.write("%s\n" % line)
