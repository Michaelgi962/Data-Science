# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from fake_useragent import UserAgent
import random

# %% [markdown]
# # Import the Data

# %%
try:
    Https_txt_file = 'proxyLists/https_proxys_part_1.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
    https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
    #Convert to array
    https_proxys = https_proxys[0].values
    #Convert to list
    https_proxys = list(https_proxys)
except:
    print('There are no https proxies to import')
    
try:
    Http_txt_file = 'proxyLists/http_proxys_part_1.txt'
    #Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
    http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
    #Convert to array
    http_proxys = http_proxys[0].values
    #Convert to list
    http_proxys = list(http_proxys)
except:
    print('There are no http proxies to import')

# %%
# Make a dictionary for the proxies to test
testProxies = {'https':https_proxys,'http':http_proxys}

# %%
# Retrieve a random user-agent
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndex(conn_type):
    num = random.randint(0, len(testProxies[conn_type]) - 1)
    return num

# %%
proxyDict = {}
def randProx(conn_type):
    # Choose a single random proxy to use
    proxy_index = randomIndex(conn_type)
    proxy = testProxies[conn_type][proxy_index]
    proxyDict[conn_type] = conn_type +'://'+ proxy
    return proxy_index

# %%
# Initialize Dictionary for good proxies 
good_http_proxy = []
good_https_proxy = []
conn_time_http = []
conn_time_https = []
goodProxy = {'https':{'proxy':good_https_proxy,'time':conn_time_https},
             'http':{'proxy':good_http_proxy,'time':conn_time_http}}

# %%
def filterProxys(url):
    timer = 0
    count = 0
    if url[0:5] == 'http:':
        conn_type = 'http'
        
    elif url[0:5] == 'https':
        conn_type = 'https'

    total_proxies = len(testProxies[conn_type])
    for n in range(len(testProxies[conn_type])):
        time.sleep(1)
        print(str(total_proxies-n)+' proxies left to filter')
            
        try:
            # Choose a random header
            randHeader()
            
        except:
            # Sometimes the header reassignment function returns an error
            pass
            
        # Choose a random proxy
        proxy_index = randProx(conn_type)

        try:
            # Try to connect to the url
            t1 = time.time()
            soup = requests.get(url,headers=header,proxies=proxyDict,timeout=5)
            t2 = time.time()
            t = t2-t1
                
            if  str(soup) == '<Response [200]>': # the connection is successful when <Response [200]> is returned
                print(str(testProxies[conn_type][proxy_index])+' is good')
                del testProxies[conn_type][proxy_index]
                timer += t
                count += 1
                print('average conn time: '+str(timer/count)+'\n')
                #Add to the good proxy and its connection time
                goodProxy[conn_type]['proxy'].append(proxyDict[conn_type])
                goodProxy[conn_type]['time'].append(t)
                    
            elif str(soup) != '<Response [200]>': #The connection was bad
                print(str(testProxies[conn_type][proxy_index])+' is bad'+'\n')
                del testProxies[conn_type][proxy_index]
                    
                    
        except: # The connection took too long 
            print(str(testProxies[conn_type][proxy_index])+' is slow'+'\n')
            del testProxies[conn_type][proxy_index]
    try:
        print('average proxy time:'+str(timer/count))
    except:
        print('No proxies to text')

# %% [markdown]
# # Filter the Https proxies

# %%
url = 'https://www.proxy-list.download/HTTPS'
filterProxys(url)
# Out:
# 1180 proxies left to filter
# 191.6.25.69:20183 is good
# average conn time: 4.64425396919
#
# 1179 proxies left to filter
# 193.41.88.58:53281 is slow
#
# 1178 proxies left to filter
# 181.112.42.38:38264 is good
# average conn time: 4.60028004646
#
# 1177 proxies left to filter
# 187.18.125.34:3128 is slow
#
# 1176 proxies left to filter
# 172.245.52.197:80 is slow
#
# 1175 proxies left to filter
# 177.87.15.6:39489 is good
# average conn time: 5.68668707212
#
# 1174 proxies left to filter
# 150.242.255.210:8080 is good
# average conn time: 6.69788807631
#
# 1173 proxies left to filter
# 200.69.75.24:3128 is good
# average conn time: 5.64182724953
#
# 1172 proxies left to filter
# 200.41.148.2:8080 is good
# average conn time: 5.80338339011
#
# 1171 proxies left to filter
# 189.203.77.147:9991 is slow
#
# 1170 proxies left to filter
# 189.45.199.37:20183 is good
# average conn time: 5.36627977235
#
# 1169 proxies left to filter
# 195.88.16.155:42014 is bad
#
# 1168 proxies left to filter
# 197.155.158.22:80 is slow
#
# 1167 proxies left to filter
# 183.87.12.209:8080 is slow
#
# 1166 proxies left to filter
# 190.9.59.198:53281 is good
# average conn time: 5.40538352728
#
# 1165 proxies left to filter
# 177.101.122.178:20183 is slow
#
# 1164 proxies left to filter
# 177.152.174.141:8888 is good
# average conn time: 5.36652901438
#
# 1163 proxies left to filter
# 160.119.154.72:8080 is slow
#
# 1162 proxies left to filter
# 194.183.182.198:53281 is slow
#
# 1161 proxies left to filter
# 185.105.4.108:3128 is slow
#
# 1160 proxies left to filter
# 189.51.98.118:48704 is bad
#
# 1159 proxies left to filter
# 176.36.164.240:47581 is good
# average conn time: 5.42537541389
#
# 1158 proxies left to filter
# 192.141.110.101:8080 is good
# average conn time: 5.4499019276
#
# 1157 proxies left to filter
# 170.239.47.138:8080 is good
# average conn time: 5.47009309133
#
# 1156 proxies left to filter
# 190.184.144.146:46456 is good
# average conn time: 5.1719387678
#
# 1155 proxies left to filter
# 165.227.47.32:80 is slow
#
# 1154 proxies left to filter
# 180.180.218.111:50421 is slow
#
# 1153 proxies left to filter
# 197.234.44.113:8083 is slow
#
# 1152 proxies left to filter
# 197.234.44.137:8083 is slow
#
# 1151 proxies left to filter
# 176.74.134.6:53281 is slow
#
# 1150 proxies left to filter
# 189.196.168.78:30880 is bad
#
# 1149 proxies left to filter
# 185.132.178.152:8080 is slow
#
# 1148 proxies left to filter
# 185.90.68.87:8081 is slow
#
# 1147 proxies left to filter
# 185.108.215.213:37329 is bad
#
# 1146 proxies left to filter
# 14.207.36.51:8080 is good
# average conn time: 4.98283992495
#
# 1145 proxies left to filter
# 177.184.63.230:8080 is slow
#
# 1144 proxies left to filter
# 185.22.174.69:1448 is good
# average conn time: 4.7434073925
#
# 1143 proxies left to filter
# 160.202.131.18:8081 is slow
#
# 1142 proxies left to filter
# 190.152.71.30:58727 is slow
#
# 1141 proxies left to filter
# 196.14.52.63:35048 is good
# average conn time: 4.62105356157
#
# 1140 proxies left to filter
# 180.180.170.188:8080 is good
# average conn time: 4.61848135555
#
# 1139 proxies left to filter
# 180.183.9.3:8213 is slow
#
# 1138 proxies left to filter
# 159.224.243.185:37793 is bad
#
# 1137 proxies left to filter
# 177.1.81.114:59501 is slow
#
# 1136 proxies left to filter
# 185.61.24.205:8081 is slow
#
# 1135 proxies left to filter
# 200.35.56.161:35945 is bad
#
# 1134 proxies left to filter
# 186.46.128.90:56942 is good
# average conn time: 4.69739961624
#
# 1133 proxies left to filter
# 181.209.82.154:23500 is slow
#
# 1132 proxies left to filter
# 167.99.1.61:3128 is slow
#
# 1131 proxies left to filter
# 197.234.56.193:8083 is slow
#
# 1130 proxies left to filter
# 191.242.230.135:8080 is good
# average conn time: 4.59708452225
#
# 1129 proxies left to filter
# 200.23.125.177:80 is slow
#
# 1128 proxies left to filter
# 197.234.45.93:8083 is slow
#
# 1127 proxies left to filter
# 18.222.244.222:8080 is slow
#
# 1126 proxies left to filter
# 151.106.10.108:8080 is good
# average conn time: 4.44878129959
#
# 1125 proxies left to filter
# 181.143.10.246:57932 is bad
#
# 1124 proxies left to filter
# 186.237.221.37:8080 is good
# average conn time: 4.44652342796
#
# 1123 proxies left to filter
# 182.53.206.47:47592 is slow
#
# 1122 proxies left to filter
# 181.129.154.146:9991 is good
# average conn time: 4.38064991344
#
# 1121 proxies left to filter
# 191.37.50.24:8080 is good
# average conn time: 4.3053161787
#
# 1120 proxies left to filter
# 170.245.173.222:53281 is slow
#
# 1119 proxies left to filter
# 186.103.217.94:9991 is good
# average conn time: 4.36222617825
#
# 1118 proxies left to filter
# 177.54.142.222:8080 is slow
#
# 1117 proxies left to filter
# 193.34.140.84:57220 is slow
#
# 1116 proxies left to filter
# 165.227.35.172:8080 is good
# average conn time: 4.21939208984
#
# 1115 proxies left to filter
# 186.250.160.205:53281 is slow
#
# 1114 proxies left to filter
# 177.204.85.203:80 is slow
#
# 1113 proxies left to filter
# 193.57.74.1:8080 is slow
#
# 1112 proxies left to filter
# 194.182.73.139:8080 is slow
#
# 1111 proxies left to filter
# 173.192.21.89:25 is slow
#
# 1110 proxies left to filter
# 182.53.59.79:8080 is good
# average conn time: 4.16363631762
#
# 1109 proxies left to filter
# 178.45.194.137:8081 is slow
#
# 1108 proxies left to filter
# 202.166.211.182:61767 is slow
#
# 1107 proxies left to filter
# 177.126.81.63:20183 is good
# average conn time: 4.15697567551
#
# 1106 proxies left to filter
# 181.129.74.218:8080 is good
# average conn time: 4.26061968293
#
# 1105 proxies left to filter
# 168.232.49.223:80 is slow
#
# 1104 proxies left to filter
# 159.65.230.251:9090 is slow
#
# 1103 proxies left to filter
# 192.140.28.69:8080 is good
# average conn time: 4.30168765989
#
# 1102 proxies left to filter
# 201.140.113.90:37193 is slow
#
# 1101 proxies left to filter
# 186.233.104.25:8080 is slow
#
# 1100 proxies left to filter
# 177.206.131.211:8080 is bad
#
# 1099 proxies left to filter
# 191.97.39.48:23500 is slow
#
# 1098 proxies left to filter
# 186.64.121.235:8080 is slow
#
# 1097 proxies left to filter
# 181.52.114.30:50835 is slow
#
# 1096 proxies left to filter
# 181.191.202.4:34703 is bad
#
# 1095 proxies left to filter
# 190.153.248.205:41131 is slow
#
# 1094 proxies left to filter
# 200.23.125.230:80 is slow
#
# 1093 proxies left to filter
# 200.87.75.174:8080 is slow
#
# 1092 proxies left to filter
# 185.119.57.254:53281 is slow
#
# 1091 proxies left to filter
# 178.57.115.124:8080 is slow
#
# 1090 proxies left to filter
# 186.225.43.49:63141 is bad
#
# 1089 proxies left to filter
# 187.198.128.59:8080 is good
# average conn time: 4.3350747029
#
# 1088 proxies left to filter
# 192.99.191.237:1080 is slow
#
# 1087 proxies left to filter
# 168.253.71.149:53281 is slow
#
# 1086 proxies left to filter
# 197.232.65.35:8080 is slow
#
# 1085 proxies left to filter
# 172.92.73.61:53281 is slow
#
# 1084 proxies left to filter
# 190.107.30.115:80 is slow
#
# 1083 proxies left to filter
# 180.232.77.107:61619 is slow
#
# 1082 proxies left to filter
# 181.112.62.154:30111 is bad
#
# 1081 proxies left to filter
# 187.58.65.225:3128 is good
# average conn time: 4.28869048242
#
# 1080 proxies left to filter
# 200.123.6.26:8080 is good
# average conn time: 4.37462812662
#
# 1079 proxies left to filter
# 187.36.171.71:3128 is good
# average conn time: 4.37476336595
#
# 1078 proxies left to filter
# 190.104.8.19:8080 is good
# average conn time: 4.35582780137
#
# 1077 proxies left to filter
# 186.227.252.8:8080 is good
# average conn time: 4.29730146272
#
# 1076 proxies left to filter
# 191.7.9.152:8080 is good
# average conn time: 4.24982717302
#
# 1075 proxies left to filter
# 186.211.248.214:44385 is bad
#
# 1074 proxies left to filter
# 178.128.116.43:8080 is bad
#
# 1073 proxies left to filter
# 179.108.167.232:8080 is good
# average conn time: 4.18973495509
#
# 1072 proxies left to filter
# 182.253.217.154:53281 is good
# average conn time: 4.27422879872
#
# 1071 proxies left to filter
# 170.78.96.86:8080 is slow
#
# 1070 proxies left to filter
# 200.58.75.96:8080 is bad
#
# 1069 proxies left to filter
# 181.115.241.90:8080 is good
# average conn time: 4.24351267326
#
# 1068 proxies left to filter
# 189.203.179.18:8080 is slow
#
# 1067 proxies left to filter
# 200.23.125.218:80 is slow
#
# 1066 proxies left to filter
# 160.19.246.241:61942 is good
# average conn time: 4.36120695472
#
# 1065 proxies left to filter
# 200.23.125.186:80 is slow
#
# 1064 proxies left to filter
# 186.4.137.53:53281 is bad
#
# 1063 proxies left to filter
# 186.46.164.164:8080 is good
# average conn time: 4.3549771716
#
# 1062 proxies left to filter
# 185.132.178.143:8080 is slow
#
# 1061 proxies left to filter
# 197.234.54.5:8083 is slow
#
# 1060 proxies left to filter
# 177.11.161.8:8080 is slow
#
# 1059 proxies left to filter
# 192.140.42.83:63141 is good
# average conn time: 4.40672221638
#
# 1058 proxies left to filter
# 151.106.8.236:8080 is good
# average conn time: 4.43916228206
#
# 1057 proxies left to filter
# 177.184.63.208:8080 is slow
#
# 1056 proxies left to filter
# 186.64.121.235:80 is slow
#
# 1055 proxies left to filter
# 190.52.128.42:8888 is bad
#
# 1054 proxies left to filter
# 177.55.183.171:8080 is good
# average conn time: 4.44302027334
#
# 1053 proxies left to filter
# 177.4.168.85:53281 is slow
#
# 1052 proxies left to filter
# 187.44.1.167:8080 is good
# average conn time: 4.38115586705
#
# 1051 proxies left to filter
# 191.187.33.49:8080 is good
# average conn time: 4.46089804691
#
# 1050 proxies left to filter
# 191.253.68.72:8080 is slow
#
# 1049 proxies left to filter
# 200.8.98.7:9991 is good
# average conn time: 4.47634033954
#
# 1048 proxies left to filter
# 182.48.92.68:80 is slow
#
# 1047 proxies left to filter
# 176.214.82.14:51049 is slow
#
# 1046 proxies left to filter
# 185.132.250.246:8080 is good
# average conn time: 4.44052689771
#
# 1045 proxies left to filter
# 200.35.56.81:50205 is bad
#
# 1044 proxies left to filter
# 160.119.154.229:8080 is slow
#
# 1043 proxies left to filter
# 191.102.83.149:80 is slow
#
# 1042 proxies left to filter
# 197.234.55.137:8083 is slow
#
# 1041 proxies left to filter
# 185.210.226.14:8080 is good
# average conn time: 4.46004698228
#
# 1040 proxies left to filter
# 189.61.107.94:80 is good
# average conn time: 4.40923978329
#
# 1039 proxies left to filter
# 170.84.223.151:8080 is good
# average conn time: 4.35881147665
#
# 1038 proxies left to filter
# 193.77.45.19:21776 is bad
#
# 1037 proxies left to filter
# 186.228.147.58:20183 is slow
#
# 1036 proxies left to filter
# 195.116.41.150:39862 is good
# average conn time: 4.3680974887
#
# 1035 proxies left to filter
# 200.24.240.187:54747 is good
# average conn time: 4.3306588002
#
# 1034 proxies left to filter
# 190.109.32.243:52893 is bad
#
# 1033 proxies left to filter
# 173.192.21.89:8123 is slow
#
# 1032 proxies left to filter
# 18.144.52.51:80 is slow
#
# 1031 proxies left to filter
# 189.1.12.201:20183 is slow
#
# 1030 proxies left to filter
# 171.83.166.196:9999 is slow
#
# 1029 proxies left to filter
# 183.88.240.216:8080 is good
# average conn time: 4.38516174864
#
# 1028 proxies left to filter
# 193.48.42.82:8080 is slow
#
# 1027 proxies left to filter
# 176.125.128.155:8081 is slow
#
# 1026 proxies left to filter
# 177.8.113.61:36380 is bad
#
# 1025 proxies left to filter
# 194.60.238.167:53281 is good
# average conn time: 4.33544846015
#
# 1024 proxies left to filter
# 170.239.86.147:8080 is slow
#
# 1023 proxies left to filter
# 182.53.197.117:8080 is good
# average conn time: 4.3051171686
#
# 1022 proxies left to filter
# 178.72.74.40:34655 is slow
#
# 1021 proxies left to filter
# 186.150.197.155:3128 is good
# average conn time: 4.28913063752
#
# 1020 proxies left to filter
# 177.74.112.162:8080 is slow
#
# 1019 proxies left to filter
# 182.52.51.19:32558 is good
# average conn time: 4.29321807417
#
# 1018 proxies left to filter
# 167.114.164.13:8080 is slow
#
# 1017 proxies left to filter
# 165.227.42.21:8080 is good
# average conn time: 4.22462722811
#
# 1016 proxies left to filter
# 182.53.197.70:56053 is good
# average conn time: 4.23715302547
#
# 1015 proxies left to filter
# 185.17.134.149:36486 is bad
#
# 1014 proxies left to filter
# 18.208.129.192:3128 is good
# average conn time: 4.17353981049
#
# 1013 proxies left to filter
# 191.97.34.130:23500 is slow
#
# 1012 proxies left to filter
# 200.23.125.187:80 is slow
#
# 1011 proxies left to filter
# 181.118.159.114:80 is slow
#
# 1010 proxies left to filter
# 186.206.231.50:3128 is good
# average conn time: 4.1620739583
#
# 1009 proxies left to filter
# 180.183.52.218:8213 is slow
#
# 1008 proxies left to filter
# 182.53.197.21:54930 is bad
#
# 1007 proxies left to filter
# 202.62.11.106:8080 is slow
#
# 1006 proxies left to filter
# 190.82.82.146:49393 is bad
#
# 1005 proxies left to filter
# 182.52.51.154:38752 is bad
#
# 1004 proxies left to filter
# 189.250.78.235:8080 is slow
#
# 1003 proxies left to filter
# 195.158.107.139:3128 is slow
#
# 1002 proxies left to filter
# 167.86.91.18:3128 is good
# average conn time: 4.1100276122
#
# 1001 proxies left to filter
# 171.83.166.220:9999 is good
# average conn time: 4.09887703881
#
# 1000 proxies left to filter
# 162.245.81.238:3128 is slow
#
# 999 proxies left to filter
# 182.160.109.125:8080 is good
# average conn time: 4.12614177924
#
# 998 proxies left to filter
# 183.89.47.196:8080 is slow
#
# 997 proxies left to filter
# 185.33.113.202:443 is slow
#
# 996 proxies left to filter
# 180.180.217.136:46116 is good
# average conn time: 4.15516510154
#
# 995 proxies left to filter
# 176.226.164.140:8081 is slow
#
# 994 proxies left to filter
# 18.237.7.113:3128 is slow
#
# 993 proxies left to filter
# 165.227.35.200:443 is slow
#
# 992 proxies left to filter
# 180.183.139.80:8213 is slow
#
# 991 proxies left to filter
# 183.88.48.199:8080 is good
# average conn time: 4.15572565349
#
# 990 proxies left to filter
# 197.216.2.14:8080 is good
# average conn time: 4.13192984988
#
# 989 proxies left to filter
# 187.19.101.37:80 is slow
#
# 988 proxies left to filter
# 190.104.235.34:8080 is good
# average conn time: 4.11215663302
#
# 987 proxies left to filter
# 194.143.251.80:8080 is good
# average conn time: 4.1022284099
#
# 986 proxies left to filter
# 177.22.107.141:8080 is slow
#
# 985 proxies left to filter
# 191.241.67.226:53281 is slow
#
# 984 proxies left to filter
# 196.3.97.86:23500 is bad
#
# 983 proxies left to filter
# 181.192.2.184:8080 is good
# average conn time: 4.12486495099
#
# 982 proxies left to filter
# 202.166.220.233:8080 is good
# average conn time: 4.10272513164
#
# 981 proxies left to filter
# 182.253.26.196:8080 is slow
#
# 980 proxies left to filter
# 185.151.24.41:41579 is slow
#
# 979 proxies left to filter
# 185.132.133.214:8080 is slow
#
# 978 proxies left to filter
# 185.24.34.253:53281 is bad
#
# 977 proxies left to filter
# 186.96.102.250:9991 is good
# average conn time: 4.07235037464
#
# 976 proxies left to filter
# 190.111.233.208:53281 is slow
#
# 975 proxies left to filter
# 195.222.106.135:42374 is good
# average conn time: 4.10209051661
#
# 974 proxies left to filter
# 179.155.189.18:8080 is good
# average conn time: 4.11304802895
#
# 973 proxies left to filter
# 187.122.248.194:38889 is good
# average conn time: 4.10631122715
#
# 972 proxies left to filter
# 191.102.104.34:8181 is good
# average conn time: 4.11224310739
#
# 971 proxies left to filter
# 160.202.40.20:55655 is slow
#
# 970 proxies left to filter
# 179.57.30.10:8080 is slow
#
# 969 proxies left to filter
# 190.0.57.250:46261 is slow
#
# 968 proxies left to filter
# 201.59.200.246:80 is slow
#
# 967 proxies left to filter
# 183.88.238.243:8080 is good
# average conn time: 4.18345399086
#
# 966 proxies left to filter
# 170.245.224.148:8080 is slow
#
# 965 proxies left to filter
# 179.49.113.14:39362 is bad
#
# 964 proxies left to filter
# 194.28.89.94:46874 is slow
#
# 963 proxies left to filter
# 178.75.27.131:41879 is good
# average conn time: 4.23429586314
#
# 962 proxies left to filter
# 190.0.244.3:9991 is good
# average conn time: 4.20924367607
#
# 961 proxies left to filter
# 178.77.197.96:55555 is slow
#
# 960 proxies left to filter
# 188.166.119.186:80 is slow
#
# 959 proxies left to filter
# 197.234.55.241:8083 is slow
#
# 958 proxies left to filter
# 190.63.134.220:31499 is slow
#
# 957 proxies left to filter
# 186.192.49.60:8080 is slow
#
# 956 proxies left to filter
# 193.106.192.149:53281 is slow
#
# 955 proxies left to filter
# 201.230.5.104:8080 is slow
#
# 954 proxies left to filter
# 190.228.106.203:8080 is good
# average conn time: 4.21026865641
#
# 953 proxies left to filter
# 185.181.209.205:80 is slow
#
# 952 proxies left to filter
# 171.83.167.107:9999 is good
# average conn time: 4.1908798305
#
# 951 proxies left to filter
# 159.65.185.6:8888 is slow
#
# 950 proxies left to filter
# 163.172.98.25:80 is slow
#
# 949 proxies left to filter
# 176.215.237.135:58446 is slow
#
# 948 proxies left to filter
# 174.137.60.201:3128 is slow
#
# 947 proxies left to filter
# 191.37.183.209:60139 is bad
#
# 946 proxies left to filter
# 178.132.92.189:55135 is good
# average conn time: 4.21018219569
#
# 945 proxies left to filter
# 185.73.206.205:40662 is bad
#
# 944 proxies left to filter
# 177.92.17.50:20183 is good
# average conn time: 4.23756856294
#
# 943 proxies left to filter
# 169.255.5.174:8080 is good
# average conn time: 4.22837406327
#
# 942 proxies left to filter
# 200.60.40.3:3128 is good
# average conn time: 4.25555029581
#
# 941 proxies left to filter
# 191.33.230.115:3128 is good
# average conn time: 4.22950232714
#
# 940 proxies left to filter
# 178.128.61.38:8080 is bad
# 939 proxies left to filter
# 185.23.82.39:59248 is slow
#
# 938 proxies left to filter
# 186.56.99.103:61242 is bad
#
# 937 proxies left to filter
# 188.27.60.30:53281 is good
# average conn time: 4.22590973431
#
# 936 proxies left to filter
# 191.241.36.162:8080 is good
# average conn time: 4.24245859264
#
# 935 proxies left to filter
# 191.102.70.82:999 is slow
#
# 934 proxies left to filter
# 159.89.119.45:8080 is good
# average conn time: 4.19809803168
#
# 933 proxies left to filter
# 177.154.224.206:44488 is bad
#
# 932 proxies left to filter
# 170.84.51.74:53281 is good
# average conn time: 4.17978699915
#
# 931 proxies left to filter
# 170.239.85.58:8080 is slow
#
# 930 proxies left to filter
# 197.234.53.69:8083 is slow
#
# 929 proxies left to filter
# 187.189.27.221:9991 is good
# average conn time: 4.18537147667
#
# 928 proxies left to filter
# 159.8.114.37:80 is slow
#
# 927 proxies left to filter
# 187.21.238.147:8080 is good
# average conn time: 4.19287062204
#
# 926 proxies left to filter
# 187.17.146.25:8080 is bad
#
# 925 proxies left to filter
# 160.202.130.22:53281 is slow
#
# 924 proxies left to filter
# 170.84.68.69:8080 is good
# average conn time: 4.17288092349
#
# 923 proxies left to filter
# 193.93.216.219:23500 is bad
#
# 922 proxies left to filter
# 200.23.125.245:80 is slow
#
# 921 proxies left to filter
# 202.7.54.35:8080 is good
# average conn time: 4.19754060946
#
# 920 proxies left to filter
# 168.195.228.241:55007 is good
# average conn time: 4.20696873715
#
# 919 proxies left to filter
# 200.5.226.118:3128 is good
# average conn time: 4.26236167888
#
# 918 proxies left to filter
# 195.211.162.116:63141 is good
# average conn time: 4.30201450659
#
# 917 proxies left to filter
# 2.82.18.110:3128 is bad
#
# 916 proxies left to filter
# 187.32.239.250:8080 is good
# average conn time: 4.27966569168
#
# 915 proxies left to filter
# 197.234.45.105:8083 is slow
#
# 914 proxies left to filter
# 176.99.218.25:8081 is slow
#
# 913 proxies left to filter
# 188.95.77.33:46509 is bad
#
# 912 proxies left to filter
# 200.23.125.222:80 is slow
#
# 911 proxies left to filter
# 180.183.141.232:8213 is good
# average conn time: 4.25539703608
#
# 910 proxies left to filter
# 165.227.62.167:8080 is slow
#
# 909 proxies left to filter
# 191.103.219.225:48612 is good
# average conn time: 4.25592092712
#
# 908 proxies left to filter
# 195.112.197.210:33193 is bad
#
# 907 proxies left to filter
# 202.182.48.86:57942 is good
# average conn time: 4.2409074587
#
# 906 proxies left to filter
# 185.12.25.90:8080 is good
# average conn time: 4.34164733794
#
# 905 proxies left to filter
# 174.137.60.244:3128 is slow
#
# 904 proxies left to filter
# 169.239.223.186:8080 is good
# average conn time: 4.35235348802
#
# 903 proxies left to filter
# 186.249.213.101:53482 is slow
#
# 902 proxies left to filter
# 185.200.37.85:8080 is good
# average conn time: 4.33746814047
#
# 901 proxies left to filter
# 187.60.163.242:8081 is slow
#
# 900 proxies left to filter
# 190.166.249.44:45062 is bad
#
# 899 proxies left to filter
# 190.94.18.214:9991 is good
# average conn time: 4.35278920408
#
# 898 proxies left to filter
# 180.92.156.150:8080 is good
# average conn time: 4.3433231171
#
# 897 proxies left to filter
# 183.89.41.121:8080 is good
# average conn time: 4.32111463503
#
# 896 proxies left to filter
# 194.28.5.25:8080 is good
# average conn time: 4.30584554716
#
# 895 proxies left to filter
# 197.234.55.73:8083 is slow
#
# 894 proxies left to filter
# 168.232.20.155:8080 is good
# average conn time: 4.30446118008
#
# 893 proxies left to filter
# 200.68.13.26:57800 is slow
#
# 892 proxies left to filter
# 180.180.175.70:59692 is slow
#
# 891 proxies left to filter
# 176.9.61.85:3128 is good
# average conn time: 4.27240798924
#
# 890 proxies left to filter
# 170.246.152.106:56838 is good
# average conn time: 4.28367201771
#
# 889 proxies left to filter
# 150.129.171.158:8080 is good
# average conn time: 4.27229250427
#
# 888 proxies left to filter
# 191.241.34.210:8080 is slow
#
# 887 proxies left to filter
# 195.230.115.241:8080 is good
# average conn time: 4.27246806078
#
# 886 proxies left to filter
# 190.2.62.209:8080 is good
# average conn time: 4.28186380967
#
# 885 proxies left to filter
# 178.32.80.235:1080 is slow
#
# 884 proxies left to filter
# 191.36.244.230:51377 is bad
#
# 883 proxies left to filter
# 191.32.57.18:80 is slow
#
# 882 proxies left to filter
# 195.62.70.22:8080 is good
# average conn time: 4.28624423208
#
# 881 proxies left to filter
# 178.128.243.15:80 is slow
#
# 880 proxies left to filter
# 183.131.247.94:80 is slow
#
# 879 proxies left to filter
# 177.53.8.103:50552 is good
# average conn time: 4.30987998155
#
# 878 proxies left to filter
# 176.108.103.21:43009 is bad
#
# 877 proxies left to filter
# 183.88.22.63:8080 is good
# average conn time: 4.29980025453
#
# 876 proxies left to filter
# 120.50.14.82:8080 is slow
#
# 875 proxies left to filter
# 195.201.14.26:80 is slow
#
# 874 proxies left to filter
# 177.136.252.7:3128 is good
# average conn time: 4.27325542835
#
# 873 proxies left to filter
# 160.238.227.200:3128 is good
# average conn time: 4.25018506646
#
# 872 proxies left to filter
# 181.129.133.74:56827 is good
# average conn time: 4.32410200962
#
# 871 proxies left to filter
# 200.97.7.90:8080 is slow
#
# 870 proxies left to filter
# 200.5.226.118:80 is good
# average conn time: 4.38459155012
#
# 869 proxies left to filter
# 170.239.84.182:80 is slow
#
# 868 proxies left to filter
# 159.255.167.89:55231 is slow
#
# 867 proxies left to filter
# 170.247.156.71:8080 is slow
#
# 866 proxies left to filter
# 159.224.226.164:33803 is slow
#
# 865 proxies left to filter
# 185.41.248.161:8080 is good
# average conn time: 4.35625857842
#
# 864 proxies left to filter
# 190.45.141.88:8080 is good
# average conn time: 4.35399555775
#
# 863 proxies left to filter
# 177.200.83.218:38565 is bad
#
# 862 proxies left to filter
# 197.234.53.93:8083 is slow
#
# 861 proxies left to filter
# 182.73.56.130:37854 is good
# average conn time: 4.37485772896
#
# 860 proxies left to filter
# 195.234.215.81:33932 is bad
#
# 859 proxies left to filter
# 193.86.23.24:8080 is slow
#
# 858 proxies left to filter
# 178.69.191.120:34953 is bad
#
# 857 proxies left to filter
# 201.217.247.99:80 is slow
#
# 856 proxies left to filter
# 187.61.108.248:8080 is slow
#
# 855 proxies left to filter
# 191.97.33.94:23500 is slow
#
# 854 proxies left to filter
# 178.128.208.62:8080 is good
# average conn time: 4.3630598178
#
# 853 proxies left to filter
# 176.113.126.127:33496 is slow
#
# 852 proxies left to filter
# 177.184.136.74:20183 is slow
#
# 851 proxies left to filter
# 193.194.123.62:80 is slow
#
# 850 proxies left to filter
# 190.210.3.69:31706 is bad
#
# 849 proxies left to filter
# 162.105.95.34:1080 is slow
#
# 848 proxies left to filter
# 191.35.231.65:8080 is slow
#
# 847 proxies left to filter
# 190.61.40.162:53281 is good
# average conn time: 4.34963724369
#
# 846 proxies left to filter
# 195.144.219.155:54857 is slow
#
# 845 proxies left to filter
# 178.128.104.148:8080 is slow
#
# 844 proxies left to filter
# 188.73.8.12:48353 is bad
#
# 843 proxies left to filter
# 189.1.16.162:23500 is good
# average conn time: 4.32945333607
#
# 842 proxies left to filter
# 185.189.88.98:23500 is good
# average conn time: 4.32667116232
#
# 841 proxies left to filter
# 202.169.226.236:8080 is slow
#
# 840 proxies left to filter
# 168.228.204.250:80 is slow
#
# 839 proxies left to filter
# 182.23.107.210:3128 is bad
#
# 838 proxies left to filter
# 191.81.42.185:8080 is good
# average conn time: 4.35149992979
#
# 837 proxies left to filter
# 189.204.158.161:8080 is good
# average conn time: 4.34598366359
#
# 836 proxies left to filter
# 193.16.247.132:53281 is slow
#
# 835 proxies left to filter
# 200.69.67.75:9991 is good
# average conn time: 4.34992175752
#
# 834 proxies left to filter
# 170.79.9.54:58829 is slow
#
# 833 proxies left to filter
# 202.169.226.230:8080 is good
# average conn time: 4.36059980464
#
# 832 proxies left to filter
# 200.23.125.204:80 is slow
#
# 831 proxies left to filter
# 168.181.61.50:8080 is good
# average conn time: 4.33985193986
#
# 830 proxies left to filter
# 179.185.89.225:80 is good
# average conn time: 4.34056143584
#
# 829 proxies left to filter
# 177.43.160.224:8080 is good
# average conn time: 4.35010894081
#
# 828 proxies left to filter
# 197.234.44.125:8083 is slow
#
# 827 proxies left to filter
# 180.183.99.12:8213 is slow
#
# 826 proxies left to filter
# 195.123.221.131:8080 is good
# average conn time: 4.35702824071
#
# 825 proxies left to filter
# 159.8.114.37:25 is slow
#
# 824 proxies left to filter
# 200.23.125.149:80 is slow
#
# 823 proxies left to filter
# 187.115.199.210:80 is good
# average conn time: 4.35857794941
#
# 822 proxies left to filter
# 183.88.53.16:8080 is slow
# 821 proxies left to filter
# 185.55.111.68:8080 is good
# average conn time: 4.33958851862
#
# 820 proxies left to filter
# 190.0.244.5:9991 is good
# average conn time: 4.33876355716
#
# 819 proxies left to filter
# 201.219.213.228:8080 is good
# average conn time: 4.31614636868
#
# 818 proxies left to filter
# 188.75.138.234:61584 is slow
#
# 817 proxies left to filter
# 168.227.213.35:8080 is good
# average conn time: 4.30814247232
#
# 816 proxies left to filter
# 185.132.133.209:8080 is slow
#
# 815 proxies left to filter
# 177.36.188.179:8080 is slow
#
# 814 proxies left to filter
# 167.114.153.18:3128 is slow
#
# 813 proxies left to filter
# 201.46.24.71:8080 is good
# average conn time: 4.28656011862
#
# 812 proxies left to filter
# 191.7.209.214:8080 is slow
#
# 811 proxies left to filter
# 185.107.70.98:3128 is slow
#
# 810 proxies left to filter
# 180.180.123.68:80 is good
# average conn time: 4.29471082654
#
# 809 proxies left to filter
# 178.253.253.82:6666 is slow
#
# 808 proxies left to filter
# 177.135.114.164:3128 is good
# average conn time: 4.27881744155
#
# 807 proxies left to filter
# 178.32.80.233:1080 is slow
#
# 806 proxies left to filter
# 190.252.225.92:8080 is good
# average conn time: 4.30013167858
#
# 805 proxies left to filter
# 180.183.15.152:8213 is slow
#
# 804 proxies left to filter
# 173.249.43.105:3128 is good
# average conn time: 4.27683625902
#
# 803 proxies left to filter
# 200.255.122.174:8080 is bad
#
# 802 proxies left to filter
# 175.139.252.195:80 is slow
#
# 801 proxies left to filter
# 195.123.233.15:80 is slow
#
# 800 proxies left to filter
# 178.188.209.242:34320 is bad
#
# 799 proxies left to filter
# 176.118.51.74:33943 is slow
#
# 798 proxies left to filter
# 159.8.114.37:8123 is slow
#
# 797 proxies left to filter
# 182.150.35.173:80 is bad
#
# 796 proxies left to filter
# 157.100.28.178:3128 is good
# average conn time: 4.26592300711
#
# 795 proxies left to filter
# 190.147.137.66:43233 is bad
#
# 794 proxies left to filter
# 200.23.125.228:80 is slow
#
# 793 proxies left to filter
# 186.209.243.233:3128 is good
# average conn time: 4.28538355091
#
# 792 proxies left to filter
# 173.232.229.108:3128 is slow
#
# 791 proxies left to filter
# 195.234.87.211:53281 is bad
#
# 790 proxies left to filter
# 201.220.140.6:8080 is good
# average conn time: 4.2844282945
#
# 789 proxies left to filter
# 185.226.160.20:79 is slow
#
# 788 proxies left to filter
# 176.63.205.248:43495 is bad
#
# 787 proxies left to filter
# 201.49.37.133:80 is good
# average conn time: 4.26730913358
#
# 786 proxies left to filter
# 191.7.192.143:8080 is good
# average conn time: 4.27466416045
#
# 785 proxies left to filter
# 180.183.131.186:8080 is good
# average conn time: 4.3055535064
#
# 784 proxies left to filter
# 187.189.249.26:8080 is good
# average conn time: 4.2824669968
#
# 783 proxies left to filter
# 195.77.80.154:42402 is slow
#
# 782 proxies left to filter
# 159.65.230.251:8081 is slow
#
# 781 proxies left to filter
# 187.191.20.6:61994 is good
# average conn time: 4.27002870652
#
# 780 proxies left to filter
# 177.39.15.214:8080 is slow
#
# 779 proxies left to filter
# 177.21.14.157:999 is slow
#
# 778 proxies left to filter
# 163.19.70.250:80 is good
# average conn time: 4.2643715617
#
# 777 proxies left to filter
# 185.208.188.182:41258 is slow
#
# 776 proxies left to filter
# 192.141.110.5:3128 is good
# average conn time: 4.25187949466
#
# 775 proxies left to filter
# 177.220.188.213:8080 is slow
#
# 774 proxies left to filter
# 180.183.138.96:8080 is slow
#
# 773 proxies left to filter
# 182.52.51.29:35932 is good
# average conn time: 4.26698563672
#
# 772 proxies left to filter
# 177.10.202.67:8080 is slow
#
# 771 proxies left to filter
# 177.86.158.122:20183 is good
# average conn time: 4.26701163946
#
# 770 proxies left to filter
# 189.229.60.24:8081 is good
# average conn time: 4.26034332961
#
# 769 proxies left to filter
# 193.169.45.18:8080 is good
# average conn time: 4.241585887
#
# 768 proxies left to filter
# 170.81.169.222:8080 is good
# average conn time: 4.24810322714
#
# 767 proxies left to filter
# 170.82.93.255:8080 is good
# average conn time: 4.29590814684
#
# 766 proxies left to filter
# 196.41.102.130:37540 is good
# average conn time: 4.29608056022
#
# 765 proxies left to filter
# 185.50.56.230:32231 is slow
#
# 764 proxies left to filter
# 202.79.29.148:8080 is good
# average conn time: 4.30464036392
#
# 763 proxies left to filter
# 182.253.82.155:38746 is slow
#
# 762 proxies left to filter
# 194.9.26.243:38391 is slow
#
# 761 proxies left to filter
# 181.143.71.235:8080 is good
# average conn time: 4.31073751938
#
# 760 proxies left to filter
# 200.23.125.173:80 is slow
#
# 759 proxies left to filter
# 144.48.110.39:41674 is bad
#
# 758 proxies left to filter
# 177.221.95.118:8080 is good
# average conn time: 4.30277937758
#
# 757 proxies left to filter
# 176.192.51.222:36252 is good
# average conn time: 4.30694424396
#
# 756 proxies left to filter
# 159.89.195.233:80 is slow
#
# 755 proxies left to filter
# 185.255.46.100:30678 is bad
#
# 754 proxies left to filter
# 174.137.58.19:3128 is slow
#
# 753 proxies left to filter
# 194.8.136.62:55155 is bad
#
# 752 proxies left to filter
# 174.137.52.85:3128 is slow
#
# 751 proxies left to filter
# 171.83.165.241:9999 is slow
#
# 750 proxies left to filter
# 182.160.104.213:8080 is good
# average conn time: 4.31444617136
#
# 749 proxies left to filter
# 202.29.210.166:36921 is bad
#
# 748 proxies left to filter
# 178.148.52.62:53281 is bad
#
# 747 proxies left to filter
# 185.255.46.2:8080 is good
# average conn time: 4.3157881891
#
# 746 proxies left to filter
# 165.227.47.32:3128 is slow
#
# 745 proxies left to filter
# 167.99.1.61:8080 is slow
#
# 744 proxies left to filter
# 170.239.84.182:8080 is slow
#
# 743 proxies left to filter
# 185.17.18.133:53281 is slow
#
# 742 proxies left to filter
# 167.114.153.18:8080 is slow
#
# 741 proxies left to filter
# 181.111.235.203:8080 is good
# average conn time: 4.32049779028
#
# 740 proxies left to filter
# 159.192.249.121:8080 is slow
#
# 739 proxies left to filter
# 182.52.51.4:40347 is bad
#
# 738 proxies left to filter
# 180.183.99.55:8213 is slow
#
# 737 proxies left to filter
# 181.225.109.154:80 is slow
#
# 736 proxies left to filter
# 194.246.105.51:41258 is slow
#
# 735 proxies left to filter
# 180.214.250.242:8080 is slow
#
# 734 proxies left to filter
# 168.232.198.35:42267 is bad
#
# 733 proxies left to filter
# 189.91.157.13:8080 is good
# average conn time: 4.31296679724
#
# 732 proxies left to filter
# 159.253.168.249:53281 is slow
#
# 731 proxies left to filter
# 181.129.145.34:63141 is good
# average conn time: 4.32583641179
#
# 730 proxies left to filter
# 167.99.1.61:80 is slow
#
# 729 proxies left to filter
# 185.200.189.250:8080 is good
# average conn time: 4.41164386272
#
# 728 proxies left to filter
# 202.5.42.133:56632 is good
# average conn time: 4.4224522468
#
# 727 proxies left to filter
# 159.192.97.181:23500 is bad
#
# 726 proxies left to filter
# 160.119.131.142:8080 is good
# average conn time: 4.44305714965
#
# 725 proxies left to filter
# 175.23.79.241:8080 is slow
#
# 724 proxies left to filter
# 191.253.105.134:53281 is good
# average conn time: 4.44872992322
#
# 723 proxies left to filter
# 177.184.206.238:39508 is good
# average conn time: 4.43709274892
#
# 722 proxies left to filter
# 182.253.188.178:8080 is good
# average conn time: 4.42950731549
#
# 721 proxies left to filter
# 162.211.126.220:443 is slow
#
# 720 proxies left to filter
# 175.20.147.57:8080 is slow
#
# 719 proxies left to filter
# 163.172.43.27:80 is slow
#
# 718 proxies left to filter
# 178.216.24.80:53281 is slow
#
# 717 proxies left to filter
# 177.23.104.114:48021 is bad
#
# 716 proxies left to filter
# 182.52.31.58:8080 is slow
#
# 715 proxies left to filter
# 192.99.191.234:1080 is slow
#
# 714 proxies left to filter
# 185.82.98.51:53281 is good
# average conn time: 4.44976469146
#
# 713 proxies left to filter
# 200.37.246.21:8080 is slow
#
# 712 proxies left to filter
# 145.255.6.171:31252 is bad
#
# 711 proxies left to filter
# 195.211.242.182:21776 is good
# average conn time: 4.44906059945
#
# 710 proxies left to filter
# 198.50.172.163:1080 is slow
#
# 709 proxies left to filter
# 190.0.35.170:9991 is good
# average conn time: 4.4720434422
#
# 708 proxies left to filter
# 190.104.245.57:8080 is slow
#
# 707 proxies left to filter
# 178.128.114.244:3128 is good
# average conn time: 4.45895027072
#
# 706 proxies left to filter
# 176.215.255.190:32851 is bad
#
# 705 proxies left to filter
# 190.249.157.89:56294 is bad
#
# 704 proxies left to filter
# 182.52.51.18:31218 is bad
#
# 703 proxies left to filter
# 182.52.134.118:37848 is bad
#
# 702 proxies left to filter
# 159.89.83.140:80 is slow
#
# 701 proxies left to filter
# 189.90.255.208:3128 is bad
# 700 proxies left to filter
# 170.239.84.152:443 is slow
#
# 699 proxies left to filter
# 176.192.124.131:39326 is bad
#
# 698 proxies left to filter
# 185.132.179.111:8080 is slow
#
# 697 proxies left to filter
# 169.0.92.50:8080 is good
# average conn time: 4.45998456815
#
# 696 proxies left to filter
# 202.52.114.67:35066 is bad
#
# 695 proxies left to filter
# 185.198.184.14:48122 is slow
#
# 694 proxies left to filter
# 188.190.59.91:8080 is good
# average conn time: 4.47843730514
#
# 693 proxies left to filter
# 174.136.111.210:8080 is slow
#
# 692 proxies left to filter
# 181.129.56.90:46840 is slow
#
# 691 proxies left to filter
# 177.36.58.242:20183 is good
# average conn time: 4.47583119075
#
# 690 proxies left to filter
# 163.172.153.70:8080 is slow
#
# 689 proxies left to filter
# 200.23.125.170:80 is slow
#
# 688 proxies left to filter
# 193.56.149.229:33581 is bad
#
# 687 proxies left to filter
# 201.17.23.75:3128 is good
# average conn time: 4.4595376285
#
# 686 proxies left to filter
# 197.234.53.33:8083 is slow
#
# 685 proxies left to filter
# 190.85.138.3:47199 is bad
#
# 684 proxies left to filter
# 168.232.135.229:8080 is slow
#
# 683 proxies left to filter
# 181.168.206.106:38024 is slow
#
# 682 proxies left to filter
# 193.27.208.137:42618 is slow
#
# 681 proxies left to filter
# 187.4.249.6:80 is good
# average conn time: 4.44896504093
#
# 680 proxies left to filter
# 183.182.101.32:54107 is bad
#
# 679 proxies left to filter
# 182.52.132.43:54879 is good
# average conn time: 4.46600423162
#
# 678 proxies left to filter
# 200.23.125.135:80 is slow
#
# 677 proxies left to filter
# 159.65.120.133:3128 is slow
#
# 676 proxies left to filter
# 189.7.17.100:8080 is good
# average conn time: 4.46495859874
#
# 675 proxies left to filter
# 197.234.43.89:8083 is slow
#
# 674 proxies left to filter
# 194.126.183.141:53281 is bad
#
# 673 proxies left to filter
# 160.238.176.53:8080 is slow
#
# 672 proxies left to filter
# 179.222.67.94:8080 is good
# average conn time: 4.46435561605
#
# 671 proxies left to filter
# 191.7.204.82:3128 is bad
#
# 670 proxies left to filter
# 180.180.124.248:60098 is good
# average conn time: 4.49062656611
#
# 669 proxies left to filter
# 201.90.36.194:3128 is bad
#
# 668 proxies left to filter
# 194.186.131.38:47532 is bad
#
# 667 proxies left to filter
# 182.52.132.37:8080 is good
# average conn time: 4.47803460502
#
# 666 proxies left to filter
# 176.113.125.11:8080 is slow
#
# 665 proxies left to filter
# 180.183.103.63:8213 is slow
#
# 664 proxies left to filter
# 177.87.63.20:8080 is slow
#
# 663 proxies left to filter
# 200.23.125.159:80 is slow
#
# 662 proxies left to filter
# 200.23.125.212:80 is slow
#
# 661 proxies left to filter
# 134.119.205.163:1080 is bad
#
# 660 proxies left to filter
# 169.38.111.13:3128 is slow
#
# 659 proxies left to filter
# 187.153.135.185:3128 is good
# average conn time: 4.47433398802
#
# 658 proxies left to filter
# 193.86.125.62:61423 is good
# average conn time: 4.48327778303
#
# 657 proxies left to filter
# 177.185.78.135:3128 is good
# average conn time: 4.46862490688
#
# 656 proxies left to filter
# 181.129.75.99:999 is slow
#
# 655 proxies left to filter
# 180.183.40.34:8213 is slow
#
# 654 proxies left to filter
# 171.35.184.234:8118 is slow
#
# 653 proxies left to filter
# 187.63.82.55:51769 is slow
#
# 652 proxies left to filter
# 188.166.222.152:3128 is slow
#
# 651 proxies left to filter
# 185.89.180.196:8080 is slow
#
# 650 proxies left to filter
# 178.128.173.108:80 is slow
#
# 649 proxies left to filter
# 177.234.161.42:8080 is good
# average conn time: 4.47008478097
#
# 648 proxies left to filter
# 165.255.202.157:8080 is slow
#
# 647 proxies left to filter
# 198.143.181.73:3128 is good
# average conn time: 4.44977818595
#
# 646 proxies left to filter
# 200.23.125.220:80 is slow
#
# 645 proxies left to filter
# 159.69.211.173:3128 is slow
#
# 644 proxies left to filter
# 159.65.148.128:8080 is slow
#
# 643 proxies left to filter
# 202.179.190.210:8080 is good
# average conn time: 4.44963471255
#
# 642 proxies left to filter
# 157.230.98.234:80 is slow
#
# 641 proxies left to filter
# 168.228.229.234:8080 is good
# average conn time: 4.44380160928
#
# 640 proxies left to filter
# 187.188.168.57:9991 is good
# average conn time: 4.43457867613
#
# 639 proxies left to filter
# 192.140.29.218:60514 is good
# average conn time: 4.43529322242
#
# 638 proxies left to filter
# 186.211.106.227:34334 is slow
#
# 637 proxies left to filter
# 201.159.104.26:8080 is good
# average conn time: 4.42138666942
#
# 636 proxies left to filter
# 185.121.2.31:8080 is good
# average conn time: 4.42565393097
#
# 635 proxies left to filter
# 200.37.231.66:8080 is good
# average conn time: 4.41389602452
#
# 634 proxies left to filter
# 171.83.167.220:9999 is good
# average conn time: 4.40589822843
#
# 633 proxies left to filter
# 190.113.225.250:53780 is bad
#
# 632 proxies left to filter
# 168.195.18.6:63141 is good
# average conn time: 4.39623669611
#
# 631 proxies left to filter
# 200.37.54.10:43063 is bad
#
# 630 proxies left to filter
# 200.49.54.182:80 is good
# average conn time: 4.39684095291
#
# 629 proxies left to filter
# 188.75.3.10:39738 is bad
#
# 628 proxies left to filter
# 186.250.213.225:60774 is good
# average conn time: 4.39180749455
#
# 627 proxies left to filter
# 186.125.59.8:59050 is bad
#
# 626 proxies left to filter
# 186.68.85.26:53281 is bad
#
# 625 proxies left to filter
# 180.183.5.51:8080 is good
# average conn time: 4.39363678296
#
# 624 proxies left to filter
# 185.132.178.209:8080 is bad
#
# 623 proxies left to filter
# 179.97.46.58:49058 is bad
#
# 622 proxies left to filter
# 200.5.32.211:8080 is good
# average conn time: 4.39494000227
#
# 621 proxies left to filter
# 191.241.38.42:42104 is bad
#
# 620 proxies left to filter
# 192.187.97.250:3128 is slow
#
# 619 proxies left to filter
# 193.38.139.101:80 is slow
#
# 618 proxies left to filter
# 163.53.150.138:45693 is slow
#
# 617 proxies left to filter
# 190.211.115.66:32474 is bad
#
# 616 proxies left to filter
# 194.114.129.131:51742 is slow
#
# 615 proxies left to filter
# 177.223.49.60:8080 is good
# average conn time: 4.4145911156
#
# 614 proxies left to filter
# 181.27.62.122:8080 is slow
#
# 613 proxies left to filter
# 187.123.94.92:3128 is slow
#
# 612 proxies left to filter
# 182.48.92.68:8080 is good
# average conn time: 4.40558495992
#
# 611 proxies left to filter
# 202.7.54.83:8080 is good
# average conn time: 4.40910606741
#
# 610 proxies left to filter
# 194.29.60.48:45416 is good
# average conn time: 4.41099498771
#
# 609 proxies left to filter
# 182.52.238.119:40456 is slow
#
# 608 proxies left to filter
# 199.27.95.234:35655 is slow
#
# 607 proxies left to filter
# 182.52.131.69:8080 is slow
#
# 606 proxies left to filter
# 177.184.63.81:8080 is slow
#
# 605 proxies left to filter
# 177.46.147.94:44883 is slow
#
# 604 proxies left to filter
# 200.23.125.252:80 is slow
#
# 603 proxies left to filter
# 180.183.128.204:8213 is slow
#
# 602 proxies left to filter
# 185.132.173.18:41258 is slow
#
# 601 proxies left to filter
# 200.35.53.117:32628 is slow
#
# 600 proxies left to filter
# 159.65.130.145:8080 is good
# average conn time: 4.46703489511
#
# 599 proxies left to filter
# 183.88.240.126:8080 is slow
#
# 598 proxies left to filter
# 200.23.125.153:80 is slow
#
# 597 proxies left to filter
# 185.51.36.152:41258 is bad
#
# 596 proxies left to filter
# 194.61.71.236:33813 is bad
#
# 595 proxies left to filter
# 171.255.192.118:8080 is slow
#
# 594 proxies left to filter
# 189.112.212.6:32373 is good
# average conn time: 4.47694964233
#
# 593 proxies left to filter
# 159.192.101.8:80 is good
# average conn time: 4.47570254278
#
# 592 proxies left to filter
# 187.33.88.178:20183 is slow
#
# 591 proxies left to filter
# 193.70.52.233:80 is slow
#
# 590 proxies left to filter
# 195.191.131.150:42911 is slow
#
# 589 proxies left to filter
# 180.211.172.151:57828 is good
# average conn time: 4.48363840852
#
# 588 proxies left to filter
# 181.196.245.78:8080 is slow
#
# 587 proxies left to filter
# 179.185.4.1:34693 is slow
#
# 586 proxies left to filter
# 190.202.130.246:8080 is good
# average conn time: 4.47510806647
#
# 585 proxies left to filter
# 176.53.2.122:8080 is slow
#
# 584 proxies left to filter
# 168.227.56.57:8080 is slow
#
# 583 proxies left to filter
# 200.69.83.154:8080 is good
# average conn time: 4.49846255078
#
# 582 proxies left to filter
# 185.107.50.1:8080 is slow
#
# 581 proxies left to filter
# 200.23.125.234:80 is slow
#
# 580 proxies left to filter
# 192.140.91.212:38812 is good
# average conn time: 4.49597523771
#
# 579 proxies left to filter
# 160.119.130.10:23500 is good
# average conn time: 4.49664157282
#
# 578 proxies left to filter
# 186.42.185.94:31588 is good
# average conn time: 4.48911776607
#
# 577 proxies left to filter
# 157.230.249.84:80 is slow
#
# 576 proxies left to filter
# 186.227.67.143:42813 is bad
#
# 575 proxies left to filter
# 159.65.164.58:80 is slow
#
# 574 proxies left to filter
# 185.122.44.218:40308 is bad
#
# 573 proxies left to filter
# 182.52.90.79:8080 is slow
#
# 572 proxies left to filter
# 169.239.46.92:8080 is slow
#
# 571 proxies left to filter
# 190.60.222.58:9991 is good
# average conn time: 4.49115785175
#
# 570 proxies left to filter
# 190.107.140.249:8080 is good
# average conn time: 4.48966456409
#
# 569 proxies left to filter
# 190.0.246.205:8080 is slow
#
# 568 proxies left to filter
# 191.253.106.89:8080 is good
# average conn time: 4.48823760575
#
# 567 proxies left to filter
# 171.83.167.112:9999 is slow
#
# 566 proxies left to filter
# 178.128.22.210:8080 is bad
#
# 565 proxies left to filter
# 177.136.185.200:80 is slow
#
# 564 proxies left to filter
# 186.96.117.190:9991 is slow
#
# 563 proxies left to filter
# 168.196.223.74:8080 is good
# average conn time: 4.49528581845
#
# 562 proxies left to filter
# 176.113.144.248:8080 is good
# average conn time: 4.48775355368
#
# 561 proxies left to filter
# 185.132.133.206:8080 is slow
#
# 560 proxies left to filter
# 185.132.178.201:8080 is slow
#
# 559 proxies left to filter
# 185.6.167.99:51123 is bad
#
# 558 proxies left to filter
# 182.23.12.50:8080 is good
# average conn time: 4.51006275571
#
# 557 proxies left to filter
# 191.102.106.1:8181 is good
# average conn time: 4.49486426254
#
# 556 proxies left to filter
# 169.159.132.30:8080 is good
# average conn time: 4.50724474829
#
# 555 proxies left to filter
# 190.114.254.203:8080 is slow
#
# 554 proxies left to filter
# 154.72.78.62:46118 is slow
#
# 553 proxies left to filter
# 185.132.179.108:8080 is slow
#
# 552 proxies left to filter
# 187.102.54.211:8080 is slow
#
# 551 proxies left to filter
# 162.220.204.122:53281 is slow
#
# 550 proxies left to filter
# 185.80.32.201:55328 is bad
#
# 549 proxies left to filter
# 195.123.212.199:56945 is bad
#
# 548 proxies left to filter
# 169.239.167.4:59068 is slow
#
# 547 proxies left to filter
# 183.88.173.125:8080 is good
# average conn time: 4.50027671495
#
# 546 proxies left to filter
# 180.183.47.70:8213 is slow
#
# 545 proxies left to filter
# 170.254.58.201:80 is good
# average conn time: 4.48475542537
#
# 544 proxies left to filter
# 193.165.151.62:54634 is bad
#
# 543 proxies left to filter
# 177.158.146.5:8080 is slow
#
# 542 proxies left to filter
# 194.186.173.6:54842 is bad
#
# 541 proxies left to filter
# 186.46.120.230:52108 is bad
#
# 540 proxies left to filter
# 181.143.99.18:8080 is good
# average conn time: 4.48352578549
#
# 539 proxies left to filter
# 197.234.56.1:8083 is slow
#
# 538 proxies left to filter
# 186.224.229.105:49820 is bad
#
# 537 proxies left to filter
# 197.234.56.241:8083 is slow
#
# 536 proxies left to filter
# 200.23.125.193:80 is slow
#
# 535 proxies left to filter
# 181.115.241.90:80 is good
# average conn time: 4.49259223978
#
# 534 proxies left to filter
# 195.208.36.45:35531 is slow
#
# 533 proxies left to filter
# 176.37.144.39:8080 is good
# average conn time: 4.50033502337
#
# 532 proxies left to filter
# 197.234.44.29:8083 is slow
#
# 531 proxies left to filter
# 170.244.106.238:8080 is good
# average conn time: 4.50213902838
#
# 530 proxies left to filter
# 200.85.123.154:53281 is slow
#
# 529 proxies left to filter
# 181.115.168.45:40320 is slow
#
# 528 proxies left to filter
# 186.235.123.216:8080 is good
# average conn time: 4.4991712241
#
# 527 proxies left to filter
# 194.12.121.100:61600 is slow
#
# 526 proxies left to filter
# 196.43.235.229:53644 is slow
#
# 525 proxies left to filter
# 167.99.215.245:3128 is slow
#
# 524 proxies left to filter
# 162.144.220.192:80 is slow
#
# 523 proxies left to filter
# 185.251.33.194:39613 is bad
#
# 522 proxies left to filter
# 177.185.221.35:21776 is slow
#
# 521 proxies left to filter
# 185.226.160.20:80 is slow
#
# 520 proxies left to filter
# 200.23.125.154:80 is slow
#
# 519 proxies left to filter
# 197.234.53.129:8083 is slow
#
# 518 proxies left to filter
# 191.36.192.196:3128 is good
# average conn time: 4.495156311
#
# 517 proxies left to filter
# 180.183.55.132:8213 is slow
#
# 516 proxies left to filter
# 200.23.125.239:80 is slow
#
# 515 proxies left to filter
# 188.130.240.221:45787 is slow
#
# 514 proxies left to filter
# 191.98.181.174:41619 is slow
#
# 513 proxies left to filter
# 200.23.125.216:80 is slow
#
# 512 proxies left to filter
# 194.242.98.254:60281 is slow
#
# 511 proxies left to filter
# 189.149.227.225:8080 is good
# average conn time: 4.49960152935
#
# 510 proxies left to filter
# 182.52.51.47:45440 is good
# average conn time: 4.499188234
#
# 509 proxies left to filter
# 171.5.17.22:8080 is good
# average conn time: 4.50991832768
#
# 508 proxies left to filter
# 170.210.80.241:3128 is good
# average conn time: 4.50433103569
#
# 507 proxies left to filter
# 154.57.4.154:80 is slow
#
# 506 proxies left to filter
# 194.187.219.146:61026 is slow
#
# 505 proxies left to filter
# 185.146.112.142:8080 is bad
#
# 504 proxies left to filter
# 181.129.58.203:40206 is slow
#
# 503 proxies left to filter
# 200.23.125.160:80 is slow
#
# 502 proxies left to filter
# 182.253.31.86:8080 is slow
#
# 501 proxies left to filter
# 186.159.3.49:41589 is slow
#
# 500 proxies left to filter
# 163.125.65.180:9797 is slow
#
# 499 proxies left to filter
# 196.13.208.23:8080 is slow
#
# 498 proxies left to filter
# 186.153.2.174:8080 is slow
#
# 497 proxies left to filter
# 163.125.65.181:9797 is slow
#
# 496 proxies left to filter
# 181.113.123.98:36494 is bad
#
# 495 proxies left to filter
# 185.200.37.77:8080 is slow
#
# 494 proxies left to filter
# 157.230.243.138:8080 is slow
#
# 493 proxies left to filter
# 178.34.21.69:8081 is slow
#
# 492 proxies left to filter
# 183.89.136.54:8080 is slow
#
# 491 proxies left to filter
# 182.253.67.42:8080 is slow
#
# 490 proxies left to filter
# 193.239.101.74:32231 is good
# average conn time: 4.49736283166
#
# 489 proxies left to filter
# 186.59.181.32:80 is good
# average conn time: 4.4993340562
#
# 488 proxies left to filter
# 157.119.207.35:8080 is slow
#
# 487 proxies left to filter
# 200.23.125.151:80 is slow
#
# 486 proxies left to filter
# 170.254.229.154:58225 is bad
#
# 485 proxies left to filter
# 185.136.150.201:52427 is slow
#
# 484 proxies left to filter
# 181.129.52.155:55429 is slow
#
# 483 proxies left to filter
# 193.43.228.254:53744 is slow
#
# 482 proxies left to filter
# 200.69.78.91:63141 is slow
#
# 481 proxies left to filter
# 187.44.146.114:33120 is good
# average conn time: 4.50231626256
#
# 480 proxies left to filter
# 200.79.180.115:8080 is slow
#
# 479 proxies left to filter
# 197.216.2.12:8080 is good
# average conn time: 4.49353442269
#
# 478 proxies left to filter
# 180.180.8.34:80 is good
# average conn time: 4.49402687827
#
# 477 proxies left to filter
# 190.3.117.18:8080 is slow
#
# 476 proxies left to filter
# 179.124.19.9:41058 is slow
#
# 475 proxies left to filter
# 187.49.95.202:9090 is slow
#
# 474 proxies left to filter
# 195.46.122.165:59472 is bad
#
# 473 proxies left to filter
# 181.48.213.158:34481 is slow
#
# 472 proxies left to filter
# 200.146.212.209:48706 is bad
#
# 471 proxies left to filter
# 185.11.199.190:3128 is slow
#
# 470 proxies left to filter
# 200.23.125.175:80 is slow
#
# 469 proxies left to filter
# 194.44.236.48:36506 is bad
#
# 468 proxies left to filter
# 200.23.125.198:80 is slow
#
# 467 proxies left to filter
# 177.54.200.10:32120 is good
# ...
#
# 238 proxies left to filter
# 176.98.80.187:36394 is slow
#
# 237 proxies left to filter
# 186.42.252.46:57367 is good
# average conn time: 4.40610995152
#
# 236 proxies left to filter
# 182.16.161.206:8080 is good
# average conn time: 4.40511474651
#
# 235 proxies left to filter
# 186.38.39.22:39524 is slow
#
# 234 proxies left to filter
# 202.54.169.235:8080 is slow
#
# 233 proxies left to filter
# 180.183.135.211:8213 is slow
#
# 232 proxies left to filter
# 202.158.11.170:80 is slow
#
# 231 proxies left to filter
# 197.234.56.129:8083 is slow
#
# 230 proxies left to filter
# 190.152.182.150:53281 is good
# average conn time: 4.41236261318
#
# 229 proxies left to filter
# 176.101.177.77:8080 is good
# average conn time: 4.41287082416
#
# 228 proxies left to filter
# 175.29.195.22:3128 is good
# average conn time: 4.41636064787
#
# 227 proxies left to filter
# 192.166.219.46:3128 is slow
#
# 226 proxies left to filter
# 179.107.97.178:3128 is slow
#
# 225 proxies left to filter
# 159.65.11.196:8080 is slow
#
# 224 proxies left to filter
# 197.159.29.182:48761 is slow
#
# 223 proxies left to filter
# 159.69.209.169:80 is slow
#
# 222 proxies left to filter
# 134.196.244.120:46425 is slow
#
# 221 proxies left to filter
# 159.89.151.66:80 is slow
#
# 220 proxies left to filter
# 196.3.97.71:23500 is good
# average conn time: 4.41516920242
#
# 219 proxies left to filter
# 188.27.137.163:30987 is bad
#
# 218 proxies left to filter
# 191.102.101.75:8080 is good
# average conn time: 4.41171963229
#
# 217 proxies left to filter
# 177.99.95.218:8080 is good
# average conn time: 4.41184832246
#
# 216 proxies left to filter
# 200.59.189.69:8080 is slow
#
# 215 proxies left to filter
# 197.255.152.20:56045 is slow
#
# 214 proxies left to filter
# 165.227.29.189:8080 is slow
#
# 213 proxies left to filter
# 195.189.90.18:8080 is good
# average conn time: 4.40504803671
#
# 212 proxies left to filter
# 197.211.3.238:8080 is slow
#
# 211 proxies left to filter
# 185.141.25.174:8080 is slow
#
# 210 proxies left to filter
# 190.60.69.202:8080 is bad
#
# 209 proxies left to filter
# 189.194.93.227:8080 is good
# average conn time: 4.39851535767
#
# 208 proxies left to filter
# 178.124.152.84:53879 is good
# average conn time: 4.40212823663
#
# 207 proxies left to filter
# 159.224.83.100:8080 is slow
#
# 206 proxies left to filter
# 187.66.74.160:8080 is slow
#
# 205 proxies left to filter
# 190.81.162.134:53281 is good
# average conn time: 4.39592492546
#
# 204 proxies left to filter
# 185.144.156.183:3128 is slow
#
# 203 proxies left to filter
# 182.52.51.43:53275 is slow
#
# 202 proxies left to filter
# 167.99.74.12:8080 is good
# average conn time: 4.38947992569
#
# 201 proxies left to filter
# 181.115.185.42:8080 is slow
#
# 200 proxies left to filter
# 185.132.133.203:8080 is good
# average conn time: 4.38901246101
#
# 199 proxies left to filter
# 185.62.190.60:8080 is slow
#
# 198 proxies left to filter
# 183.89.120.77:8081 is good
# average conn time: 4.38976659007
#
# 197 proxies left to filter
# 177.193.9.203:3128 is slow
#
# 196 proxies left to filter
# 179.127.155.4:8080 is good
# average conn time: 4.38556407002
#
# 195 proxies left to filter
# 176.98.76.210:37951 is good
# average conn time: 4.38098642397
#
# 194 proxies left to filter
# 194.87.151.3:53281 is good
# average conn time: 4.37721364972
#
# 193 proxies left to filter
# 186.237.131.122:8080 is slow
#
# 192 proxies left to filter
# 194.190.93.136:56574 is slow
#
# 191 proxies left to filter
# 182.53.206.44:45900 is good
# average conn time: 4.37397734679
#
# 190 proxies left to filter
# 186.193.26.106:3128 is bad
#
# 189 proxies left to filter
# 185.26.219.34:59821 is bad
#
# 188 proxies left to filter
# 165.227.67.144:8000 is slow
#
# 187 proxies left to filter
# 162.245.213.92:54494 is bad
#
# 186 proxies left to filter
# 179.52.25.198:8080 is good
# average conn time: 4.36851174386
#
# 185 proxies left to filter
# 190.2.8.193:8080 is good
# average conn time: 4.36597476403
#
# 184 proxies left to filter
# 187.111.90.89:53281 is good
# average conn time: 4.36309798074
#
# 183 proxies left to filter
# 177.66.52.237:41366 is good
# average conn time: 4.36080119623
#
# 182 proxies left to filter
# 159.192.96.185:8080 is good
# average conn time: 4.35620772215
#
# 181 proxies left to filter
# 197.234.54.13:8083 is slow
#
# 180 proxies left to filter
# 189.50.145.18:8080 is slow
#
# 179 proxies left to filter
# 200.23.125.254:80 is slow
#
# 178 proxies left to filter
# 180.210.205.199:8888 is slow
#
# 177 proxies left to filter
# 182.253.93.3:53281 is slow
#
# 176 proxies left to filter
# 180.183.100.136:8213 is slow
#
# 175 proxies left to filter
# 175.110.96.246:8080 is slow
#
# 174 proxies left to filter
# 165.227.67.144:80 is slow
#
# 173 proxies left to filter
# 200.23.125.194:80 is slow
#
# 172 proxies left to filter
# 178.32.80.239:1080 is slow
#
# 171 proxies left to filter
# 196.202.229.6:8080 is good
# average conn time: 4.35798249467
#
# 170 proxies left to filter
# 188.255.252.143:43072 is bad
#
# 169 proxies left to filter
# 200.23.125.183:80 is slow
#
# 168 proxies left to filter
# 200.23.125.189:80 is slow
#
# 167 proxies left to filter
# 167.99.75.117:8080 is good
# average conn time: 4.36209561923
#
# 166 proxies left to filter
# 175.110.96.198:8080 is slow
#
# 165 proxies left to filter
# 175.100.72.95:59728 is good
# average conn time: 4.36499088514
#
# 164 proxies left to filter
# 180.183.53.170:8080 is good
# average conn time: 4.36555814418
#
# 163 proxies left to filter
# 202.70.74.37:8080 is slow
#
# 162 proxies left to filter
# 187.18.10.106:8080 is slow
#
# 161 proxies left to filter
# 186.96.102.254:9991 is good
# average conn time: 4.36450690485
#
# 160 proxies left to filter
# 185.22.174.69:10010 is good
# average conn time: 4.35576179099
#
# 159 proxies left to filter
# 178.128.116.43:3128 is slow
#
# 158 proxies left to filter
# 180.180.218.133:59300 is slow
#
# 157 proxies left to filter
# 168.227.56.164:8080 is good
# average conn time: 4.36404591058
#
# 156 proxies left to filter
# 196.3.97.82:23500 is slow
#
# 155 proxies left to filter
# 200.23.125.155:80 is slow
#
# 154 proxies left to filter
# 176.111.10.136:52307 is slow
#
# 153 proxies left to filter
# 170.247.173.134:8080 is slow
#
# 152 proxies left to filter
# 200.54.194.10:53281 is good
# average conn time: 4.36144033661
#
# 151 proxies left to filter
# 185.195.252.109:8080 is good
# average conn time: 4.37505414473
#
# 150 proxies left to filter
# 165.227.107.218:8080 is slow
#
# 149 proxies left to filter
# 197.232.16.104:48034 is slow
#
# 148 proxies left to filter
# 134.119.222.254:8080 is slow
#
# 147 proxies left to filter
# 190.192.30.233:53281 is slow
#
# 146 proxies left to filter
# 200.23.125.145:80 is slow
#
# 145 proxies left to filter
# 200.23.125.214:80 is slow
#
# 144 proxies left to filter
# 183.89.8.185:8080 is good
# average conn time: 4.3731836806
#
# 143 proxies left to filter
# 186.4.251.135:8080 is good
# average conn time: 4.36710265996
#
# 142 proxies left to filter
# 171.100.86.216:80 is good
# average conn time: 4.37467071152
#
# 141 proxies left to filter
# 197.234.55.233:8083 is slow
#
# 140 proxies left to filter
# 200.23.125.242:80 is slow
#
# 139 proxies left to filter
# 168.90.30.180:20183 is good
# average conn time: 4.36888913525
#
# 138 proxies left to filter
# 197.234.45.229:8083 is slow
#
# 137 proxies left to filter
# 194.186.150.18:8080 is bad
#
# 136 proxies left to filter
# 191.7.210.162:45532 is slow
#
# 135 proxies left to filter
# 186.250.119.179:8080 is bad
#
# 134 proxies left to filter
# 190.16.237.38:43105 is good
# average conn time: 4.36891830695
#
# 133 proxies left to filter
# 200.152.78.48:38543 is slow
#
# 132 proxies left to filter
# 18.224.121.209:80 is slow
#
# 131 proxies left to filter
# 168.0.8.225:8080 is good
# average conn time: 4.36878320023
#
# 130 proxies left to filter
# 176.118.48.118:59905 is bad
#
# 129 proxies left to filter
# 197.210.186.38:30909 is bad
#
# 128 proxies left to filter
# 178.32.80.236:1080 is slow
#
# 127 proxies left to filter
# 160.202.129.22:53281 is good
# average conn time: 4.36962006778
#
# 126 proxies left to filter
# 187.115.88.234:80 is good
# average conn time: 4.36181245478
#
# 125 proxies left to filter
# 202.147.196.169:8080 is slow
#
# 124 proxies left to filter
# 182.23.99.134:58141 is slow
#
# 123 proxies left to filter
# 165.227.62.167:80 is slow
#
# 122 proxies left to filter
# 197.234.42.41:8083 is slow
#
# 121 proxies left to filter
# 167.99.72.14:8181 is slow
#
# 120 proxies left to filter
# 185.52.71.180:53281 is good
# average conn time: 4.35672333297
#
# 119 proxies left to filter
# 170.79.171.110:8080 is slow
#
# 118 proxies left to filter
# 168.205.250.239:53281 is slow
#
# 117 proxies left to filter
# 201.236.248.216:52006 is slow
#
# 116 proxies left to filter
# 189.89.91.234:20183 is good
# average conn time: 4.35970074344
#
# 115 proxies left to filter
# 187.44.177.178:41178 is bad
#
# 114 proxies left to filter
# 178.79.24.36:8080 is slow
#
# 113 proxies left to filter
# 186.4.197.118:80 is good
# average conn time: 4.35578606521
#
# 112 proxies left to filter
# 202.72.209.84:53281 is slow
#
# 111 proxies left to filter
# 18.191.74.68:8080 is slow
#
# 110 proxies left to filter
# 175.103.46.82:8080 is bad
#
# 109 proxies left to filter
# 192.140.42.81:57373 is bad
#
# 108 proxies left to filter
# 200.23.125.176:80 is slow
#
# 107 proxies left to filter
# 194.186.135.74:3130 is good
# average conn time: 4.35220894776
#
# 106 proxies left to filter
# 189.50.149.143:53281 is good
# average conn time: 4.35714307017
#
# 105 proxies left to filter
# 191.100.25.15:30299 is good
# average conn time: 4.35320173582
#
# 104 proxies left to filter
# 180.183.124.149:8213 is slow
#
# 103 proxies left to filter
# 186.47.46.30:31146 is good
# average conn time: 4.35364754995
#
# 102 proxies left to filter
# 185.183.99.231:8080 is slow
#
# 101 proxies left to filter
# 161.49.186.218:8080 is good
# average conn time: 4.35977651286
#
# 100 proxies left to filter
# 190.163.125.146:8080 is slow
#
# 99 proxies left to filter
# 180.183.243.4:8080 is bad
#
# 98 proxies left to filter
# 189.85.92.115:8080 is slow
#
# 97 proxies left to filter
# 180.183.119.238:8213 is slow
#
# 96 proxies left to filter
# 191.7.200.218:46535 is bad
#
# 95 proxies left to filter
# 167.99.7.198:8080 is good
# average conn time: 4.34919416935
#
# 94 proxies left to filter
# 160.0.223.6:8080 is good
# average conn time: 4.3502785432
#
# 93 proxies left to filter
# 186.64.121.220:3128 is slow
#
# 92 proxies left to filter
# 168.227.66.211:8080 is slow
#
# 91 proxies left to filter
# 182.16.186.210:23500 is slow
#
# 90 proxies left to filter
# 200.147.153.131:80 is slow
#
# 89 proxies left to filter
# 165.227.29.189:3128 is slow
#
# 88 proxies left to filter
# 18.130.255.122:80 is slow
#
# 87 proxies left to filter
# 180.180.217.124:50875 is good
# average conn time: 4.35014495337
#
# 86 proxies left to filter
# 186.42.224.222:34570 is bad
#
# 85 proxies left to filter
# 202.62.84.210:53281 is bad
#
# 84 proxies left to filter
# 200.23.125.152:80 is slow
#
# 83 proxies left to filter
# 154.72.79.252:57668 is slow
#
# 82 proxies left to filter
# 195.206.42.190:61643 is slow
#
# 81 proxies left to filter
# 164.163.32.239:63141 is slow
#
# 80 proxies left to filter
# 200.35.44.189:41511 is bad
#
# 79 proxies left to filter
# 190.214.12.82:3128 is good
# average conn time: 4.34774488211
#
# 78 proxies left to filter
# 163.125.65.182:9797 is good
# average conn time: 4.34400977797
#
# 77 proxies left to filter
# 190.52.35.2:8082 is good
# average conn time: 4.35738914146
#
# 76 proxies left to filter
# 188.112.11.131:8080 is good
# average conn time: 4.35246900969
#
# 75 proxies left to filter
# 191.238.218.78:80 is slow
#
# 74 proxies left to filter
# 201.182.223.16:37492 is good
# average conn time: 4.35263312585
#
# 73 proxies left to filter
# 185.144.156.183:8080 is slow
#
# 72 proxies left to filter
# 177.12.84.238:8080 is good
# average conn time: 4.35431847044
#
# 71 proxies left to filter
# 146.88.77.51:8080 is good
# average conn time: 4.35775670035
#
# 70 proxies left to filter
# 175.20.164.19:8080 is slow
#
# 69 proxies left to filter
# 182.253.142.50:8080 is slow
#
# 68 proxies left to filter
# 177.184.81.190:20183 is slow
#
# 67 proxies left to filter
# 162.243.102.207:3128 is slow
#
# 66 proxies left to filter
# 185.160.60.36:33471 is bad
#
# 65 proxies left to filter
# 178.32.80.239:8080 is bad
#
# 64 proxies left to filter
# 197.44.61.229:8080 is slow
#
# 63 proxies left to filter
# 180.183.101.47:8213 is slow
#
# 62 proxies left to filter
# 182.52.74.76:34084 is bad
#
# 61 proxies left to filter
# 160.16.52.185:3128 is bad
#
# 60 proxies left to filter
# 180.183.42.103:8213 is slow
#
# 59 proxies left to filter
# 193.95.220.23:3128 is good
# average conn time: 4.35640859066
#
# 58 proxies left to filter
# 177.46.147.89:44883 is bad
#
# 57 proxies left to filter
# 185.208.100.197:59732 is bad
#
# 56 proxies left to filter
# 178.32.204.97:443 is slow
#
# 55 proxies left to filter
# 183.88.228.208:8080 is good
# average conn time: 4.35303093374
#
# 54 proxies left to filter
# 194.183.182.195:53281 is good
# average conn time: 4.35475766451
#
# 53 proxies left to filter
# 180.183.115.254:8080 is good
# average conn time: 4.36402023491
#
# 52 proxies left to filter
# 186.96.113.108:9991 is good
# average conn time: 4.35856428395
#
# 51 proxies left to filter
# 179.60.241.169:42166 is bad
#
# 50 proxies left to filter
# 182.253.233.77:8080 is slow
#
# 49 proxies left to filter
# 185.132.133.195:8080 is slow
#
# 48 proxies left to filter
# 193.37.192.243:8080 is good
# average conn time: 4.36238534557
#
# 47 proxies left to filter
# 182.52.31.121:52078 is good
# average conn time: 4.37258971297
#
# 46 proxies left to filter
# 167.99.197.24:8080 is bad
#
# 45 proxies left to filter
# 183.88.192.197:8080 is good
# average conn time: 4.36959011978
#
# 44 proxies left to filter
# 181.112.225.78:58948 is good
# average conn time: 4.37797667236
#
# 43 proxies left to filter
# 178.47.139.50:8080 is slow
#
# 42 proxies left to filter
# 177.184.206.116:8080 is good
# average conn time: 4.37161415348
#
# 41 proxies left to filter
# 200.23.125.174:80 is slow
#
# 40 proxies left to filter
# 202.29.20.151:43083 is slow
#
# 39 proxies left to filter
# 183.30.204.170:9999 is slow
#
# 38 proxies left to filter
# 185.14.250.204:58185 is bad
#
# 37 proxies left to filter
# 192.99.207.23:40067 is slow
#
# 36 proxies left to filter
# 200.66.94.147:8080 is good
# average conn time: 4.36761298448
#
# 35 proxies left to filter
# 181.115.168.69:49076 is bad
#
# 34 proxies left to filter
# 170.82.52.48:8080 is good
# average conn time: 4.36896425282
#
# 33 proxies left to filter
# 183.88.158.77:8088 is good
# average conn time: 4.36535937421
#
# 32 proxies left to filter
# 159.138.22.191:80 is good
# average conn time: 4.35992928848
#
# 31 proxies left to filter
# 185.132.178.135:8080 is slow
#
# 30 proxies left to filter
# 174.85.22.214:3128 is slow
#
# 29 proxies left to filter
# 185.72.252.9:55670 is slow
#
# 28 proxies left to filter
# 178.92.9.210:3128 is bad
#
# 27 proxies left to filter
# 159.192.136.67:8080 is good
# average conn time: 4.35545950594
#
# 26 proxies left to filter
# 194.88.106.86:3128 is slow
#
# 25 proxies left to filter
# 180.183.119.201:8080 is good
# average conn time: 4.35904040314
#
# 24 proxies left to filter
# 190.92.65.145:8080 is slow
#
# 23 proxies left to filter
# 188.242.5.172:80 is good
# average conn time: 4.35574304569
#
# 22 proxies left to filter
# 200.81.169.242:38138 is bad
#
# 21 proxies left to filter
# 183.82.116.56:8080 is slow
#
# 20 proxies left to filter
# 177.107.53.229:8080 is good
# average conn time: 4.35284391103
#
# 19 proxies left to filter
# 175.126.168.176:80 is slow
#
# 18 proxies left to filter
# 177.104.139.132:8080 is good
# average conn time: 4.35311907201
#
# 17 proxies left to filter
# 200.54.40.165:9991 is good
# average conn time: 4.35105355505
#
# 16 proxies left to filter
# 181.112.223.230:8080 is bad
#
# 15 proxies left to filter
# 187.188.211.73:9991 is bad
#
# 14 proxies left to filter
# 181.112.57.54:53281 is bad
#
# 13 proxies left to filter
# 193.68.135.125:59278 is slow
#
# 12 proxies left to filter
# 179.187.9.61:8080 is good
# average conn time: 4.3495046734
#
# 11 proxies left to filter
# 187.109.63.9:20183 is good
# average conn time: 4.34412427857
#
# 10 proxies left to filter
# 197.234.44.201:8083 is slow
#
# 9 proxies left to filter
# 173.249.35.163:1448 is good
# average conn time: 4.33727626846
#
# 8 proxies left to filter
# 186.1.18.208:8080 is good
# average conn time: 4.34391334837
#
# 7 proxies left to filter
# 193.92.85.51:8080 is bad
#
# 6 proxies left to filter
# 184.180.90.226:8080 is slow
#
# 5 proxies left to filter
# 178.134.76.230:57804 is bad
#
# 4 proxies left to filter
# 181.112.58.22:65238 is good
# average conn time: 4.35272969534
#
# 3 proxies left to filter
# 177.105.225.157:38805 is good
# average conn time: 4.35302772668
#
# 2 proxies left to filter
# 190.15.205.50:8080 is good
# average conn time: 4.36352169654
#
# 1 proxies left to filter
# 197.234.55.17:8083 is slow
#
# average proxy time:4.36352169654

# %% [markdown]
# # Filter the Http proxies

# %%
url = 'https://www.proxy-list.download/HTTP'
filterProxys(url)
# Out:
# No proxies to text

# %% [markdown]
# # Overwrite the source text file with partially filtered or empty ip list

# %%
# overwrite the existing source of https proxy data with the filtered data
with open('proxyLists/https_proxys_part_1.txt', "w") as output:
    for line in testProxies['https']:
        output.write("%s\n" % line)

# %%
# overwrite the existing source of http proxy data with the filtered data
with open('proxyLists/http_proxys_part_1.txt', "w") as output:
    for line in testProxies['http']:
        output.write("%s\n" % line)

# %% [markdown]
# # Get all proxies that had connections times less than one second

# %%
df = pd.DataFrame(goodProxy['https'])
fast_proxies_https = list(df['proxy'][df['time']<1])

# %%
df = pd.DataFrame(goodProxy['http'])
fast_proxies_http = list(df['proxy'][df['time']<1])

# %% [markdown]
# # Import the single filtered files of proxys that had connections times less than one second and combine with the new filtered proxys

# %%
# Import
try:
    existing_https_proxies = list(pd.read_csv('../filtered_https_proxys.txt', header = None)[0])
except: #If the file is empty
    existing_https_proxies = []
try:
    existing_http_proxies = list(pd.read_csv('../filtered_http_proxys.txt', header = None)[0])
except: #If the file is empty
    existing_http_proxies = []

# %%
# add the new proxys to the existing ones if they are not already there
[existing_https_proxies.append(x) 
 for x in fast_proxies_https 
 if x not in existing_https_proxies]

[existing_http_proxies.append(x) 
 for x in fast_proxies_http 
 if x not in existing_http_proxies]
# Out:
# []

# %% [markdown]
# # Rewrite the final proxys text file with the new and old filtered proxies

# %%
#append filtered http proxys to existing .txt file
with open('../filtered_http_proxys.txt', "w") as output:
    for line in existing_http_proxies:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('../filtered_https_proxys.txt', "w") as output:
    for line in existing_https_proxies:
        output.write("%s\n" % line)
