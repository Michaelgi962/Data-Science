# %% [markdown]
# # Ref: https://codelike.pro/create-a-crawler-with-rotating-ip-proxy-in-python/

# %% [markdown]
# # Import Libraries

# %%
# Get the text data from the first job posting
import pandas as pd
import requests # For website connections
from bs4 import BeautifulSoup # For HTML parsing
import time
from nltk.corpus import stopwords # Filter oustopwordsopwords, such as 'the', 'or', 'and'
import re # Regular expressions
from itertools import groupby

# %%
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import random

# %%
Https_txt_file = 'proxyLists/https_proxys_part_4.txt'
#Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTPS
https_proxys = pd.read_csv(Https_txt_file, sep=" ", header=None)
#Convert to array
https_proxys = https_proxys[0].values
#Convert to list
https_proxys = list(https_proxys)

Http_txt_file = 'proxyLists/http_proxys_part_4.txt'
#Download New HTTPS IPs .txt file from https://www.proxy-list.download/HTTP
http_proxys = pd.read_csv(Http_txt_file, sep=" ", header=None)
#Convert to array
http_proxys = http_proxys[0].values
#Convert to list
http_proxys = list(http_proxys)

# %%
header = {}
def randHeader():
    ua = UserAgent()
    header['User-Agent'] = ua.random

# %%
# Retrieve a random index for the https proxy
def randomIndexHttps():
    num = random.randint(0, len(https_proxys) - 1)
    return num

# Retrieve a random index for the http proxy
def randomIndexHttp():
    num = random.randint(0, len(http_proxys) - 1)
    return num

# %%
proxyDict = {}
def randProx():
    # Choose a random proxy ip
    proxy_index_http = randomIndexHttp()
    proxy_index_https = randomIndexHttps()
   
    http_proxy = http_proxys[proxy_index_http]
    https_proxy = https_proxys[proxy_index_https]
    
    http_proxy_final  = 'http://' + http_proxy
    https_proxy_final = 'https://' + https_proxy

    proxyDict['http'] = http_proxy_final
    proxyDict['https'] = https_proxy_final
    
    return proxy_index_https,proxy_index_http

# %%
randProx()
print(proxyDict['http'],proxyDict['https'])
# Out:
# ('http://188.130.230.40:8081', 'https://185.70.105.194:3128')

# %%
url = 'http://icanhazip.com'
if url[0:5] == 'http:':
    for n in range(len(http_proxys)-1):
        # Every 10 requests, generate a new proxy
        t1 = time.time()
        # Choose a random proxy ip
        proxy_index_https,proxy_index_http = randProx()
        print(len(https_proxys),len(http_proxys))
        # Make the call
        try:
            my_ip = requests.get(url,headers=header,proxies=proxyDict,timeout=1).text
            t2 = time.time()
            t = t2-t1
            print('time:'+str(t)+', #' + str(n) + ': ' + str(proxyDict['http']))

        except: # If error, delete this proxy and find another one    
            t2 = time.time()
            del http_proxys[proxy_index_http]
            print('time:'+str(t2-t1)+str(proxyDict['http'])+ ' deleted.')

elif url[0:5] == 'https':
    for n in range(len(https_proxys)-1):
        # Every 10 requests, generate a new proxy
        t1 = time.time()
        # Choose a random proxy ip
        proxy_index_https,proxy_index_http = randProx()
        print(len(https_proxys),len(http_proxys))
        # Make the call
        try:
            my_ip = requests.get(url,headers=header,proxies=proxyDict,timeout=2).text
            t2 = time.time()
            t = t2-t1
            print('time:'+str(t)+', #' + str(n) + ': ' + str(proxyDict['https']))

        except: # If error, delete this proxy and find another one                 
            t2 = time.time()
            del https_proxys[proxy_index_https]
            print('time:'+str(t2-t1)+str(proxyDict['https'])+ ' deleted.')
# Out:
# (2, 229)
# time:0.211128950119, #0: 198.211.103.89
#
# (2, 229)
# time:0.209538936615, #1: HTTP/1.1 400 Bad Request
#
#
# (2, 229)
# time:0.0681459903717, #2: 429 Too Many Requests
#
# (2, 229)
# time:1.00974488258http://195.9.237.66:8080 deleted.
# (2, 228)
# time:0.220264911652, #4: 185.144.158.41
#
# (2, 228)
# time:0.0659830570221, #5: 429 Too Many Requests
#
# (2, 228)
# time:0.142940044403, #6: 185.144.156.183
#
# (2, 228)
# time:1.01518106461http://186.96.115.210:9991 deleted.
# (2, 227)
# time:0.797466039658, #8: 193.106.57.37
#
# (2, 227)
# time:1.01028084755http://202.153.231.147:80 deleted.
# (2, 226)
# time:0.220095157623, #10: 429 Too Many Requests
#
# (2, 226)
# time:1.01098895073http://185.194.27.238:8080 deleted.
# (2, 225)
# time:0.797296047211, #12: 191.252.100.32
#
# (2, 225)
# time:1.19995594025http://197.234.35.82:53281 deleted.
# (2, 224)
# time:0.210078001022, #14: 185.144.158.41
#
# (2, 224)
# time:1.11923003197http://185.132.178.201:8080 deleted.
# (2, 223)
# time:1.00867795944http://193.106.130.249:8080 deleted.
# (2, 222)
# time:0.630087852478, #17: 2a00:1838:36:e4::ca87
#
# (2, 222)
# time:1.00720787048http://190.124.34.221:53515 deleted.
# (2, 221)
# time:0.11485004425, #19: HTTP/1.1 400 Bad Request
#
#
# (2, 221)
# time:0.0621390342712, #20: 429 Too Many Requests
#
# (2, 221)
# time:1.24078702927http://202.138.248.123:50215 deleted.
# (2, 220)
# time:0.0598380565643, #22: 429 Too Many Requests
#
# (2, 220)
# time:0.2064640522, #23: HTTP/1.1 400 Bad Request
#
#
# (2, 220)
# time:1.11101102829http://192.162.68.126:80 deleted.
# (2, 219)
# time:0.138322114944http://189.39.120.226:3128 deleted.
# (2, 218)
# time:0.0602869987488, #26: HTTP/1.1 400 Bad Request
#
#
# (2, 218)
# time:0.811528921127, #27: 191.252.100.32
#
# (2, 218)
# time:1.17837309837, #28: 202.148.2.254
#
# (2, 218)
# time:1.00842785835http://185.189.209.1:34824 deleted.
# (2, 217)
# time:1.01217794418http://196.25.12.2:8888 deleted.
# (2, 216)
# time:0.212445020676, #31: 185.144.158.41
#
# (2, 216)
# time:0.969903945923, #32: 191.242.195.112
#
# (2, 216)
# time:2.18862485886http://193.112.202.5:1080 deleted.
# (2, 215)
# time:1.00966310501http://192.141.110.209:8080 deleted.
# (2, 214)
# time:1.00663518906http://202.62.48.55:59736 deleted.
# (2, 213)
# time:1.00990891457http://190.242.41.133:8080 deleted.
# (2, 212)
# time:1.01089906693http://190.122.97.138:52622 deleted.
# (2, 211)
# time:0.117747068405, #38: HTTP/1.1 400 Bad Request
#
#
# (2, 211)
# time:1.00802707672http://190.181.18.99:53281 deleted.
# (2, 210)
# time:0.777757883072, #40: 186.10.80.226
#
# (2, 210)
# time:0.217716932297, #41: 429 Too Many Requests
#
# (2, 210)
# time:1.23578691483http://202.54.169.235:8080 deleted.
# (2, 209)
# time:1.01079702377http://200.54.108.54:80 deleted.
# (2, 208)
# time:0.825656890869, #44: 201.48.194.210
#
# (2, 208)
# time:0.915683031082, #45: 188.247.39.14
#
# (2, 208)
# time:1.00899481773http://202.166.210.74:32571 deleted.
# (2, 207)
# time:0.580868005753, #47: 191.241.235.24
#
# (2, 207)
# time:0.582293987274, #48: 191.241.235.24
#
# (2, 207)
# time:0.213387966156, #49: HTTP/1.1 400 Bad Request
#
#
# (2, 207)
# time:1.01302194595http://190.149.165.154:39850 deleted.
# (2, 206)
# time:0.327737092972, #51: 199.19.203.114
#
# (2, 206)
# time:0.0680959224701, #52: HTTP/1.1 400 Bad Request
#
#
# (2, 206)
# time:1.19610500336http://191.33.228.178:45312 deleted.
# (2, 205)
# time:0.6876308918, #54: 2a00:1838:36:37d::68ac
#
# (2, 205)
# time:0.874516963959, #55: 201.217.247.98
#
# (2, 205)
# time:0.833467006683, #56: 186.250.119.179
#
# (2, 205)
# time:0.203974962234, #57: 198.211.103.89
#
# (2, 205)
# time:1.07044196129http://198.11.178.14:8080 deleted.
# (2, 204)
# time:0.225630044937, #59: HTTP/1.1 400 Bad Request
#
#
# (2, 204)
# time:1.01093411446http://185.70.105.226:3128 deleted.
# (2, 203)
# time:0.572932958603, #61: 191.241.235.24
#
# (2, 203)
# time:1.01051712036http://191.102.73.37:8080 deleted.
# (2, 202)
# time:1.01314711571http://201.148.167.246:38325 deleted.
# (2, 201)
# time:0.84595489502, #64: 191.252.100.32
#
# (2, 201)
# time:0.738382816315, #65: 193.86.1.130
#
# (2, 201)
# time:0.155514955521, #66: 2607:5300:60:1c23::1
#
# (2, 201)
# time:0.714097976685, #67: 190.102.154.131
#
# (2, 201)
# time:0.205973863602, #68: HTTP/1.1 400 Bad Request
#
#
# (2, 201)
# time:0.211472988129, #69: HTTP/1.1 400 Bad Request
#
#
# (2, 201)
# time:1.51477384567, #70: 185.138.123.78
#
# (2, 201)
# time:0.203632116318, #71: 198.211.103.89
#
# (2, 201)
# time:1.0364689827http://198.74.57.231:80 deleted.
# (2, 200)
# time:1.00778007507http://185.162.142.81:53281 deleted.
# (2, 199)
# time:1.42238497734http://202.129.251.74:38917 deleted.
# (2, 198)
# time:1.0109231472http://190.215.118.171:35186 deleted.
# (2, 197)
# time:1.00827503204http://201.49.73.110:53650 deleted.
# (2, 196)
# time:0.61625289917, #77: 200.255.122.174
#
# (2, 196)
# time:0.680371999741, #78: 2a00:1838:36:37d::68ac
#
# (2, 196)
# time:0.793491125107, #79: 185.7.169.214
#
# (2, 196)
# time:1.1704018116, #80: 197.216.2.126
#
# (2, 196)
# time:1.08866095543http://189.203.179.18:8080 deleted.
# (2, 195)
# time:0.0602400302887, #82: 429 Too Many Requests
#
# (2, 195)
# time:0.820814847946, #83: 201.217.247.98
#
# (2, 195)
# time:0.688570976257, #84: 185.61.24.205
#
# (2, 195)
# time:1.10813593864, #85: 202.148.2.254
#
# (2, 195)
# time:0.907886981964, #86: 190.90.20.229
#
# (2, 195)
# time:1.1547999382http://193.150.117.5:8000 deleted.
# (2, 194)
# time:1.3017270565http://202.166.173.81:63238 deleted.
# (2, 193)
# time:1.01036810875http://195.13.247.110:58584 deleted.
# (2, 192)
# time:0.530833005905, #90: 185.62.190.60
#
# (2, 192)
# time:1.01497101784http://186.201.15.133:38616 deleted.
# (2, 191)
# time:1.1309800148, #92: 200.77.176.138
#
# (2, 191)
# time:1.31228709221http://185.138.123.78:55630 deleted.
# (2, 190)
# time:1.02757000923http://196.3.97.86:23500 deleted.
# (2, 189)
# time:0.202511072159, #95: 198.211.103.89
#
# (2, 189)
# time:0.617647171021, #96: 194.88.105.156
#
# (2, 189)
# time:0.858486175537, #97: 200.69.236.64
#
# (2, 189)
# time:1.01587891579http://201.67.41.204:8080 deleted.
# (2, 188)
# time:0.0599789619446, #99: 429 Too Many Requests
#
# (2, 188)
# time:1.00741696358http://185.89.3.241:34927 deleted.
# (2, 187)
# time:0.636914014816, #101: 2a00:1838:36:e4::ca87
#
# (2, 187)
# time:0.62026309967, #102: 188.225.9.121
#
# (2, 187)
# time:0.204382896423, #103: HTTP/1.1 400 Bad Request
#
#
# (2, 187)
# time:0.114590167999http://185.132.133.185:8080 deleted.
# (2, 186)
# time:0.0604028701782, #105: 429 Too Many Requests
#
# (2, 186)
# time:1.26497793198http://190.82.94.13:80 deleted.
# (2, 185)
# time:1.08761000633http://201.143.32.82:80 deleted.
# (2, 184)
# time:0.0707020759583, #108: 429 Too Many Requests
#
# (2, 184)
# time:1.00859713554http://190.52.193.97:63141 deleted.
# (2, 183)
# time:0.203630208969, #110: HTTP/1.1 400 Bad Request
#
#
# (2, 183)
# time:0.114603042603, #111: HTTP/1.1 400 Bad Request
#
#
# (2, 183)
# time:1.00708293915http://190.145.140.106:8080 deleted.
# (2, 182)
# time:1.0071451664http://196.27.105.156:53281 deleted.
# (2, 181)
# time:1.0092420578http://187.17.154.192:55843 deleted.
# (2, 180)
# time:0.578960895538, #115: 191.241.235.24
#
# (2, 180)
# time:0.0744678974152, #116: HTTP/1.1 400 Bad Request
#
#
# (2, 180)
# time:0.0709638595581, #117: 429 Too Many Requests
#
# (2, 180)
# time:1.01963806152http://198.183.157.52:80 deleted.
# (2, 179)
# time:0.0579700469971, #119: HTTP/1.1 400 Bad Request
#
#
# (2, 179)
# time:1.0136859417http://202.166.202.29:58794 deleted.
# (2, 178)
# time:1.00915908813http://187.44.146.114:33120 deleted.
# (2, 177)
# time:1.14118003845http://193.150.121.67:4444 deleted.
# (2, 176)
# time:0.752892017365, #123: 185.7.169.214
#
# (2, 176)
# time:0.215742826462, #124: 185.144.159.188
#
# (2, 176)
# time:0.797895908356, #125: 201.48.194.210
#
# (2, 176)
# time:0.204956054688, #126: HTTP/1.1 400 Bad Request
#
#
# (2, 176)
# time:0.203644990921, #127: HTTP/1.1 400 Bad Request
#
#
# (2, 176)
# time:0.897911071777, #128: 189.112.212.6
#
# (2, 176)
# time:1.12664294243http://189.126.79.126:52678 deleted.
# (2, 175)
# time:1.02145791054http://190.130.117.115:53882 deleted.
# (2, 174)
# time:0.406984090805, #131: 190.121.227.174
#
# (2, 174)
# time:0.0612351894379, #132: 429 Too Many Requests
#
# (2, 174)
# time:0.0668849945068, #133: 429 Too Many Requests
#
# (2, 174)
# time:0.7209649086, #134: 189.89.248.40
#
# (2, 174)
# time:1.1387360096http://188.134.16.191:43665 deleted.
# (2, 173)
# time:0.20788192749, #136: HTTP/1.1 400 Bad Request
#
#
# (2, 173)
# time:1.01339912415http://188.94.229.229:8080 deleted.
# (2, 172)
# time:1.01024389267http://186.159.3.217:40864 deleted.
# (2, 171)
# time:0.516681194305, #139: 191.102.82.94
#
# (2, 171)
# time:0.57492184639, #140: 191.241.235.24
#
# (2, 171)
# time:1.11503696442http://185.132.133.206:8080 deleted.
# (2, 170)
# time:0.47779583931, #142: <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html><head>
# <meta type="copyright" content="Copyright (C) 1996-2015 The Squid Software Foundation and contributors">
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title>ERROR: The requested URL could not be retrieved</title>
# <style type="text/css"><!--
#  /*
#  * Copyright (C) 1996-2015 The Squid Software Foundation and contributors
#  *
#  * Squid software is distributed under GPLv2+ license and includes
#  * contributions from numerous individuals and organizations.
#  * Please see the COPYING and CONTRIBUTORS files for details.
#  */
#
# /*
#  Stylesheet for Squid Error pages
#  Adapted from design by Free CSS Templates
#  http://www.freecsstemplates.org
#  Released for free under a Creative Commons Attribution 2.5 License
# */
#
# /* Page basics */
# * {
# 	font-family: verdana, sans-serif;
# }
#
# html body {
# 	margin: 0;
# 	padding: 0;
# 	background: #efefef;
# 	font-size: 12px;
# 	color: #1e1e1e;
# }
#
# /* Page displayed title area */
# #titles {
# 	margin-left: 15px;
# 	padding: 10px;
# 	padding-left: 100px;
# 	background: url('/squid-internal-static/icons/SN.png') no-repeat left;
# }
#
# /* initial title */
# #titles h1 {
# 	color: #000000;
# }
# #titles h2 {
# 	color: #000000;
# }
#
# /* special event: FTP success page titles */
# #titles ftpsuccess {
# 	background-color:#00ff00;
# 	width:100%;
# }
#
# /* Page displayed body content area */
# #content {
# 	padding: 10px;
# 	background: #ffffff;
# }
#
# /* General text */
# p {
# }
#
# /* error brief description */
# #error p {
# }
#
# /* some data which may have caused the problem */
# #data {
# }
#
# /* the error message received from the system or other software */
# #sysmsg {
# }
#
# pre {
#     font-family:sans-serif;
# }
#
# /* special event: FTP / Gopher directory listing */
# #dirmsg {
#     font-family: courier;
#     color: black;
#     font-size: 10pt;
# }
# #dirlisting {
#     margin-left: 2%;
#     margin-right: 2%;
# }
# #dirlisting tr.entry td.icon,td.filename,td.size,td.date {
#     border-bottom: groove;
# }
# #dirlisting td.size {
#     width: 50px;
#     text-align: right;
#     padding-right: 5px;
# }
#
# /* horizontal lines */
# hr {
# 	margin: 0;
# }
#
# /* page displayed footer area */
# #footer {
# 	font-size: 9px;
# 	padding-left: 10px;
# }
#
#
# body
# :lang(fa) { direction: rtl; font-size: 100%; font-family: Tahoma, Roya, sans-serif; float: right; }
# :lang(he) { direction: rtl; }
#  --></style>
# </head><body id=ERR_DNS_FAIL>
# <div id="titles">
# <h1>ERROR</h1>
# <h2>The requested URL could not be retrieved</h2>
# </div>
# <hr>
#
# <div id="content">
# <p>The following error was encountered while trying to retrieve the URL: <a href="http://icanhazip.com/">http://icanhazip.com/</a></p>
#
# <blockquote id="error">
# <p><b>Unable to determine IP address from host name <q>icanhazip.com</q></b></p>
# </blockquote>
#
# <p>The DNS server returned:</p>
# <blockquote id="data">
# <pre>No DNS records</pre>
# </blockquote>
#
# <p>This means that the cache was not able to resolve the hostname presented in the URL. Check if the address is correct.</p>
#
# <p>Your cache administrator is <a href="mailto:webmaster?subject=CacheErrorInfo%20-%20ERR_DNS_FAIL&amp;body=CacheHost%3A%20Asiabettor-Staging%0D%0AErrPage%3A%20ERR_DNS_FAIL%0D%0AErr%3A%20%5Bnone%5D%0D%0ADNS%20ErrMsg%3A%20No%20DNS%20records%0D%0ATimeStamp%3A%20Fri,%2005%20Apr%202019%2004%3A37%3A39%20GMT%0D%0A%0D%0AClientIP%3A%20128.210.106.81%0D%0A%0D%0AHTTP%20Request%3A%0D%0AGET%20%2F%20HTTP%2F1.1%0AConnection%3A%20keep-alive%0D%0AAccept-Encoding%3A%20gzip,%20deflate%0D%0AAccept%3A%20*%2F*%0D%0AUser-Agent%3A%20python-requests%2F2.21.0%0D%0AHost%3A%20icanhazip.com%0D%0A%0D%0A%0D%0A">webmaster</a>.</p>
# <br>
# </div>
#
# <hr>
# <div id="footer">
# <p>Generated Fri, 05 Apr 2019 04:37:39 GMT by Asiabettor-Staging (squid/3.5.12)</p>
# <!-- ERR_DNS_FAIL -->
# </div>
# </body></html>
#
# (2, 170)
# time:1.15789794922, #143: 202.169.226.236
#
# (2, 170)
# time:0.572015047073, #144: 191.241.235.24
#
# (2, 170)
# time:1.10711503029http://190.80.11.32:8080 deleted.
# (2, 169)
# time:0.521700143814, #146: 185.62.190.60
#
# (2, 169)
# time:0.206900835037, #147: HTTP/1.1 400 Bad Request
#
#
# (2, 169)
# time:0.577307939529, #148: 191.241.235.24
#
# (2, 169)
# time:0.207337141037, #149: HTTP/1.1 400 Bad Request
#
#
# (2, 169)
# time:0.081404209137, #150: 429 Too Many Requests
#
# (2, 169)
# time:0.218420028687, #151: 429 Too Many Requests
#
# (2, 169)
# time:1.00881004333http://200.152.68.54:80 deleted.
# (2, 168)
# time:0.562114953995, #153: 191.102.82.94
#
# (2, 168)
# time:1.00742197037http://185.70.105.223:8888 deleted.
# (2, 167)
# time:0.751115083694, #155: 201.217.247.98
#
# (2, 167)
# time:1.11470603943http://185.132.178.199:8080 deleted.
# (2, 166)
# time:0.219419956207, #157: 429 Too Many Requests
#
# (2, 166)
# time:1.01052498817http://190.104.142.78:8080 deleted.
# (2, 165)
# time:0.244832992554, #159: 2607:5300:60:1c23::1
#
# (2, 165)
# time:1.01477384567http://190.61.40.162:53281 deleted.
# (2, 164)
# time:1.00935721397http://197.255.152.20:56045 deleted.
# (2, 163)
# time:1.00636601448http://200.35.56.161:35945 deleted.
# (2, 162)
# time:0.18368601799, #163: 199.201.122.89
#
# (2, 162)
# time:0.583276987076, #164: 191.241.235.24
#
# (2, 162)
# time:0.204952001572, #165: HTTP/1.1 400 Bad Request
#
#
# (2, 162)
# time:0.431955099106, #166: 190.121.227.174
#
# (2, 162)
# time:0.230820894241, #167: 429 Too Many Requests
#
# (2, 162)
# time:0.783143043518, #168: 201.48.194.210
#
# (2, 162)
# time:0.0612578392029, #169: 429 Too Many Requests
#
# (2, 162)
# time:0.628685951233, #170: 2a00:1838:36:e4::ca87
#
# (2, 162)
# time:1.01025700569http://191.7.204.82:3128 deleted.
# (2, 161)
# time:0.210016965866, #172: HTTP/1.1 400 Bad Request
#
#
# (2, 161)
# time:0.20516204834, #173: HTTP/1.1 400 Bad Request
#
#
# (2, 161)
# time:1.01154708862http://191.36.172.193:8080 deleted.
# (2, 160)
# time:0.803078889847, #175: 185.7.169.214
#
# (2, 160)
# time:0.572153091431, #176: 191.241.235.24
#
# (2, 160)
# time:0.263177156448, #177: 185.144.159.188
#
# (2, 160)
# time:0.786087989807, #178: 190.102.154.131
#
# (2, 160)
# time:0.206964015961, #179: 198.211.103.89
#
# (2, 160)
# time:0.184882164001, #180: 199.201.122.89
#
# (2, 160)
# time:1.01075792313http://187.109.210.215:8080 deleted.
# (2, 159)
# time:0.207361936569, #182: HTTP/1.1 400 Bad Request
#
#
# (2, 159)
# time:0.0609588623047, #183: 429 Too Many Requests
#
# (2, 159)
# time:0.213212013245, #184: 198.1.114.12
#
# (2, 159)
# time:1.00914096832http://190.211.104.226:8080 deleted.
# (2, 158)
# time:1.13019895554http://191.100.24.251:21776 deleted.
# (2, 157)
# time:1.15815997124http://194.135.97.178:3128 deleted.
# (2, 156)
# time:0.448844909668, #188: 190.107.30.117
#
# (2, 156)
# time:0.620624065399, #189: 200.255.122.174
#
# (2, 156)
# time:1.11181020737http://185.64.18.25:8080 deleted.
# (2, 155)
# time:1.15738391876http://191.239.243.156:3128 deleted.
# (2, 154)
# time:0.206494092941, #192: HTTP/1.1 400 Bad Request
#
#
# (2, 154)
# time:0.0616970062256, #193: 429 Too Many Requests
#
# (2, 154)
# time:0.581351995468, #194: 191.241.235.24
#
# (2, 154)
# time:1.00715899467http://193.165.151.62:54634 deleted.
# (2, 153)
# time:0.884835958481, #196: 186.248.146.170
#
# (2, 153)
# time:0.674855232239, #197: 2a00:1838:36:379::b7e5
#
# (2, 153)
# time:0.792184114456, #198: 191.252.100.32
#
# (2, 153)
# time:0.580947875977, #199: 191.241.235.24
#
# (2, 153)
# time:0.736343860626, #200: 200.155.36.185
#
# (2, 153)
# time:0.0705580711365, #201: HTTP/1.1 400 Bad Request
#
#
# (2, 153)
# time:0.072850227356, #202: 429 Too Many Requests
#
# (2, 153)
# time:0.117741107941, #203: 429 Too Many Requests
#
# (2, 153)
# time:0.581092834473, #204: 191.241.235.24
#
# (2, 153)
# time:0.594898939133, #205: 191.241.235.24
#
# (2, 153)
# time:1.151460886http://189.125.170.36:80 deleted.
# (2, 152)
# time:1.20103907585http://195.209.131.19:48671 deleted.
# (2, 151)
# time:0.233247041702, #208: 2607:5300:60:1c23::1
#
# (2, 151)
# time:1.26214504242http://202.137.25.8:8080 deleted.
# (2, 150)
# time:0.96381187439, #210: 188.247.39.14
#
# (2, 150)
# time:0.488344907761, #211: 188.166.119.186
#
# (2, 150)
# time:0.113165140152, #212: HTTP/1.1 400 Bad Request
#
#
# (2, 150)
# time:0.579329967499, #213: 191.241.235.24
#
# (2, 150)
# time:0.220453023911, #214: 429 Too Many Requests
#
# (2, 150)
# time:0.208781957626, #215: HTTP/1.1 400 Bad Request
#
#
# (2, 150)
# time:0.206768035889, #216: HTTP/1.1 400 Bad Request
#
#
# (2, 150)
# time:0.0619978904724, #217: 429 Too Many Requests
#
# (2, 150)
# time:1.2759308815http://202.150.132.98:63141 deleted.
# (2, 149)
# time:0.205157995224, #219: HTTP/1.1 400 Bad Request
#
#
# (2, 149)
# time:0.0632359981537, #220: 429 Too Many Requests
#
# (2, 149)
# time:0.767980098724, #221: 2a00:1838:36:37d::68ac
#
# (2, 149)
# time:1.00769400597http://202.124.38.230:8080 deleted.
# (2, 148)
# time:0.634922981262, #223: 2a00:1838:36:e4::ca87
#
# (2, 148)
# time:0.231695175171, #224: 185.144.158.41
#
# (2, 148)
# time:1.17342114449http://186.10.80.226:80 deleted.
# (2, 147)
# time:0.182882070541, #226: 199.201.122.89
#
# (2, 147)
# time:0.7483959198, #227: 190.90.193.96

# %%
url = 'https://dataandthingsscience.wordpress.com/2019/03/29/version-control-with-git-and-github/'
if url[0:5] == 'http:':
    for n in range(len(http_proxys)-1):
        # Every 10 requests, generate a new proxy
        t1 = time.time()
        # Choose a random proxy ip
        proxy_index_https,proxy_index_http = randProx()
        print(len(https_proxys),len(http_proxys))
        # Make the call
        try:
            my_ip = requests.get(url,headers=header,proxies=proxyDict,timeout=1).text
            t2 = time.time()
            t = t2-t1
            print('time:'+str(t)+', #' + str(n) + ': ' + str(proxyDict['http']))

        except: # If error, delete this proxy and find another one    
            t2 = time.time()
            del http_proxys[proxy_index_http]
            print('time:'+str(t2-t1)+str(proxyDict['http'])+ ' deleted.')

elif url[0:5] == 'https':
    for n in range(len(https_proxys)-1):
        # Every 10 requests, generate a new proxy
        t1 = time.time()
        # Choose a random proxy ip
        proxy_index_https,proxy_index_http = randProx()
        print(len(https_proxys),len(http_proxys))
        # Make the call
        try:
            my_ip = requests.get(url,headers=header,proxies=proxyDict,timeout=2).text
            t2 = time.time()
            t = t2-t1
            print('time:'+str(t)+', #' + str(n) + ': ' + str(proxyDict['https']))

        except: # If error, delete this proxy and find another one                 
            t2 = time.time()
            del https_proxys[proxy_index_https]
            print('time:'+str(t2-t1)+str(proxyDict['https'])+ ' deleted.')
# Out:
# (8, 229)
# time:2.14909505844https://187.111.192.142:50608 deleted.
# (7, 229)
# time:2.01463699341https://186.177.141.223:54087 deleted.
# (6, 229)
# time:2.29529094696, #2: 429 Too Many Requests
#
# (6, 229)
# time:2.0114300251https://190.255.37.60:8080 deleted.
# (5, 229)
# time:2.00918292999https://190.184.202.158:38295 deleted.
# (4, 229)
# time:2.01150608063https://202.5.37.96:63141 deleted.
# (3, 229)
# time:4.23137903214https://197.216.2.9:8080 deleted.

# %%
#append filtered http proxys to existing .txt file
with open('proxyLists/filtered_http_proxys.txt', "a") as output:
    for line in http_proxys:
        output.write("%s\n" % line)

# %%
# append filtered https proxies to existing text file
with open('proxyLists/filtered_https_proxys.txt', "a") as output:
    for line in https_proxys:
        output.write("%s\n" % line)
